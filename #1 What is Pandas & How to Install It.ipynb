# %%
import pandas as pd

count_df = pd.read_excel(r'C:\Users\dell\Desktop\img\MOCK_DATA.xlsx')
count_df
# Out:
#      customer_id   first_name     last_name  age                        email  \
# 0              4      Curtice        Cannop   58       ccannop0@earthlink.net
# 1              2     Mignonne        Lemmen   62         mlemmen1@walmart.com
# 2              3         Doug         Spark   51           dspark2@utexas.edu
# 3              8        Orion       Burford   21             oburford3@ca.gov
# 4              9       Ansley  Swindlehurst   32      aswindlehurst4@webs.com
# ..           ...          ...           ...  ...                          ...
# 995            8      Sigmund       Dibling   79  sdiblingrn@seattletimes.com
# 996            6        Bjorn        Minico   67        bminicoro@histats.com
# 997            9       Harley          Romi   53             hromirp@lulu.com
# 998            5         Peta        Parris   60         pparrisrq@ustream.tv
# 999            4  Christopher         Pardi   58              cpardirr@goo.gl
#
# ...

# %%
pd.__version__
# Out:
# '2.0.3'
