# %%
import pandas as pd

games = pd.read_csv(r'C:\Users\dell\Desktop\img\vgsalesGlobale.csv')
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      Devshare     82.51     20.44      8.39        10.16          7.01
# 1          Muxo      7.43      8.40      9.66         3.07          6.33
# 2         Eidel     17.50     17.96      7.15         4.74          5.63
# 3         Mynte     13.05      5.60      5.64         6.97          1.23
# 4         Quinu     16.92     24.00      5.59         5.16          3.66
# ..          ...       ...       ...       ...          ...           ...
# 995    Edgewire     77.09      3.36      0.69        10.33          0.34
# 996       Skyba      5.14      8.72      4.02         7.42          8.20
# 997  Topicstorm     19.89     27.42      4.02         4.12          0.65
# 998  Jabbertype     38.59      7.22      6.20         3.71          0.09
# 999      Voonyx     58.61     21.83      5.89         2.65          0.50
#
# [1000 rows x 11 columns]

# %%
games.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year              int64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
games["Rank"].dtype
# Out:
# dtype('int64')

# %%
games.describe()
# Out:
#               Rank        Year     NA_Sales     EU_Sales     JP_Sales  \
# count  1000.000000  1000.00000  1000.000000  1000.000000  1000.000000
# mean    500.500000  2001.02100    41.325110    14.142520     5.074350
# std     288.819436    12.28664    24.012333     8.231226     2.986946
# min       1.000000  1980.00000     0.140000     0.090000     0.030000
# 25%     250.750000  1990.00000    20.127500     7.037500     2.447500
# 50%     500.500000  2001.00000    40.960000    14.125000     5.095000
# 75%     750.250000  2011.00000    61.792500    21.375000     7.695000
# max    1000.000000  2022.00000    82.730000    29.000000    10.220000
#
#        Other_Sales  Global_Sales
# count  1000.000000   1000.000000
# mean      5.360470      5.348440
# std       3.025754      3.069422
# min       0.020000      0.000000
# 25%       2.722500      2.727500
# 50%       5.515000      5.430000
# 75%       7.960000      8.072500
# max      10.550000     10.560000

# %%
games["Rank"].describe()
# Out:
# count    1000.000000
# mean      500.500000
# std       288.819436
# min         1.000000
# 25%       250.750000
# 50%       500.500000
# 75%       750.250000
# max      1000.000000
# Name: Rank, dtype: float64

# %%
games.Genre.describe()
# Out:
# count        1000
# unique          3
# top       Shooter
# freq          343
# Name: Genre, dtype: object

# %%
games.value_counts()
# Out:
# Rank  Name                            Platform         Year  Genre    Publisher   NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 1     Syrup - Monin - Passion Fruit   Nintendo Switch  2008  Action   Devshare    82.51     20.44     8.39      10.16        7.01            1
# 672   Horseradish - Prepared          Nintendo Switch  2022  Sports   Blognation  8.89      4.36      4.13      8.23         0.49            1
# 659   Hinge W Undercut                PS4              1995  Action   Geba        24.02     5.79      4.33      2.95         6.55            1
# 660   Apricots - Dried                Nintendo Switch  2021  Action   Skipstorm   7.97      2.75      6.99      0.34         6.66            1
# 661   Tomatoes - Heirloom             PS4              2013  Action   Voomm       30.15     19.51     4.57      6.90         6.84            1
#                                                                                                                                             ..
# 339   Muffin - Banana Nut Individual  PS4              2002  Shooter  Meevee      22.13     8.14      5.79      4.78         1.12            1
# 340   The Pop Shoppe - Root Beer      Nintendo Switch  2017  Sports   Zooveo      57.23     4.15      3.47      6.79         4.61            1
# 341   Beer - Steamwhistle             Nintendo Switch  1997  Sports   Dablist     61.42     20.91     4.80      0.15         8.95            1
# 342   Bread - Hamburger Buns          Xbox One         2007  Shooter  Flashset    28.36     19.56     1.98      7.70         1.36            1
# 1000  Cheese - Swiss Sliced           Xbox One         1996  Action   Voonyx      58.61     21.83     5.89      2.65         0.50            1
# Name: count, Length: 1000, dtype: int64

# %%
games.Genre.value_counts()
# Out:
# Genre
# Shooter    343
# Sports     336
# Action     321
# Name: count, dtype: int64

# %%
games.Rank.value_counts()
# Out:
# Rank
# 1       1
# 672     1
# 659     1
# 660     1
# 661     1
#        ..
# 339     1
# 340     1
# 341     1
# 342     1
# 1000    1
# Name: count, Length: 1000, dtype: int64

# %%
games.Genre.value_counts(normalize=True)
# Out:
# Genre
# Shooter    0.343
# Sports     0.336
# Action     0.321
# Name: proportion, dtype: float64

# %%
type(games.Genre.value_counts())
# Out:
# pandas.core.series.Series

# %%
games.Genre.value_counts().head()
# Out:
# Genre
# Shooter    343
# Sports     336
# Action     321
# Name: count, dtype: int64

# %%
games.Genre.unique()
# Out:
# array(['Action', 'Sports', 'Shooter'], dtype=object)

# %%
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      Devshare     82.51     20.44      8.39        10.16          7.01
# 1          Muxo      7.43      8.40      9.66         3.07          6.33
# 2         Eidel     17.50     17.96      7.15         4.74          5.63
# 3         Mynte     13.05      5.60      5.64         6.97          1.23
# 4         Quinu     16.92     24.00      5.59         5.16          3.66
# ..          ...       ...       ...       ...          ...           ...
# 995    Edgewire     77.09      3.36      0.69        10.33          0.34
# 996       Skyba      5.14      8.72      4.02         7.42          8.20
# 997  Topicstorm     19.89     27.42      4.02         4.12          0.65
# 998  Jabbertype     38.59      7.22      6.20         3.71          0.09
# 999      Voonyx     58.61     21.83      5.89         2.65          0.50
#
# [1000 rows x 11 columns]

# %%
games.Platform.unique()
# Out:
# array(['Nintendo Switch', 'PS4', 'Xbox One'], dtype=object)

# %%
games.Platform.nunique()
# Out:
# 3

# %%
pd.crosstab(games.Genre, games.Year)
# Out:
# Year     1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# Genre                                                                ...
# Action      7     4     7    11     8     8     7     9     6    13  ...
# Shooter     5     6    10     7     9     5     7    10     9     8  ...
# Sports      3    11     8     5     8    14    10     7     8     8  ...
#
# Year     2013  2014  2015  2016  2017  2018  2019  2020  2021  2022
# Genre
# Action     10     7     8     6     8     5     6     2    12    10
# Shooter     1     8     5     8     4    10    10    11     9     5
# Sports      6    10     9     8    12     9     7     4     6     5
#
# [3 rows x 43 columns]

# %%
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      Devshare     82.51     20.44      8.39        10.16          7.01
# 1          Muxo      7.43      8.40      9.66         3.07          6.33
# 2         Eidel     17.50     17.96      7.15         4.74          5.63
# 3         Mynte     13.05      5.60      5.64         6.97          1.23
# 4         Quinu     16.92     24.00      5.59         5.16          3.66
# ..          ...       ...       ...       ...          ...           ...
# 995    Edgewire     77.09      3.36      0.69        10.33          0.34
# 996       Skyba      5.14      8.72      4.02         7.42          8.20
# 997  Topicstorm     19.89     27.42      4.02         4.12          0.65
# 998  Jabbertype     38.59      7.22      6.20         3.71          0.09
# 999      Voonyx     58.61     21.83      5.89         2.65          0.50
#
# [1000 rows x 11 columns]

# %%
games.Global_Sales.describe()
# Out:
# count    1000.000000
# mean        5.348440
# std         3.069422
# min         0.000000
# 25%         2.727500
# 50%         5.430000
# 75%         8.072500
# max        10.560000
# Name: Global_Sales, dtype: float64

# %%
games.Global_Sales.mean()
# Out:
# 5.34844

# %%
games.Global_Sales.value_counts()
# Out:
# Global_Sales
# 2.97    6
# 3.97    5
# 0.97    5
# 2.27    4
# 6.44    4
#        ..
# 6.98    1
# 9.05    1
# 0.95    1
# 6.26    1
# 0.50    1
# Name: count, Length: 644, dtype: int64

# %%
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      Devshare     82.51     20.44      8.39        10.16          7.01
# 1          Muxo      7.43      8.40      9.66         3.07          6.33
# 2         Eidel     17.50     17.96      7.15         4.74          5.63
# 3         Mynte     13.05      5.60      5.64         6.97          1.23
# 4         Quinu     16.92     24.00      5.59         5.16          3.66
# ..          ...       ...       ...       ...          ...           ...
# 995    Edgewire     77.09      3.36      0.69        10.33          0.34
# 996       Skyba      5.14      8.72      4.02         7.42          8.20
# 997  Topicstorm     19.89     27.42      4.02         4.12          0.65
# 998  Jabbertype     38.59      7.22      6.20         3.71          0.09
# 999      Voonyx     58.61     21.83      5.89         2.65          0.50
#
# [1000 rows x 11 columns]

# %%
games.Year.plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
games.Genre.value_counts()
# Out:
# Genre
# Shooter    343
# Sports     336
# Action     321
# Name: count, dtype: int64

# %%
games.Genre.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Genre'>
