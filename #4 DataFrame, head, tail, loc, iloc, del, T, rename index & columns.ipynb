# %%
import pandas as pd

data={"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],      
      "score":[90,80,85,75,95,60,65],      
      "sport":["Wrestling","Football","Skiing","Swimming","Tennis",
               "Karete","Surfing"],      
      "sex":["M","M","M","M","F","F","F"]}

df = pd.DataFrame(data=data)

df
# Out:
#       name  score      sport sex
# 0     Bill     90  Wrestling   M
# 1      Tom     80   Football   M
# 2      Tim     85     Skiing   M
# 3     John     75   Swimming   M
# 4     Alex     95     Tennis   F
# 5  Vanessa     60     Karete   F
# 6     Kate     65    Surfing   F

# %%
df.head()
# Out:
#    name  score      sport sex
# 0  Bill     90  Wrestling   M
# 1   Tom     80   Football   M
# 2   Tim     85     Skiing   M
# 3  John     75   Swimming   M
# 4  Alex     95     Tennis   F

# %%
df.head()
# Out:
#    name  score      sport sex
# 0  Bill     90  Wrestling   M
# 1   Tom     80   Football   M
# 2   Tim     85     Skiing   M
# 3  John     75   Swimming   M
# 4  Alex     95     Tennis   F

# %%
df.tail()
# Out:
#       name  score     sport sex
# 2      Tim     85    Skiing   M
# 3     John     75  Swimming   M
# 4     Alex     95    Tennis   F
# 5  Vanessa     60    Karete   F
# 6     Kate     65   Surfing   F

# %%
import pandas as pd

games = pd.read_csv(r'C:\Users\dell\Desktop\img\vgsalesGlobale.csv')
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.head()
# Out:
#    Rank                           Name         Platform  Year    Genre  \
# 0     1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1     2                           Yams  Nintendo Switch  2010   Sports
# 2     3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3     4                        Gherkin         Xbox One  2016   Action
# 4     5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0  Devshare     82.51     20.44      8.39        10.16          7.01
# 1      Muxo      7.43      8.40      9.66         3.07          6.33
# 2     Eidel     17.50     17.96      7.15         4.74          5.63
# 3     Mynte     13.05      5.60      5.64         6.97          1.23
# 4     Quinu     16.92     24.00      5.59         5.16          3.66

# %%
games.head(20)
# Out:
#     Rank                           Name         Platform  Year    Genre  \
# 0      1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1      2                           Yams  Nintendo Switch  2010   Sports
# 2      3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3      4                        Gherkin         Xbox One  2016   Action
# 4      5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# 5      6  Pastry - Banana Muffin - Mini  Nintendo Switch  1994   Sports
# 6      7    Nantucket Pine Orangebanana         Xbox One  2017   Action
# 7      8       Island Oasis - Raspberry              PS4  1999   Action
# 8      9                  Nori Sea Weed              PS4  1988   Sports
# 9     10       Cheese - Taleggio D.o.p.  Nintendo Switch  2005   Action
# 10    11   Soup - Clam Chowder, Dry Mix  Nintendo Switch  2005   Action
# 11    12               Soup - Campbells              PS4  2010  Shooter
# ...

# %%
games.tail()
# Out:
#      Rank                        Name  Platform  Year    Genre   Publisher  \
# 995   996  Shrimp - Black Tiger 16/20  Xbox One  1985   Sports    Edgewire
# 996   997  Muffin Mix - Morning Glory  Xbox One  2011  Shooter       Skyba
# 997   998    Muffin Orange Individual       PS4  1996   Action  Topicstorm
# 998   999               Sage - Ground       PS4  1997   Sports  Jabbertype
# 999  1000       Cheese - Swiss Sliced  Xbox One  1996   Action      Voonyx
#
#      NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 995     77.09      3.36      0.69        10.33          0.34
# 996      5.14      8.72      4.02         7.42          8.20
# 997     19.89     27.42      4.02         4.12          0.65
# 998     38.59      7.22      6.20         3.71          0.09
# 999     58.61     21.83      5.89         2.65          0.50

# %%
games.tail(15)
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 985   986   Lemonade - Pineapple Passion  Nintendo Switch  1984   Sports
# 986   987            Beer - Rickards Red         Xbox One  2001   Sports
# 987   988          Paper Towel Touchless              PS4  1986   Sports
# 988   989  Appetizer - Asian Shrimp Roll         Xbox One  2019   Sports
# 989   990                Fireball Whisky              PS4  2008   Action
# 990   991                Cabbage - Green         Xbox One  1989   Sports
# 991   992   Lettuce - Mini Greens, Whole  Nintendo Switch  1985   Sports
# 992   993   Wine - Barbera Alba Doc 2001              PS4  2001   Sports
# 993   994           Apple - Granny Smith  Nintendo Switch  2019   Sports
# 994   995              Sausage - Chorizo         Xbox One  1990   Action
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# ...

# %%
import pandas as pd

data={"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],      
      "score":[90,80,85,75,95,60,65],      
      "sport":["Wrestling","Football","Skiing","Swimming","Tennis",
               "Karete","Surfing"],      
      "sex":["M","M","M","M","F","F","F"]}

df = pd.DataFrame(data=data)

df
# Out:
#       name  score      sport sex
# 0     Bill     90  Wrestling   M
# 1      Tom     80   Football   M
# 2      Tim     85     Skiing   M
# 3     John     75   Swimming   M
# 4     Alex     95     Tennis   F
# 5  Vanessa     60     Karete   F
# 6     Kate     65    Surfing   F

# %%
df=pd.DataFrame(data, columns=["name", "sport", "gender", "score", "age"])

df
# Out:
#       name      sport gender  score  age
# 0     Bill  Wrestling    NaN     90  NaN
# 1      Tom   Football    NaN     80  NaN
# 2      Tim     Skiing    NaN     85  NaN
# 3     John   Swimming    NaN     75  NaN
# 4     Alex     Tennis    NaN     95  NaN
# 5  Vanessa     Karete    NaN     60  NaN
# 6     Kate    Surfing    NaN     65  NaN

# %%
df=pd.DataFrame(df, columns=["name", "sport", "gender", "score", "age"])
df
# Out:
#       name      sport gender  score  age
# 0     Bill  Wrestling    NaN     90  NaN
# 1      Tom   Football    NaN     80  NaN
# 2      Tim     Skiing    NaN     85  NaN
# 3     John   Swimming    NaN     75  NaN
# 4     Alex     Tennis    NaN     95  NaN
# 5  Vanessa     Karete    NaN     60  NaN
# 6     Kate    Surfing    NaN     65  NaN

# %%
import pandas as pd

games = pd.read_csv(r'C:\Users\dell\Desktop\img\vgsalesGlobale.csv')
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games = pd.DataFrame(games, columns=['Year', "Rank", "Genre"])
games
# Out:
#      Year  Rank    Genre
# 0    2008     1   Action
# 1    2010     2   Sports
# 2    1985     3   Sports
# 3    2016     4   Action
# 4    2020     5  Shooter
# ..    ...   ...      ...
# 995  1985   996   Sports
# 996  2011   997  Shooter
# 997  1996   998   Action
# 998  1997   999   Sports
# 999  1996  1000   Action
#
# [1000 rows x 3 columns]

# %%
games.columns = ['Year', "Rank", 'Platf']

games
# Out:
#      Year  Rank    Platf
# 0    2008     1   Action
# 1    2010     2   Sports
# 2    1985     3   Sports
# 3    2016     4   Action
# 4    2020     5  Shooter
# ..    ...   ...      ...
# 995  1985   996   Sports
# 996  2011   997  Shooter
# 997  1996   998   Action
# 998  1997   999   Sports
# 999  1996  1000   Action
#
# [1000 rows x 3 columns]

# %%
import pandas as pd

games = pd.read_csv(r'C:\Users\dell\Desktop\img\vgsalesGlobale.csv')
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games = pd.DataFrame(games, columns=["Rank", "Name", "Year"], index = range(1, 1001))
games
# Out:
#         Rank                           Name    Year
# 1        2.0                           Yams  2010.0
# 2        3.0                  Pepsi, 355 Ml  1985.0
# 3        4.0                        Gherkin  2016.0
# 4        5.0  Pastry - French Mini Assorted  2020.0
# 5        6.0  Pastry - Banana Muffin - Mini  1994.0
# ...      ...                            ...     ...
# 996    997.0     Muffin Mix - Morning Glory  2011.0
# 997    998.0       Muffin Orange Individual  1996.0
# 998    999.0                  Sage - Ground  1997.0
# 999   1000.0          Cheese - Swiss Sliced  1996.0
# 1000     NaN                            NaN     NaN
#
# [1000 rows x 3 columns]

# %%
import pandas as pd

games = pd.read_csv(r'C:\Users\dell\Desktop\img\vgsalesGlobale.csv')

games[["Rank"]]
# Out:
#      Rank
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
# ..    ...
# 995   996
# 996   997
# 997   998
# 998   999
# 999  1000
#
# [1000 rows x 1 columns]

# %%
games.loc[:, "Rank":"Rank"]
# Out:
#      Rank
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
# ..    ...
# 995   996
# 996   997
# 997   998
# 998   999
# 999  1000
#
# [1000 rows x 1 columns]

# %%
games.loc[:, ["Rank"]]
# Out:
#      Rank
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
# ..    ...
# 995   996
# 996   997
# 997   998
# 998   999
# 999  1000
#
# [1000 rows x 1 columns]

# %%
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games[["Rank", "Name"]]
# Out:
#      Rank                           Name
# 0       1  Syrup - Monin - Passion Fruit
# 1       2                           Yams
# 2       3                  Pepsi, 355 Ml
# 3       4                        Gherkin
# 4       5  Pastry - French Mini Assorted
# ..    ...                            ...
# 995   996     Shrimp - Black Tiger 16/20
# 996   997     Muffin Mix - Morning Glory
# 997   998       Muffin Orange Individual
# 998   999                  Sage - Ground
# 999  1000          Cheese - Swiss Sliced
#
# [1000 rows x 2 columns]

# %%
my_columns = ["Rank", "Name"]
games[my_columns]
# Out:
#      Rank                           Name
# 0       1  Syrup - Monin - Passion Fruit
# 1       2                           Yams
# 2       3                  Pepsi, 355 Ml
# 3       4                        Gherkin
# 4       5  Pastry - French Mini Assorted
# ..    ...                            ...
# 995   996     Shrimp - Black Tiger 16/20
# 996   997     Muffin Mix - Morning Glory
# 997   998       Muffin Orange Individual
# 998   999                  Sage - Ground
# 999  1000          Cheese - Swiss Sliced
#
# [1000 rows x 2 columns]

# %%
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.Name
# Out:
# 0      Syrup - Monin - Passion Fruit
# 1                               Yams
# 2                      Pepsi, 355 Ml
# 3                            Gherkin
# 4      Pastry - French Mini Assorted
#                    ...
# 995       Shrimp - Black Tiger 16/20
# 996       Muffin Mix - Morning Glory
# 997         Muffin Orange Individual
# 998                    Sage - Ground
# 999            Cheese - Swiss Sliced
# Name: Name, Length: 1000, dtype: object

# %%
games.loc[[0]]
# Out:
#    Rank                           Name         Platform  Year   Genre  \
# 0     1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008  Action
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0  Devshare     82.51     20.44      8.39        10.16          7.01

# %%
games.loc[[0, 5]]
# Out:
#    Rank                           Name         Platform  Year   Genre  \
# 0     1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008  Action
# 5     6  Pastry - Banana Muffin - Mini  Nintendo Switch  1994  Sports
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0  Devshare     82.51     20.44      8.39        10.16          7.01
# 5   Myworks     62.13      8.62      7.69         0.72          5.06

# %%
games.loc[0:5]
# Out:
#    Rank                           Name         Platform  Year    Genre  \
# 0     1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1     2                           Yams  Nintendo Switch  2010   Sports
# 2     3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3     4                        Gherkin         Xbox One  2016   Action
# 4     5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# 5     6  Pastry - Banana Muffin - Mini  Nintendo Switch  1994   Sports
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0  Devshare     82.51     20.44      8.39        10.16          7.01
# 1      Muxo      7.43      8.40      9.66         3.07          6.33
# 2     Eidel     17.50     17.96      7.15         4.74          5.63
# 3     Mynte     13.05      5.60      5.64         6.97          1.23
# 4     Quinu     16.92     24.00      5.59         5.16          3.66
# ...

# %%
games.iloc[[0]]
# Out:
#    Rank                           Name         Platform  Year   Genre  \
# 0     1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008  Action
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0  Devshare     82.51     20.44      8.39        10.16          7.01

# %%
games.iloc[[0, 5]]
# Out:
#    Rank                           Name         Platform  Year   Genre  \
# 0     1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008  Action
# 5     6  Pastry - Banana Muffin - Mini  Nintendo Switch  1994  Sports
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0  Devshare     82.51     20.44      8.39        10.16          7.01
# 5   Myworks     62.13      8.62      7.69         0.72          5.06

# %%
games.iloc[0:5]
# Out:
#    Rank                           Name         Platform  Year    Genre  \
# 0     1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1     2                           Yams  Nintendo Switch  2010   Sports
# 2     3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3     4                        Gherkin         Xbox One  2016   Action
# 4     5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0  Devshare     82.51     20.44      8.39        10.16          7.01
# 1      Muxo      7.43      8.40      9.66         3.07          6.33
# 2     Eidel     17.50     17.96      7.15         4.74          5.63
# 3     Mynte     13.05      5.60      5.64         6.97          1.23
# 4     Quinu     16.92     24.00      5.59         5.16          3.66

# %%
import pandas as pd

games = pd.read_csv(r'C:\Users\dell\Desktop\img\vgsalesGlobale.csv')

games = pd.DataFrame(games, columns=["Rank", "Name", "Year", 'product_id'], index = range(1, 1001))
games
# Out:
#         Rank                           Name    Year  product_id
# 1        2.0                           Yams  2010.0         NaN
# 2        3.0                  Pepsi, 355 Ml  1985.0         NaN
# 3        4.0                        Gherkin  2016.0         NaN
# 4        5.0  Pastry - French Mini Assorted  2020.0         NaN
# 5        6.0  Pastry - Banana Muffin - Mini  1994.0         NaN
# ...      ...                            ...     ...         ...
# 996    997.0     Muffin Mix - Morning Glory  2011.0         NaN
# 997    998.0       Muffin Orange Individual  1996.0         NaN
# 998    999.0                  Sage - Ground  1997.0         NaN
# 999   1000.0          Cheese - Swiss Sliced  1996.0         NaN
# 1000     NaN                            NaN     NaN         NaN
#
# [1000 rows x 4 columns]

# %%
games.product_id = 1
games
# Out:
#         Rank                           Name    Year  product_id
# 1        2.0                           Yams  2010.0           1
# 2        3.0                  Pepsi, 355 Ml  1985.0           1
# 3        4.0                        Gherkin  2016.0           1
# 4        5.0  Pastry - French Mini Assorted  2020.0           1
# 5        6.0  Pastry - Banana Muffin - Mini  1994.0           1
# ...      ...                            ...     ...         ...
# 996    997.0     Muffin Mix - Morning Glory  2011.0           1
# 997    998.0       Muffin Orange Individual  1996.0           1
# 998    999.0                  Sage - Ground  1997.0           1
# 999   1000.0          Cheese - Swiss Sliced  1996.0           1
# 1000     NaN                            NaN     NaN           1
#
# [1000 rows x 4 columns]

# %%
games.product_id = list(map(lambda x: 1 if x < 2010 else 2 if x > 2010 else 5 , games.Year ))
games
# Out:
#         Rank                           Name    Year  product_id
# 1        2.0                           Yams  2010.0           5
# 2        3.0                  Pepsi, 355 Ml  1985.0           1
# 3        4.0                        Gherkin  2016.0           2
# 4        5.0  Pastry - French Mini Assorted  2020.0           2
# 5        6.0  Pastry - Banana Muffin - Mini  1994.0           1
# ...      ...                            ...     ...         ...
# 996    997.0     Muffin Mix - Morning Glory  2011.0           2
# 997    998.0       Muffin Orange Individual  1996.0           1
# 998    999.0                  Sage - Ground  1997.0           1
# 999   1000.0          Cheese - Swiss Sliced  1996.0           1
# 1000     NaN                            NaN     NaN           5
#
# [1000 rows x 4 columns]

# %%
games
# Out:
#         Rank                           Name    Year  product_id
# 1        2.0                           Yams  2010.0           5
# 2        3.0                  Pepsi, 355 Ml  1985.0           1
# 3        4.0                        Gherkin  2016.0           2
# 4        5.0  Pastry - French Mini Assorted  2020.0           2
# 5        6.0  Pastry - Banana Muffin - Mini  1994.0           1
# ...      ...                            ...     ...         ...
# 996    997.0     Muffin Mix - Morning Glory  2011.0           2
# 997    998.0       Muffin Orange Individual  1996.0           1
# 998    999.0                  Sage - Ground  1997.0           1
# 999   1000.0          Cheese - Swiss Sliced  1996.0           1
# 1000     NaN                            NaN     NaN           5
#
# [1000 rows x 4 columns]

# %%
games["category"] = games["Year"] > 2010

games
# Out:
#         Rank                           Name    Year  product_id  category
# 1        2.0                           Yams  2010.0           5     False
# 2        3.0                  Pepsi, 355 Ml  1985.0           1     False
# 3        4.0                        Gherkin  2016.0           2      True
# 4        5.0  Pastry - French Mini Assorted  2020.0           2      True
# 5        6.0  Pastry - Banana Muffin - Mini  1994.0           1     False
# ...      ...                            ...     ...         ...       ...
# 996    997.0     Muffin Mix - Morning Glory  2011.0           2      True
# 997    998.0       Muffin Orange Individual  1996.0           1     False
# 998    999.0                  Sage - Ground  1997.0           1     False
# 999   1000.0          Cheese - Swiss Sliced  1996.0           1     False
# 1000     NaN                            NaN     NaN           5     False
#
# [1000 rows x 5 columns]

# %%
games.loc[games['category'] == True, 'category'] = 'new'
games.loc[games['category'] == False, 'category'] = 'old'

games
# Out:
#         Rank                           Name    Year  product_id category
# 1        2.0                           Yams  2010.0           5      old
# 2        3.0                  Pepsi, 355 Ml  1985.0           1      old
# 3        4.0                        Gherkin  2016.0           2      new
# 4        5.0  Pastry - French Mini Assorted  2020.0           2      new
# 5        6.0  Pastry - Banana Muffin - Mini  1994.0           1      old
# ...      ...                            ...     ...         ...      ...
# 996    997.0     Muffin Mix - Morning Glory  2011.0           2      new
# 997    998.0       Muffin Orange Individual  1996.0           1      old
# 998    999.0                  Sage - Ground  1997.0           1      old
# 999   1000.0          Cheese - Swiss Sliced  1996.0           1      old
# 1000     NaN                            NaN     NaN           5      old
#
# [1000 rows x 5 columns]

# %%
del games['category']

# %%
games
# Out:
#         Rank                           Name    Year  product_id
# 1        2.0                           Yams  2010.0           5
# 2        3.0                  Pepsi, 355 Ml  1985.0           1
# 3        4.0                        Gherkin  2016.0           2
# 4        5.0  Pastry - French Mini Assorted  2020.0           2
# 5        6.0  Pastry - Banana Muffin - Mini  1994.0           1
# ...      ...                            ...     ...         ...
# 996    997.0     Muffin Mix - Morning Glory  2011.0           2
# 997    998.0       Muffin Orange Individual  1996.0           1
# 998    999.0                  Sage - Ground  1997.0           1
# 999   1000.0          Cheese - Swiss Sliced  1996.0           1
# 1000     NaN                            NaN     NaN           5
#
# [1000 rows x 4 columns]

# %%
scores={"Math":{"A":85,"B":90,"C":95}, 
        "Physics":{"A":90,"B":80,"C":75}}

scores_df = pd.DataFrame(data=scores)

scores_df
# Out:
#    Math  Physics
# A    85       90
# B    90       80
# C    95       75

# %%
scores_df.T
# Out:
#           A   B   C
# Math     85  90  95
# Physics  90  80  75

# %%
scores_df.index.name = 'name'
scores_df.columns.name = 'lesson'

scores_df
# Out:
# lesson  Math  Physics
# name
# A         85       90
# B         90       80
# C         95       75

# %%
import pandas as pd

games = pd.read_csv(r'C:\Users\dell\Desktop\img\vgsalesGlobale.csv')

games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.T
# Out:
#                                         0                1              2    \
# Rank                                      1                2              3
# Name          Syrup - Monin - Passion Fruit             Yams  Pepsi, 355 Ml
# Platform                    Nintendo Switch  Nintendo Switch            PS4
# Year                                   2008             2010           1985
# Genre                                Action           Sports         Sports
# Publisher                          Devshare             Muxo          Eidel
# NA_Sales                              82.51             7.43           17.5
# EU_Sales                              20.44              8.4          17.96
# JP_Sales                               8.39             9.66           7.15
# Other_Sales                           10.16             3.07           4.74
# Global_Sales                           7.01             6.33           5.63
#
#                    3                              4    \
# ...

# %%
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.index.name = 'N'
games.columns.name = 'columns'

games
# Out:
# columns  Rank                           Name         Platform  Year    Genre  \
# N
# 0           1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1           2                           Yams  Nintendo Switch  2010   Sports
# 2           3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3           4                        Gherkin         Xbox One  2016   Action
# 4           5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..        ...                            ...              ...   ...      ...
# 995       996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996       997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997       998       Muffin Orange Individual              PS4  1996   Action
# 998       999                  Sage - Ground              PS4  1997   Sports
# 999      1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
# ...

# %%
games.values
# Out:
# array([[1, 'Syrup - Monin - Passion Fruit', 'Nintendo Switch', ..., 8.39,
#         10.16, 7.01],
#        [2, 'Yams', 'Nintendo Switch', ..., 9.66, 3.07, 6.33],
#        [3, 'Pepsi, 355 Ml', 'PS4', ..., 7.15, 4.74, 5.63],
#        ...,
#        [998, 'Muffin Orange Individual', 'PS4', ..., 4.02, 4.12, 0.65],
#        [999, 'Sage - Ground', 'PS4', ..., 6.2, 3.71, 0.09],
#        [1000, 'Cheese - Swiss Sliced', 'Xbox One', ..., 5.89, 2.65, 0.5]],
#       dtype=object)

# %%
games.values.shape
# Out:
# (1000, 11)

# %%
scores={"Math":{"A":85,"B":90,"C":95}, 
        "Physics":{"A":90,"B":80,"C":75}}

scores_df = pd.DataFrame(data=scores)

scores_df
# Out:
#    Math  Physics
# A    85       90
# B    90       80
# C    95       75

# %%
scores_df.index
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
scores_df.index[0]
# Out:
# 'A'

# %%
scores_df.index[0] = 'E'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[276], line 1
# ----> 1 scores_df.index[0] = 'E'
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5157, in Index.__setitem__(self, key, value)
#    5155 @final
#    5156 def __setitem__(self, key, value):
# -> 5157     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
scores_df
# Out:
#    Math  Physics
# A    85       90
# B    90       80
# C    95       75

# %%
scores_df.index = ['b', 'C', "E"]

# %%
scores_df.index
# Out:
# Index(['b', 'C', 'E'], dtype='object')

# %%
scores_df
# Out:
#    Math  Physics
# b    85       90
# C    90       80
# E    95       75

# %%
scores_df.rename(index={'b': 'A'}, inplace=True)

scores_df
# Out:
#    Math  Physics
# A    85       90
# C    90       80
# E    95       75

# %%
scores_df.rename(columns={'Math': 'History'}, inplace=True)

scores_df
# Out:
#    History  Physics
# A       85       90
# C       90       80
# E       95       75

# %%
games
# Out:
# columns  Rank                           Name         Platform  Year    Genre  \
# N
# 0           1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1           2                           Yams  Nintendo Switch  2010   Sports
# 2           3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3           4                        Gherkin         Xbox One  2016   Action
# 4           5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..        ...                            ...              ...   ...      ...
# 995       996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996       997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997       998       Muffin Orange Individual              PS4  1996   Action
# 998       999                  Sage - Ground              PS4  1997   Sports
# 999      1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
# ...

# %%
games.index
# Out:
# RangeIndex(start=0, stop=1000, step=1, name='N')

# %%
games.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object', name='columns')

# %%
games = games.rename(index={0: 1})
games = games.rename(columns={'Name': 'Company_name'})

games
# Out:
# columns  Rank                   Company_name         Platform  Year    Genre  \
# N
# 1           1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1           2                           Yams  Nintendo Switch  2010   Sports
# 2           3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3           4                        Gherkin         Xbox One  2016   Action
# 4           5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..        ...                            ...              ...   ...      ...
# 995       996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996       997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997       998       Muffin Orange Individual              PS4  1996   Action
# 998       999                  Sage - Ground              PS4  1997   Sports
# 999      1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
# ...
