# %%
import pandas as pd
import numpy as np
ser=pd.Series(data=[1,2,3,4],
            index=["a","b","c","d"])
ser
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
ser["a"]
# Out:
# 1

# %%
ser = ser.reindex(index=["c","d","a","b"])

ser
# Out:
# c    3
# d    4
# a    1
# b    2
# dtype: int64

# %%
ser = ser.reindex(index=["c","d","a","b", "g"])

ser
# Out:
# c    3.0
# d    4.0
# a    1.0
# b    2.0
# g    NaN
# dtype: float64

# %%
ser=pd.Series(["blue","yellow","purple"],
             index=[0,2,4])
ser
# Out:
# 0      blue
# 2    yellow
# 4    purple
# dtype: object

# %%
ser.reindex(index=range(6), method='ffill')
# Out:
# 0      blue
# 1      blue
# 2    yellow
# 3    yellow
# 4    purple
# 5    purple
# dtype: object

# %%
df=pd.DataFrame(data=np.arange(9).reshape(3,3),
                index=["a","c","d"],
                columns=["Tim","Tom","Kate"])
df
# Out:
#    Tim  Tom  Kate
# a    0    1     2
# c    3    4     5
# d    6    7     8

# %%
df_2 = df.reindex(index=["d","c","b","a"])

df_2
# Out:
#    Tim  Tom  Kate
# d  6.0  7.0   8.0
# c  3.0  4.0   5.0
# b  NaN  NaN   NaN
# a  0.0  1.0   2.0

# %%
names = ["Kate","Tim", 'Jane', "Tom"]
df_2.reindex(columns=names)
# Out:
#    Kate  Tim  Jane  Tom
# d   8.0  6.0   NaN  7.0
# c   5.0  3.0   NaN  4.0
# b   NaN  NaN   NaN  NaN
# a   2.0  0.0   NaN  1.0

# %%
import pandas as pd

games = pd.read_csv(r'C:\Users\dell\Desktop\img\vgsalesGlobale.csv')

games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games = games.drop(index=2)

# %%
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# 5       6  Pastry - Banana Muffin - Mini  Nintendo Switch  1994   Sports
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.reindex(range(1000))
# Out:
#        Rank                           Name         Platform    Year    Genre  \
# 0       1.0  Syrup - Monin - Passion Fruit  Nintendo Switch  2008.0   Action
# 1       2.0                           Yams  Nintendo Switch  2010.0   Sports
# 2       NaN                            NaN              NaN     NaN      NaN
# 3       4.0                        Gherkin         Xbox One  2016.0   Action
# 4       5.0  Pastry - French Mini Assorted  Nintendo Switch  2020.0  Shooter
# ..      ...                            ...              ...     ...      ...
# 995   996.0     Shrimp - Black Tiger 16/20         Xbox One  1985.0   Sports
# 996   997.0     Muffin Mix - Morning Glory         Xbox One  2011.0  Shooter
# 997   998.0       Muffin Orange Individual              PS4  1996.0   Action
# 998   999.0                  Sage - Ground              PS4  1997.0   Sports
# 999  1000.0          Cheese - Swiss Sliced         Xbox One  1996.0   Action
#
# ...

# %%
games.reindex(range(1000), method='ffill')
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       2                           Yams  Nintendo Switch  2010   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.reindex(range(1000), method='bfill')
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       4                        Gherkin         Xbox One  2016   Action
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
import pandas as pd

games = pd.read_csv(r'C:\Users\dell\Desktop\img\vgsalesGlobale.csv')

games = games.drop(index=2)

games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# 5       6  Pastry - Banana Muffin - Mini  Nintendo Switch  1994   Sports
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.loc[2] = [3, 'Muffin Orange Individua','PS4',1996, 'Action', 'Topicstorm',  19.89, 27.42, 4.02, 4.12, 0.65]

games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# 5       6  Pastry - Banana Muffin - Mini  Nintendo Switch  1994   Sports
# ..    ...                            ...              ...   ...      ...
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
# 2       3        Muffin Orange Individua              PS4  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
import pandas as pd

games = pd.read_csv(r'C:\Users\dell\Desktop\img\vgsalesGlobale.csv')

games = games.drop(index=2)

games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# 5       6  Pastry - Banana Muffin - Mini  Nintendo Switch  1994   Sports
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games = games.reindex(range(len(games)+1), fill_value=0)

games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       0                              0                0     0        0
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.loc[2] = [3, 'Muffin Orange Individua','PS4',1996, 'Action', 'Topicstorm',  19.89, 27.42, 4.02, 4.12, 0.65]

games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3        Muffin Orange Individua              PS4  1996   Action
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
ser=pd.Series(np.arange(5.),
            index=["a","b","c","d","e"])
ser
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
ser.drop('b')
# Out:
# a    0.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
ser.drop(['a', 'b'])
# Out:
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
df=pd.DataFrame(data=np.arange(16).reshape(4,4),
                  index=["Kate","Tim",
                         "Tom","Alex"],
                  columns=list("ABCD"))
df
# Out:
#        A   B   C   D
# Kate   0   1   2   3
# Tim    4   5   6   7
# Tom    8   9  10  11
# Alex  12  13  14  15

# %%
df.drop(index = "Kate")
# Out:
#        A   B   C   D
# Tim    4   5   6   7
# Tom    8   9  10  11
# Alex  12  13  14  15

# %%
df.drop("Kate")
# Out:
#        A   B   C   D
# Tim    4   5   6   7
# Tom    8   9  10  11
# Alex  12  13  14  15

# %%
import pandas as pd

games = pd.read_csv(r'C:\Users\dell\Desktop\img\vgsalesGlobale.csv')

games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.drop(index=0)
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# 5       6  Pastry - Banana Muffin - Mini  Nintendo Switch  1994   Sports
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.drop(index=0, axis=0)
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# 5       6  Pastry - Banana Muffin - Mini  Nintendo Switch  1994   Sports
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.drop(0)
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# 5       6  Pastry - Banana Muffin - Mini  Nintendo Switch  1994   Sports
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.drop([0, 5])
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# 6       7    Nantucket Pine Orangebanana         Xbox One  2017   Action
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.drop('Name', axis=1)
# Out:
#      Rank         Platform  Year    Genre   Publisher  NA_Sales  EU_Sales  \
# 0       1  Nintendo Switch  2008   Action    Devshare     82.51     20.44
# 1       2  Nintendo Switch  2010   Sports        Muxo      7.43      8.40
# 2       3              PS4  1985   Sports       Eidel     17.50     17.96
# 3       4         Xbox One  2016   Action       Mynte     13.05      5.60
# 4       5  Nintendo Switch  2020  Shooter       Quinu     16.92     24.00
# ..    ...              ...   ...      ...         ...       ...       ...
# 995   996         Xbox One  1985   Sports    Edgewire     77.09      3.36
# 996   997         Xbox One  2011  Shooter       Skyba      5.14      8.72
# 997   998              PS4  1996   Action  Topicstorm     19.89     27.42
# 998   999              PS4  1997   Sports  Jabbertype     38.59      7.22
# 999  1000         Xbox One  1996   Action      Voonyx     58.61     21.83
#
#      JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.drop(columns='Name')
# Out:
#      Rank         Platform  Year    Genre   Publisher  NA_Sales  EU_Sales  \
# 0       1  Nintendo Switch  2008   Action    Devshare     82.51     20.44
# 1       2  Nintendo Switch  2010   Sports        Muxo      7.43      8.40
# 2       3              PS4  1985   Sports       Eidel     17.50     17.96
# 3       4         Xbox One  2016   Action       Mynte     13.05      5.60
# 4       5  Nintendo Switch  2020  Shooter       Quinu     16.92     24.00
# ..    ...              ...   ...      ...         ...       ...       ...
# 995   996         Xbox One  1985   Sports    Edgewire     77.09      3.36
# 996   997         Xbox One  2011  Shooter       Skyba      5.14      8.72
# 997   998              PS4  1996   Action  Topicstorm     19.89     27.42
# 998   999              PS4  1997   Sports  Jabbertype     38.59      7.22
# 999  1000         Xbox One  1996   Action      Voonyx     58.61     21.83
#
#      JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.drop(columns = ["Year", 'Name'])
# Out:
#      Rank         Platform    Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0       1  Nintendo Switch   Action    Devshare     82.51     20.44      8.39
# 1       2  Nintendo Switch   Sports        Muxo      7.43      8.40      9.66
# 2       3              PS4   Sports       Eidel     17.50     17.96      7.15
# 3       4         Xbox One   Action       Mynte     13.05      5.60      5.64
# 4       5  Nintendo Switch  Shooter       Quinu     16.92     24.00      5.59
# ..    ...              ...      ...         ...       ...       ...       ...
# 995   996         Xbox One   Sports    Edgewire     77.09      3.36      0.69
# 996   997         Xbox One  Shooter       Skyba      5.14      8.72      4.02
# 997   998              PS4   Action  Topicstorm     19.89     27.42      4.02
# 998   999              PS4   Sports  Jabbertype     38.59      7.22      6.20
# 999  1000         Xbox One   Action      Voonyx     58.61     21.83      5.89
#
#      Other_Sales  Global_Sales
# ...

# %%
games.drop(columns = games.loc[:, ["Year", 'Name']])
# Out:
#      Rank         Platform    Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0       1  Nintendo Switch   Action    Devshare     82.51     20.44      8.39
# 1       2  Nintendo Switch   Sports        Muxo      7.43      8.40      9.66
# 2       3              PS4   Sports       Eidel     17.50     17.96      7.15
# 3       4         Xbox One   Action       Mynte     13.05      5.60      5.64
# 4       5  Nintendo Switch  Shooter       Quinu     16.92     24.00      5.59
# ..    ...              ...      ...         ...       ...       ...       ...
# 995   996         Xbox One   Sports    Edgewire     77.09      3.36      0.69
# 996   997         Xbox One  Shooter       Skyba      5.14      8.72      4.02
# 997   998              PS4   Action  Topicstorm     19.89     27.42      4.02
# 998   999              PS4   Sports  Jabbertype     38.59      7.22      6.20
# 999  1000         Xbox One   Action      Voonyx     58.61     21.83      5.89
#
#      Other_Sales  Global_Sales
# ...

# %%
games.drop(index=[0:5], columns = ["Name", "Year"])
# Out:
#   Cell In[131], line 1
#     games.drop(index=[0:5], columns = ["Name", "Year"])
#                        ^
# SyntaxError: invalid syntax

# %%
games.drop(index = games.index[0:5], columns=["Name", "Year"])
# Out:
#      Rank         Platform    Genre      Publisher  NA_Sales  EU_Sales  \
# 5       6  Nintendo Switch   Sports        Myworks     62.13      8.62
# 6       7         Xbox One   Action        Gabcube     39.17      9.58
# 7       8              PS4   Action      Gigashots     47.41     22.16
# 8       9              PS4   Sports        Myworks     23.07      2.96
# 9      10  Nintendo Switch   Action  Chatterbridge     38.89     26.25
# ..    ...              ...      ...            ...       ...       ...
# 995   996         Xbox One   Sports       Edgewire     77.09      3.36
# 996   997         Xbox One  Shooter          Skyba      5.14      8.72
# 997   998              PS4   Action     Topicstorm     19.89     27.42
# 998   999              PS4   Sports     Jabbertype     38.59      7.22
# 999  1000         Xbox One   Action         Voonyx     58.61     21.83
#
#      JP_Sales  Other_Sales  Global_Sales
# 5        7.69         0.72          5.06
# ...

# %%
games.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
games.index[0:5]
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games["Name"] == 'Yams'
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Name, Length: 1000, dtype: bool

# %%
games[games["Name"] == 'Yams']
# Out:
#      Rank  Name         Platform  Year   Genre Publisher  NA_Sales  EU_Sales  \
# 1       2  Yams  Nintendo Switch  2010  Sports      Muxo      7.43      8.40
# 765   766  Yams         Xbox One  2021  Action    Voonix     34.92     15.81
#
#      JP_Sales  Other_Sales  Global_Sales
# 1        9.66         3.07          6.33
# 765      0.71         7.41          5.38

# %%
games[games["Name"] == 'Yams'].index
# Out:
# Index([1, 765], dtype='int64')

# %%
games.drop(index=games[games["Name"] == 'Yams'].index)
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# 5       6  Pastry - Banana Muffin - Mini  Nintendo Switch  1994   Sports
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.loc[games.loc[:, "Name"] == 'Yams', :].index
# Out:
# Index([1, 765], dtype='int64')

# %%
games[(games["Name"] == 'Yams') | (games["Year"] == 2008)].index
# Out:
# Index([  0,   1,  33,  75,  78, 145, 175, 176, 199, 205, 293, 303, 327, 349,
#        355, 456, 462, 468, 514, 566, 622, 657, 666, 732, 765, 783, 836, 855,
#        857, 866, 925, 953, 989],
#       dtype='int64')

# %%
games.drop(index = games[(games["Name"] == 'Yams') | (games["Year"] == 2008)].index)
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# 5       6  Pastry - Banana Muffin - Mini  Nintendo Switch  1994   Sports
# 6       7    Nantucket Pine Orangebanana         Xbox One  2017   Action
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
midx = pd.MultiIndex(levels=[['llama', 'cow', 'falcon'],
                             ['speed', 'weight', 'length']],
                     codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2],
                            [0, 1, 2, 0, 1, 2, 0, 1, 2]])
df = pd.DataFrame(index=midx, columns=['big', 'small'],
                  data=[[45, 30], [200, 100], [1.5, 1], [30, 20],
                        [250, 150], [1.5, 0.8], [320, 250],
                        [1, 0.8], [0.3, 0.2]])
df
# Out:
#                  big  small
# llama  speed    45.0   30.0
#        weight  200.0  100.0
#        length    1.5    1.0
# cow    speed    30.0   20.0
#        weight  250.0  150.0
#        length    1.5    0.8
# falcon speed   320.0  250.0
#        weight    1.0    0.8
#        length    0.3    0.2

# %%
df.drop(index='length', level=1)
# Out:
#                  big  small
# llama  speed    45.0   30.0
#        weight  200.0  100.0
# cow    speed    30.0   20.0
#        weight  250.0  150.0
# falcon speed   320.0  250.0
#        weight    1.0    0.8

# %%
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.loc[:, "NA_Sales"].mean()
# Out:
# 41.32511

# %%
games.loc[:, ["NA_Sales", 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].mean()
# Out:
# NA_Sales        41.32511
# EU_Sales        14.14252
# JP_Sales         5.07435
# Other_Sales      5.36047
# Global_Sales     5.34844
# dtype: float64

# %%
games.loc[:, ["NA_Sales", 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].mean(axis=0)
# Out:
# NA_Sales        41.32511
# EU_Sales        14.14252
# JP_Sales         5.07435
# Other_Sales      5.36047
# Global_Sales     5.34844
# dtype: float64

# %%
games.loc[:, ["NA_Sales", 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].mean(axis='index')
# Out:
# NA_Sales        41.32511
# EU_Sales        14.14252
# JP_Sales         5.07435
# Other_Sales      5.36047
# Global_Sales     5.34844
# dtype: float64

# %%
games.loc[:, ["NA_Sales", 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].mean(axis=1)
# Out:
# 0      25.702
# 1       6.978
# 2      10.596
# 3       6.498
# 4      11.066
#         ...
# 995    18.362
# 996     6.700
# 997    11.220
# 998    11.162
# 999    17.896
# Length: 1000, dtype: float64

# %%
games.loc[:, ["NA_Sales", 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].mean(axis='columns')
# Out:
# 0      25.702
# 1       6.978
# 2      10.596
# 3       6.498
# 4      11.066
#         ...
# 995    18.362
# 996     6.700
# 997    11.220
# 998    11.162
# 999    17.896
# Length: 1000, dtype: float64

# %%
np.array([82.51, 20.44, 8.39, 10.16, 7.01]).mean()
# Out:
# 25.701999999999998
