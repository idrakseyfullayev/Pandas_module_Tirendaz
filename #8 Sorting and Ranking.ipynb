# %%
import pandas as pd; import numpy as np

# %%
ser=pd.Series(range(5),
            index=["e","d","a","b","c"])
ser
# Out:
# e    0
# d    1
# a    2
# b    3
# c    4
# dtype: int64

# %%
ser.sort_index()
# Out:
# a    2
# b    3
# c    4
# d    1
# e    0
# dtype: int64

# %%
ser.sort_values()
# Out:
# e    0
# d    1
# a    2
# b    3
# c    4
# dtype: int64

# %%
df=pd.DataFrame(
    np.arange(12).reshape(3,4),
    index=["two","one","three"],
    columns=["d","a","b","c"])
df
# Out:
#        d  a   b   c
# two    0  1   2   3
# one    4  5   6   7
# three  8  9  10  11

# %%
df.sort_index()
# Out:
#        d  a   b   c
# one    4  5   6   7
# three  8  9  10  11
# two    0  1   2   3

# %%
df.index
# Out:
# Index(['two', 'one', 'three'], dtype='object')

# %%
df.columns
# Out:
# Index(['d', 'a', 'b', 'c'], dtype='object')

# %%
df.sort_index(axis=1)
# Out:
#        a   b   c  d
# two    1   2   3  0
# one    5   6   7  4
# three  9  10  11  8

# %%
df.sort_index(ascending=False)
# Out:
#        d  a   b   c
# two    0  1   2   3
# three  8  9  10  11
# one    4  5   6   7

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#        d   c   b  a
# two    0   3   2  1
# one    4   7   6  5
# three  8  11  10  9

# %%
ser2=pd.Series([5,np.nan,3,-1,9])
ser2
# Out:
# 0    5.0
# 1    NaN
# 2    3.0
# 3   -1.0
# 4    9.0
# dtype: float64

# %%
ser2.sort_values()
# Out:
# 3   -1.0
# 2    3.0
# 0    5.0
# 4    9.0
# 1    NaN
# dtype: float64

# %%
ser2.sort_values(ascending=False)
# Out:
# 4    9.0
# 0    5.0
# 2    3.0
# 3   -1.0
# 1    NaN
# dtype: float64

# %%
df2=pd.DataFrame(
    {"a":[5,3,-1,9]})
df2
# Out:
#    a
# 0  5
# 1  3
# 2 -1
# 3  9

# %%
df2.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df2.sort_values()
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
df2=pd.DataFrame(
    {"a":[5,3,-1,9],"b":[1,-2,0,5]})
df2
# Out:
#    a  b
# 0  5  1
# 1  3 -2
# 2 -1  0
# 3  9  5

# %%
df2.sort_values(by="a")
# Out:
#    a  b
# 2 -1  0
# 1  3 -2
# 0  5  1
# 3  9  5

# %%
df2.sort_values(by="b")
# Out:
#    a  b
# 1  3 -2
# 2 -1  0
# 0  5  1
# 3  9  5

# %%
df2.sort_values(by=["b", "a"])
# Out:
#    a  b
# 1  3 -2
# 2 -1  0
# 0  5  1
# 3  9  5

# %%
import pandas as pd

games = pd.read_csv(r'C:\Users\dell\Desktop\img\vgsalesGlobale.csv')

games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.Name.sort_index()
# Out:
# 0      Syrup - Monin - Passion Fruit
# 1                               Yams
# 2                      Pepsi, 355 Ml
# 3                            Gherkin
# 4      Pastry - French Mini Assorted
#                    ...
# 995       Shrimp - Black Tiger 16/20
# 996       Muffin Mix - Morning Glory
# 997         Muffin Orange Individual
# 998                    Sage - Ground
# 999            Cheese - Swiss Sliced
# Name: Name, Length: 1000, dtype: object

# %%
games.Name.sort_values()
# Out:
# 907                     Alize Sunset
# 590                  Anchovy Fillets
# 516                  Anchovy Fillets
# 55     Appetizer - Asian Shrimp Roll
# 782    Appetizer - Asian Shrimp Roll
#                    ...
# 441          Yogurt - French Vanilla
# 906                   Yogurt - Plain
# 512                            Yucca
# 236                       Yukon Jack
# 274           Zucchini - Mini, Green
# Name: Name, Length: 1000, dtype: object

# %%
games["Name"].sort_values()
# Out:
# 907                     Alize Sunset
# 590                  Anchovy Fillets
# 516                  Anchovy Fillets
# 55     Appetizer - Asian Shrimp Roll
# 782    Appetizer - Asian Shrimp Roll
#                    ...
# 441          Yogurt - French Vanilla
# 906                   Yogurt - Plain
# 512                            Yucca
# 236                       Yukon Jack
# 274           Zucchini - Mini, Green
# Name: Name, Length: 1000, dtype: object

# %%
games[["Name"]].sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 games[["Name"]].sort_values()
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
games[["Name"]].sort_values(by="Name")
# Out:
#                               Name
# 907                   Alize Sunset
# 590                Anchovy Fillets
# 516                Anchovy Fillets
# 55   Appetizer - Asian Shrimp Roll
# 782  Appetizer - Asian Shrimp Roll
# ..                             ...
# 441        Yogurt - French Vanilla
# 906                 Yogurt - Plain
# 512                          Yucca
# 236                     Yukon Jack
# 274         Zucchini - Mini, Green
#
# [1000 rows x 1 columns]

# %%
games[["Name"]].sort_values(by="Name", ascending=False)
# Out:
#                               Name
# 274         Zucchini - Mini, Green
# 236                     Yukon Jack
# 512                          Yucca
# 906                 Yogurt - Plain
# 441        Yogurt - French Vanilla
# ..                             ...
# 782  Appetizer - Asian Shrimp Roll
# 55   Appetizer - Asian Shrimp Roll
# 590                Anchovy Fillets
# 516                Anchovy Fillets
# 907                   Alize Sunset
#
# [1000 rows x 1 columns]

# %%
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.sort_values("Year")
# Out:
#      Rank                         Name         Platform  Year    Genre  \
# 952   953   Wine - Sogrape Mateus Rose         Xbox One  1980   Action
# 784   785             Chicken - Livers              PS4  1980   Action
# 743   744              Steampan - Foil              PS4  1980  Shooter
# 244   245      V8 - Vegetable Cocktail         Xbox One  1980   Sports
# 585   586  Pasta - Rotini, Colour, Dry              PS4  1980   Action
# ..    ...                          ...              ...   ...      ...
# 869   870         Bread Base - Toscano         Xbox One  2022   Action
# 371   372   Curry Paste - Green Masala              PS4  2022   Sports
# 817   818                      Tumeric         Xbox One  2022  Shooter
# 190   191   Wine - Gato Negro Cabernet         Xbox One  2022  Shooter
# 445   446             Pears - Bartlett  Nintendo Switch  2022   Action
#
#      Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.sort_values(["Year", "Genre"])
# Out:
#      Rank                          Name         Platform  Year   Genre  \
# 170   171            Asparagus - Frozen         Xbox One  1980  Action
# 279   280  Wine - Puligny Montrachet A.  Nintendo Switch  1980  Action
# 585   586   Pasta - Rotini, Colour, Dry              PS4  1980  Action
# 619   620             Beans - Navy, Dry  Nintendo Switch  1980  Action
# 784   785              Chicken - Livers              PS4  1980  Action
# ..    ...                           ...              ...   ...     ...
# 12     13           Stock - Beef, Brown         Xbox One  2022  Sports
# 85     86    Pie Box - Cello Window 2.5              PS4  2022  Sports
# 371   372    Curry Paste - Green Masala              PS4  2022  Sports
# 671   672        Horseradish - Prepared  Nintendo Switch  2022  Sports
# 712   713     Pineapple - Canned, Rings         Xbox One  2022  Sports
#
#        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.sort_values(["Year", "Genre"], ascending=False)
# Out:
#      Rank                             Name         Platform  Year   Genre  \
# 12     13              Stock - Beef, Brown         Xbox One  2022  Sports
# 85     86       Pie Box - Cello Window 2.5              PS4  2022  Sports
# 371   372       Curry Paste - Green Masala              PS4  2022  Sports
# 671   672           Horseradish - Prepared  Nintendo Switch  2022  Sports
# 712   713        Pineapple - Canned, Rings         Xbox One  2022  Sports
# ..    ...                              ...              ...   ...     ...
# 585   586      Pasta - Rotini, Colour, Dry              PS4  1980  Action
# 619   620                Beans - Navy, Dry  Nintendo Switch  1980  Action
# 784   785                 Chicken - Livers              PS4  1980  Action
# 795   796  Ice - Clear, 300 Lb For Carving              PS4  1980  Action
# 952   953       Wine - Sogrape Mateus Rose         Xbox One  1980  Action
#
#        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.sort_values(["Year", "Genre"], ascending=[True, False])[games['Year']==1980]
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6340\1527179548.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   games.sort_values(["Year", "Genre"], ascending=[True, False])[games['Year']==1980]
#      Rank                             Name         Platform  Year    Genre  \
# 244   245          V8 - Vegetable Cocktail         Xbox One  1980   Sports
# 553   554       Nori Sea Weed - Gold Label  Nintendo Switch  1980   Sports
# 761   762                           V8 Pet         Xbox One  1980   Sports
# 90     91   Pasta - Lasagna Noodle, Frozen         Xbox One  1980  Shooter
# 117   118             Rum - Cream, Amarula  Nintendo Switch  1980  Shooter
# 196   197    Wine - Hardys Bankside Shiraz         Xbox One  1980  Shooter
# 433   434                 Rabbit - Saddles         Xbox One  1980  Shooter
# 743   744                  Steampan - Foil              PS4  1980  Shooter
# ...

# %%
games.sort_values(["Year", "Genre"], ascending=[True, False]).loc[games['Year']==1980]
# Out:
#      Rank                             Name         Platform  Year    Genre  \
# 244   245          V8 - Vegetable Cocktail         Xbox One  1980   Sports
# 553   554       Nori Sea Weed - Gold Label  Nintendo Switch  1980   Sports
# 761   762                           V8 Pet         Xbox One  1980   Sports
# 90     91   Pasta - Lasagna Noodle, Frozen         Xbox One  1980  Shooter
# 117   118             Rum - Cream, Amarula  Nintendo Switch  1980  Shooter
# 196   197    Wine - Hardys Bankside Shiraz         Xbox One  1980  Shooter
# 433   434                 Rabbit - Saddles         Xbox One  1980  Shooter
# 743   744                  Steampan - Foil              PS4  1980  Shooter
# 170   171               Asparagus - Frozen         Xbox One  1980   Action
# 279   280     Wine - Puligny Montrachet A.  Nintendo Switch  1980   Action
# 585   586      Pasta - Rotini, Colour, Dry              PS4  1980   Action
# ...

# %%
games.sort_values(["Year", "Genre"], ascending=[True, True]).loc[games['Year']==1980]
# Out:
#      Rank                             Name         Platform  Year    Genre  \
# 170   171               Asparagus - Frozen         Xbox One  1980   Action
# 279   280     Wine - Puligny Montrachet A.  Nintendo Switch  1980   Action
# 585   586      Pasta - Rotini, Colour, Dry              PS4  1980   Action
# 619   620                Beans - Navy, Dry  Nintendo Switch  1980   Action
# 784   785                 Chicken - Livers              PS4  1980   Action
# 795   796  Ice - Clear, 300 Lb For Carving              PS4  1980   Action
# 952   953       Wine - Sogrape Mateus Rose         Xbox One  1980   Action
# 90     91   Pasta - Lasagna Noodle, Frozen         Xbox One  1980  Shooter
# 117   118             Rum - Cream, Amarula  Nintendo Switch  1980  Shooter
# 196   197    Wine - Hardys Bankside Shiraz         Xbox One  1980  Shooter
# 433   434                 Rabbit - Saddles         Xbox One  1980  Shooter
# ...

# %%
games[games['Year']==1980].sort_values(["Year", "Genre"], ascending=[True, True])
# Out:
#      Rank                             Name         Platform  Year    Genre  \
# 170   171               Asparagus - Frozen         Xbox One  1980   Action
# 279   280     Wine - Puligny Montrachet A.  Nintendo Switch  1980   Action
# 585   586      Pasta - Rotini, Colour, Dry              PS4  1980   Action
# 619   620                Beans - Navy, Dry  Nintendo Switch  1980   Action
# 784   785                 Chicken - Livers              PS4  1980   Action
# 795   796  Ice - Clear, 300 Lb For Carving              PS4  1980   Action
# 952   953       Wine - Sogrape Mateus Rose         Xbox One  1980   Action
# 90     91   Pasta - Lasagna Noodle, Frozen         Xbox One  1980  Shooter
# 117   118             Rum - Cream, Amarula  Nintendo Switch  1980  Shooter
# 196   197    Wine - Hardys Bankside Shiraz         Xbox One  1980  Shooter
# 433   434                 Rabbit - Saddles         Xbox One  1980  Shooter
# ...
