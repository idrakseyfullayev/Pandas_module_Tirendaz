# %%
import pandas as pd; import numpy as np

# %%
df=pd.DataFrame(
    [[2.4,np.nan],[6.3,-5.4],
     [np.nan,np.nan],[0.75,-1.3]],
    index=["a","b","c","d"],
    columns=["one","two"])
df
# Out:
#     one  two
# a  2.40  NaN
# b  6.30 -5.4
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.sum()
# Out:
# one    9.45
# two   -6.70
# dtype: float64

# %%
pd.DataFrame(df.sum())
# Out:
#         0
# one  9.45
# two -6.70

# %%
df.sum(axis=1)
# Out:
# a    2.40
# b    0.90
# c    0.00
# d   -0.55
# dtype: float64

# %%
df.mean()
# Out:
# one    3.15
# two   -3.35
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# a    2.400
# b    0.450
# c      NaN
# d   -0.275
# dtype: float64

# %%
df
# Out:
#     one  two
# a  2.40  NaN
# b  6.30 -5.4
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.mean(axis=0, skipna=False)
# Out:
# one   NaN
# two   NaN
# dtype: float64

# %%
df.mean(axis=1, skipna=False)
# Out:
# a      NaN
# b    0.450
# c      NaN
# d   -0.275
# dtype: float64

# %%
df
# Out:
#     one  two
# a  2.40  NaN
# b  6.30 -5.4
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.idxmax()
# Out:
# one    b
# two    d
# dtype: object

# %%
df.idxmin()
# Out:
# one    d
# two    b
# dtype: object

# %%
df
# Out:
#     one  two
# a  2.40  NaN
# b  6.30 -5.4
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.cumsum()
# Out:
#     one  two
# a  2.40  NaN
# b  8.70 -5.4
# c   NaN  NaN
# d  9.45 -6.7

# %%
df.cumsum(axis=1)
# Out:
#     one   two
# a  2.40   NaN
# b  6.30  0.90
# c   NaN   NaN
# d  0.75 -0.55

# %%
df.describe()
# Out:
#          one       two
# count  3.000  2.000000
# mean   3.150 -3.350000
# std    2.850  2.899138
# min    0.750 -5.400000
# 25%    1.575 -4.375000
# 50%    2.400 -3.350000
# 75%    4.350 -2.325000
# max    6.300 -1.300000

# %%
import pandas as pd

iris = pd.read_csv(r'C:\Users\dell\Desktop\img\iris.csv')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species  id  \
# 0           7.2          2.8           2.2          0.3  versicolor   1
# 1           6.0          2.9           3.0          2.3  versicolor   2
# 2           6.5          3.4           1.0          1.1   virginica   3
# 3           6.5          3.1           5.5          1.8  versicolor   4
# 4           6.1          2.4           2.7          0.3   virginica   5
#
#    color        date   time  temperature
# 0  green   6/24/2022  17.83         35.3
# 1   blue  12/18/2021  10.01         -8.1
# 2   blue   1/29/2020   2.76        -40.0
# 3    red   1/25/2022   6.21        -24.3
# 4  green   12/6/2022  17.59         21.8

# %%
np.corrcoef(iris["sepal_length"], iris["sepal_width"])
# Out:
# array([[ 1.        , -0.04020441],
#        [-0.04020441,  1.        ]])

# %%
iris["sepal_length"].corr(iris["sepal_width"])
# Out:
# -0.040204407975702024

# %%
iris.iloc[:, 0:4].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.040204      0.028092     0.016639
# sepal_width      -0.040204     1.000000      0.011579    -0.012173
# petal_length      0.028092     0.011579      1.000000     0.034720
# petal_width       0.016639    -0.012173      0.034720     1.000000

# %%
iris.iloc[:, 0:4].corrwith(iris.sepal_length)
# Out:
# sepal_length    1.000000
# sepal_width    -0.040204
# petal_length    0.028092
# petal_width     0.016639
# dtype: float64

# %%
iris.iloc[:, 0:4].cov()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.067559    -0.028703      0.049826     0.011821
# sepal_width      -0.028703     0.477449      0.013734    -0.005783
# petal_length      0.049826     0.013734      2.946743     0.040980
# petal_width       0.011821    -0.005783      0.040980     0.472767

# %%
iris["sepal_length"].cov(iris["sepal_width"])
# Out:
# -0.028703383383383393

# %%
iris["sepal_length"].corr(iris["sepal_width"])
# Out:
# -0.040204407975702024

# %%
ser=pd.Series(["b","b","b","b","c",
             "c","a","a","a"])
ser
# Out:
# 0    b
# 1    b
# 2    b
# 3    b
# 4    c
# 5    c
# 6    a
# 7    a
# 8    a
# dtype: object

# %%
ser.unique()
# Out:
# array(['b', 'c', 'a'], dtype=object)

# %%
ser.value_counts()
# Out:
# b    4
# a    3
# c    2
# Name: count, dtype: int64

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species    id  \
# 0             7.2          2.8           2.2          0.3  versicolor     1
# 1             6.0          2.9           3.0          2.3  versicolor     2
# 2             6.5          3.4           1.0          1.1   virginica     3
# 3             6.5          3.1           5.5          1.8  versicolor     4
# 4             6.1          2.4           2.7          0.3   virginica     5
# ..            ...          ...           ...          ...         ...   ...
# 995           5.3          4.0           6.5          2.1   virginica   996
# 996           5.7          3.3           2.2          1.3   virginica   997
# 997           7.5          3.5           2.1          2.1  versicolor   998
# 998           5.3          2.7           5.0          0.4      setosa   999
# 999           5.7          3.8           1.9          1.7  versicolor  1000
#
#      color        date   time  temperature
# ...

# %%
iris.color.unique()
# Out:
# array(['green', 'blue', 'red'], dtype=object)

# %%
iris.color.value_counts()
# Out:
# color
# blue     358
# green    334
# red      308
# Name: count, dtype: int64

# %%
iris.color.count()
# Out:
# 1000

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species    id  \
# 0             7.2          2.8           2.2          0.3  versicolor     1
# 1             6.0          2.9           3.0          2.3  versicolor     2
# 2             6.5          3.4           1.0          1.1   virginica     3
# 3             6.5          3.1           5.5          1.8  versicolor     4
# 4             6.1          2.4           2.7          0.3   virginica     5
# ..            ...          ...           ...          ...         ...   ...
# 995           5.3          4.0           6.5          2.1   virginica   996
# 996           5.7          3.3           2.2          1.3   virginica   997
# 997           7.5          3.5           2.1          2.1  versicolor   998
# 998           5.3          2.7           5.0          0.4      setosa   999
# 999           5.7          3.8           1.9          1.7  versicolor  1000
#
#      color        date   time  temperature
# ...

# %%
gr = iris.color.isin(['green'])
gr
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996     True
# 997    False
# 998     True
# 999     True
# Name: color, Length: 1000, dtype: bool

# %%
iris[gr]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species    id  \
# 0             7.2          2.8           2.2          0.3  versicolor     1
# 4             6.1          2.4           2.7          0.3   virginica     5
# 5             6.1          2.9           5.3          1.4  versicolor     6
# 7             5.6          3.0           5.1          1.6   virginica     8
# 8             5.6          4.0           6.2          2.2      setosa     9
# ..            ...          ...           ...          ...         ...   ...
# 992           7.9          3.0           5.0          1.6      setosa   993
# 993           6.0          2.2           4.0          0.8  versicolor   994
# 996           5.7          3.3           2.2          1.3   virginica   997
# 998           5.3          2.7           5.0          0.4      setosa   999
# 999           5.7          3.8           1.9          1.7  versicolor  1000
#
#      color        date   time  temperature
# ...

# %%
iris[gr][['id', "color"]]
# Out:
#        id  color
# 0       1  green
# 4       5  green
# 5       6  green
# 7       8  green
# 8       9  green
# ..    ...    ...
# 992   993  green
# 993   994  green
# 996   997  green
# 998   999  green
# 999  1000  green
#
# [334 rows x 2 columns]

# %%
iris.loc[gr, ['id', "color"]]
# Out:
#        id  color
# 0       1  green
# 4       5  green
# 5       6  green
# 7       8  green
# 8       9  green
# ..    ...    ...
# 992   993  green
# 993   994  green
# 996   997  green
# 998   999  green
# 999  1000  green
#
# [334 rows x 2 columns]

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species    id  \
# 0             7.2          2.8           2.2          0.3  versicolor     1
# 1             6.0          2.9           3.0          2.3  versicolor     2
# 2             6.5          3.4           1.0          1.1   virginica     3
# 3             6.5          3.1           5.5          1.8  versicolor     4
# 4             6.1          2.4           2.7          0.3   virginica     5
# ..            ...          ...           ...          ...         ...   ...
# 995           5.3          4.0           6.5          2.1   virginica   996
# 996           5.7          3.3           2.2          1.3   virginica   997
# 997           7.5          3.5           2.1          2.1  versicolor   998
# 998           5.3          2.7           5.0          0.4      setosa   999
# 999           5.7          3.8           1.9          1.7  versicolor  1000
#
#      color        date   time  temperature
# ...

# %%
num_7_2 = iris["sepal_length"].isin([7.2])
num_7_2
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: sepal_length, Length: 1000, dtype: bool

# %%
iris.loc[num_7_2]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species   id  \
# 0             7.2          2.8           2.2          0.3  versicolor    1
# 49            7.2          3.5           3.9          0.2   virginica   50
# 82            7.2          3.2           3.7          2.0   virginica   83
# 109           7.2          3.8           3.2          2.3      setosa  110
# 146           7.2          4.3           3.2          1.2  versicolor  147
# 170           7.2          2.1           4.3          2.3  versicolor  171
# 241           7.2          2.4           1.5          1.0  versicolor  242
# 243           7.2          2.1           5.2          1.1  versicolor  244
# 368           7.2          2.6           6.8          0.2   virginica  369
# 437           7.2          3.3           5.9          2.2      setosa  438
# 447           7.2          2.3           4.2          0.9      setosa  448
# ...

# %%
iris.loc[num_7_2, ['sepal_length', 'id', 'color']]
# Out:
#      sepal_length   id  color
# 0             7.2    1  green
# 49            7.2   50   blue
# 82            7.2   83    red
# 109           7.2  110    red
# 146           7.2  147  green
# 170           7.2  171   blue
# 241           7.2  242  green
# 243           7.2  244   blue
# 368           7.2  369  green
# 437           7.2  438    red
# 447           7.2  448    red
# 465           7.2  466   blue
# 501           7.2  502    red
# 524           7.2  525  green
# 533           7.2  534   blue
# 545           7.2  546   blue
# 563           7.2  564  green
# 611           7.2  612  green
# 612           7.2  613   blue
# 619           7.2  620   blue
# 660           7.2  661    red
# 683           7.2  684  green
# 694           7.2  695  green
# 701           7.2  702  green
# 733           7.2  734   blue
# 814           7.2  815  green
# 846           7.2  847   blue
# 847           7.2  848    red
# 863           7.2  864  green
# 898           7.2  899    red
# ...

# %%
iris.loc[iris.sepal_length==7.2, ['sepal_length', 'id', 'color']]
# Out:
#      sepal_length   id  color
# 0             7.2    1  green
# 49            7.2   50   blue
# 82            7.2   83    red
# 109           7.2  110    red
# 146           7.2  147  green
# 170           7.2  171   blue
# 241           7.2  242  green
# 243           7.2  244   blue
# 368           7.2  369  green
# 437           7.2  438    red
# 447           7.2  448    red
# 465           7.2  466   blue
# 501           7.2  502    red
# 524           7.2  525  green
# 533           7.2  534   blue
# 545           7.2  546   blue
# 563           7.2  564  green
# 611           7.2  612  green
# 612           7.2  613   blue
# 619           7.2  620   blue
# 660           7.2  661    red
# 683           7.2  684  green
# 694           7.2  695  green
# 701           7.2  702  green
# 733           7.2  734   blue
# 814           7.2  815  green
# 846           7.2  847   blue
# 847           7.2  848    red
# 863           7.2  864  green
# 898           7.2  899    red
# ...

# %%
iris.loc[iris.sepal_length==7.2, ['sepal_length', 'id', 'color']].value_counts('color')
# Out:
# color
# blue     12
# green    12
# red       8
# Name: count, dtype: int64

# %%
iris.loc[iris.sepal_length==7.2, ['sepal_length', 'id', 'color']].color.value_counts()
# Out:
# color
# green    12
# blue     12
# red       8
# Name: count, dtype: int64

# %%
iris.loc[(iris.sepal_length==7.2) & (iris.color=='green'), ['sepal_length', 'id', 'color']].value_counts('color')
# Out:
# color
# green    12
# Name: count, dtype: int64
