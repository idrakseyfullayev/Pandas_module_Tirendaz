# %%
import pandas as pd

df = pd.read_table('data.txt')
df
# Out:
#   name  score sex
# 0  Tim     80   M
# 1  Tom     85   M
# 2  Kim     70   F
# 3  Sam     90   M
# 4  Efe     75   M

# %%
import pandas as pd

df = pd.read_csv('data.txt', sep='\s+')
df
# Out:
#   name  score sex
# 0  Tim     80   M
# 1  Tom     85   M
# 2  Kim     70   F
# 3  Sam     90   M
# 4  Efe     75   M

# %%
import pandas as pd

df = pd.read_table(r'C:\Users\dell\Desktop\img\data.txt')
df
# Out:
#   name  score sex
# 0  Tim     80   M
# 1  Tom     85   M
# 2  Kim     70   F
# 3  Sam     90   M
# 4  Efe     75   M

# %%
import pandas as pd

df = pd.read_table('data2.txt')
df
# Out:
#     Tom,80,M
# 0   Tim,85,M
# 1   Kim,70,M
# 2  Kate,90,F
# 3  Alex,75,F

# %%
import pandas as pd

df = pd.read_table('data2.txt', sep=',')
df
# Out:
#     Tom  80  M
# 0   Tim  85  M
# 1   Kim  70  M
# 2  Kate  90  F
# 3  Alex  75  F

# %%
import pandas as pd

df = pd.read_csv('data2.txt')
df
# Out:
#     Tom  80  M
# 0   Tim  85  M
# 1   Kim  70  M
# 2  Kate  90  F
# 3  Alex  75  F

# %%
import pandas as pd

df = pd.read_table(r'C:\Users\dell\Desktop\img\data2.txt')
df
# Out:
#     Tom,80,M
# 0   Tim,85,M
# 1   Kim,70,M
# 2  Kate,90,F
# 3  Alex,75,F

# %%
import pandas as pd

df = pd.read_table(r'C:\Users\dell\Desktop\img\data2.txt', sep=',')
df
# Out:
#     Tom  80  M
# 0   Tim  85  M
# 1   Kim  70  M
# 2  Kate  90  F
# 3  Alex  75  F

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\dell\Desktop\img\data2.txt')
df
# Out:
#     Tom  80  M
# 0   Tim  85  M
# 1   Kim  70  M
# 2  Kate  90  F
# 3  Alex  75  F

# %%
import pandas as pd

df = pd.read_table(r'C:\Users\dell\Desktop\img\data2.txt', sep=',', header=None)
df
# Out:
#       0   1  2
# 0   Tom  80  M
# 1   Tim  85  M
# 2   Kim  70  M
# 3  Kate  90  F
# 4  Alex  75  F

# %%
import pandas as pd

df = pd.read_table(r'C:\Users\dell\Desktop\img\data2.txt', sep=',', header=None, names=["name","score","sex"])
df
# Out:
#    name  score sex
# 0   Tom     80   M
# 1   Tim     85   M
# 2   Kim     70   M
# 3  Kate     90   F
# 4  Alex     75   F

# %%
import pandas as pd

df = pd.read_table(r'C:\Users\dell\Desktop\img\data2.txt', sep=',', 
                   header=None, 
                   names=["name","score","sex"],
                   index_col="name"
                  )
df
# Out:
#       score sex
# name
# Tom      80   M
# Tim      85   M
# Kim      70   M
# Kate     90   F
# Alex     75   F

# %%
import pandas as pd

df = pd.read_table(r'C:\Users\dell\Desktop\img\data2.txt', sep=',', 
                   header=None, 
                   names=["name","score","sex"],
                   index_col="sex"
                  )
df
# Out:
#      name  score
# sex
# M     Tom     80
# M     Tim     85
# M     Kim     70
# F    Kate     90
# F    Alex     75

# %%
import pandas as pd

df = pd.read_table(r'C:\Users\dell\Desktop\img\data2.txt', sep=',', 
                   header=None, 
                   names=["name","score","sex"],
                   )
df.set_index('name')
# Out:
#       score sex
# name
# Tom      80   M
# Tim      85   M
# Kim      70   M
# Kate     90   F
# Alex     75   F

# %%
import pandas as pd

df = pd.read_table('data3.txt')
df
# Out:
#   lesson,name,one,two
# 0      Math,Kim,80,85
# 1      Math,Tim,90,70
# 2      Math,Tom,70,95
# 3     Stat,Kate,65,90
# 4     Stat,Alex,85,80
# 5      Stat,Sam,55,70

# %%
import pandas as pd

df = pd.read_table('data3.txt', sep=',')
df
# Out:
#   lesson  name  one  two
# 0   Math   Kim   80   85
# 1   Math   Tim   90   70
# 2   Math   Tom   70   95
# 3   Stat  Kate   65   90
# 4   Stat  Alex   85   80
# 5   Stat   Sam   55   70

# %%
import pandas as pd

df = pd.read_table('data3.txt', sep=',', 
                   index_col=['lesson', "name"])
df
# Out:
#              one  two
# lesson name
# Math   Kim    80   85
#        Tim    90   70
#        Tom    70   95
# Stat   Kate   65   90
#        Alex   85   80
#        Sam    55   70

# %%
import pandas as pd

df = pd.read_table('data3.txt', sep=',')
df.set_index(['lesson', 'name'])
# Out:
#              one  two
# lesson name
# Math   Kim    80   85
#        Tim    90   70
#        Tom    70   95
# Stat   Kate   65   90
#        Alex   85   80
#        Sam    55   70

# %%
import pandas as pd

df = pd.read_table('data4.txt')
df
# Out:
#                 #hello
# 0       name,score,sex
# 1  #scores of students
# 2             Tim,80,M
# 3            Kate,85,F
# 4            Alex,70,M
# 5             Tom,90,M
# 6             Kim,75,F

# %%
import pandas as pd

df = pd.read_table('data4.txt', sep=',')
df
# Out:
#                           #hello
# name                score    sex
# #scores of students NaN      NaN
# Tim                 80         M
# Kate                85         F
# Alex                70         M
# Tom                 90         M
# Kim                 75         F

# %%
import pandas as pd

df = pd.read_table('data4.txt', sep=',', skiprows=[0, 2])
df
# Out:
#    name  score sex
# 0   Tim     80   M
# 1  Kate     85   F
# 2  Alex     70   M
# 3   Tom     90   M
# 4   Kim     75   F

# %%
import pandas as pd

df = pd.read_table('data4.txt', sep=',', skiprows=lambda x: x in [0, 2])
df
# Out:
#    name  score sex
# 0   Tim     80   M
# 1  Kate     85   F
# 2  Alex     70   M
# 3   Tom     90   M
# 4   Kim     75   F

# %%
import pandas as pd

df = pd.read_table('data4.txt', sep=',', 
                   skiprows=[0, 2],
                   usecols=[0, 1]
                  )
df
# Out:
#    name  score
# 0   Tim     80
# 1  Kate     85
# 2  Alex     70
# 3   Tom     90
# 4   Kim     75

# %%
import pandas as pd

df = pd.read_table('data4.txt', sep=',', 
                   skiprows=[0, 2],
                   usecols=['name']
                  )
df
# Out:
#    name
# 0   Tim
# 1  Kate
# 2  Alex
# 3   Tom
# 4   Kim

# %%
import pandas as pd

df = pd.read_table('data4.txt', sep=',', 
                   skiprows=[0, 2],
                   usecols=['name'],
                   nrows = 2
                  )
df
# Out:
#    name
# 0   Tim
# 1  Kate

# %%
import pandas as pd

df = pd.read_table('data5.txt')
df
# Out:
#   name,score,sex
# 0      Tim,80,NA
# 1       Tom,,Tom
# 2    Kate,70,n.a
# 3          ,90,K
# 4       Kim,-5,K

# %%
import pandas as pd

df = pd.read_table('data5.txt', sep=',')
df
# Out:
#    name  score  sex
# 0   Tim   80.0  NaN
# 1   Tom    NaN  Tom
# 2  Kate   70.0  n.a
# 3   NaN   90.0    K
# 4   Kim   -5.0    K

# %%
pd.isnull(df)
# Out:
#     name  score    sex
# 0  False  False   True
# 1  False   True  False
# 2  False  False  False
# 3   True  False  False
# 4  False  False  False

# %%
import pandas as pd

df = pd.read_table('data5.txt', sep=',', na_values=[-5, 'n.a'])
df
# Out:
#    name  score  sex
# 0   Tim   80.0  NaN
# 1   Tom    NaN  Tom
# 2  Kate   70.0  NaN
# 3   NaN   90.0    K
# 4   Kim    NaN    K

# %%
import pandas as pd

df = pd.read_table('data5.txt', sep=',', na_values=[-5, 'n.a', 'Tom', "K"])
df
# Out:
#    name  score  sex
# 0   Tim   80.0  NaN
# 1   NaN    NaN  NaN
# 2  Kate   70.0  NaN
# 3   NaN   90.0  NaN
# 4   Kim    NaN  NaN

# %%
import pandas as pd

df = pd.read_table('data5.txt', sep=',')
df
# Out:
#    name  score  sex
# 0   Tim   80.0  NaN
# 1   Tom    NaN  Tom
# 2  Kate   70.0  n.a
# 3   NaN   90.0    K
# 4   Kim   -5.0    K

# %%
import pandas as pd

missing_data = {'score': -5, 'sex': ['n.a', "Tom"]}

df = pd.read_table('data5.txt', sep=',', na_values=missing_data)
df
# Out:
#    name  score  sex
# 0   Tim   80.0  NaN
# 1   Tom    NaN  NaN
# 2  Kate   70.0  NaN
# 3   NaN   90.0    K
# 4   Kim    NaN    K

# %%
import pandas as pd

df = pd.read_table('data5.txt', sep=',')
df

int(df.loc[df.score < 0, 'score'].values)
# Out:
# -5

# %%
import pandas as pd

df = pd.read_table('data5.txt', sep=',')
df

list(df.loc[~( (df.sex == 'F') | (df.sex == 'M') ), 'sex'].values)
# Out:
# [nan, 'Tom', 'n.a', 'K', 'K']

# %%
import pandas as pd

missing_data = {'score': int(df.loc[df.score < 0, 'score'].values),
                'sex': list(df.loc[~( (df.sex == 'F') | (df.sex == 'M') ), 'sex'].values)
               }

df = pd.read_table('data5.txt', sep=',', na_values=missing_data)
df
# Out:
#    name  score  sex
# 0   Tim   80.0  NaN
# 1   Tom    NaN  NaN
# 2  Kate   70.0  NaN
# 3   NaN   90.0  NaN
# 4   Kim    NaN  NaN

# %%
import pandas as pd

df = pd.read_table('data.txt')
df
# Out:
#   name  score sex
# 0  Tim     80   M
# 1  Tom     85   M
# 2  Kim     70   F
# 3  Sam     90   M
# 4  Efe     75   M

# %%
df.to_csv('new_data.csv')

# %%
df.to_csv('new_data.txt')

# %%
df.to_csv(r'C:\Users\dell\Desktop\img\new_data.csv')

# %%
df.to_csv('new_data_1.csv', sep='|')

# %%
import sys

df.to_csv(sys.stdout, sep='|')
# Out:
# |name|score|sex
# 0|Tim|80|M
# 1|Tom|85|M
# 2|Kim|70|F
# 3|Sam|90|M
# 4|Efe|75|M

# %%
import sys

df.to_csv(sys.stdout, sep='|', na_rep='NULL')
# Out:
# |name|score|sex
# 0|Tim|80|M
# 1|Tom|85|M
# 2|Kim|70|F
# 3|Sam|90|M
# 4|Efe|75|M

# %%
import sys

df.to_csv(sys.stdout, sep='|', na_rep='NULL', index=False, header=False)
# Out:
# Tim|80|M
# Tom|85|M
# Kim|70|F
# Sam|90|M
# Efe|75|M

# %%
df.to_csv('new_data_2.csv', sep='|', index=False, header=False)

# %%
import sys

df.to_csv(sys.stdout, sep='|', na_rep='NULL', index=False, columns=['name', 'score'])
# Out:
# name|score
# Tim|80
# Tom|85
# Kim|70
# Sam|90
# Efe|75
