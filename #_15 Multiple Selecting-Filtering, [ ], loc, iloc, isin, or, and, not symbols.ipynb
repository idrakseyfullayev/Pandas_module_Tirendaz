# %%
import pandas as pd

film = pd.read_csv("http://bit.ly/imdbratings")

film.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
film['title'].head()
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2      The Godfather: Part II
# 3             The Dark Knight
# 4                Pulp Fiction
# Name: title, dtype: object

# %%
film[['title']].head()
# Out:
#                       title
# 0  The Shawshank Redemption
# 1             The Godfather
# 2    The Godfather: Part II
# 3           The Dark Knight
# 4              Pulp Fiction

# %%
film[['title', 'genre']].head()
# Out:
#                       title   genre
# 0  The Shawshank Redemption   Crime
# 1             The Godfather   Crime
# 2    The Godfather: Part II   Crime
# 3           The Dark Knight  Action
# 4              Pulp Fiction   Crime

# %%
film.loc[0]
# Out:
# star_rating                                                     9.3
# title                                      The Shawshank Redemption
# content_rating                                                    R
# genre                                                         Crime
# duration                                                        142
# actors_list       [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# Name: 0, dtype: object

# %%
film.loc[[0]]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
film.loc[[0, 1, 3]]
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
film.loc[0:5]
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
# 5          8.9              12 Angry Men      NOT RATED   Drama        96
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...

# %%
film.loc[0:5, 'title']
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2      The Godfather: Part II
# 3             The Dark Knight
# 4                Pulp Fiction
# 5                12 Angry Men
# Name: title, dtype: object

# %%
film.loc[0:5, 'title':'title']
# Out:
#                       title
# 0  The Shawshank Redemption
# 1             The Godfather
# 2    The Godfather: Part II
# 3           The Dark Knight
# 4              Pulp Fiction
# 5              12 Angry Men

# %%
film.loc[0:5, ['title']]
# Out:
#                       title
# 0  The Shawshank Redemption
# 1             The Godfather
# 2    The Godfather: Part II
# 3           The Dark Knight
# 4              Pulp Fiction
# 5              12 Angry Men

# %%
film.loc[5, ['title']]
# Out:
# title    12 Angry Men
# Name: 5, dtype: object

# %%
film.loc[[5], ['title']]
# Out:
#           title
# 5  12 Angry Men

# %%
film.loc[0:5, ['title', 'genre']]
# Out:
#                       title   genre
# 0  The Shawshank Redemption   Crime
# 1             The Godfather   Crime
# 2    The Godfather: Part II   Crime
# 3           The Dark Knight  Action
# 4              Pulp Fiction   Crime
# 5              12 Angry Men   Drama

# %%
film.loc[0:5, 'title': 'genre']
# Out:
#                       title content_rating   genre
# 0  The Shawshank Redemption              R   Crime
# 1             The Godfather              R   Crime
# 2    The Godfather: Part II              R   Crime
# 3           The Dark Knight          PG-13  Action
# 4              Pulp Fiction              R   Crime
# 5              12 Angry Men      NOT RATED   Drama

# %%
film.loc[:, ['genre']]
# Out:
#          genre
# 0        Crime
# 1        Crime
# 2        Crime
# 3       Action
# 4        Crime
# ..         ...
# 974     Comedy
# 975  Adventure
# 976     Action
# 977     Horror
# 978      Crime
#
# [979 rows x 1 columns]

# %%
film.loc[:, 'title':'genre']
# Out:
#                                                title content_rating      genre
# 0                           The Shawshank Redemption              R      Crime
# 1                                      The Godfather              R      Crime
# 2                             The Godfather: Part II              R      Crime
# 3                                    The Dark Knight          PG-13     Action
# 4                                       Pulp Fiction              R      Crime
# ..                                               ...            ...        ...
# 974                                          Tootsie             PG     Comedy
# 975                      Back to the Future Part III             PG  Adventure
# 976  Master and Commander: The Far Side of the World          PG-13     Action
# 977                                      Poltergeist             PG     Horror
# 978                                      Wall Street              R      Crime
#
# [979 rows x 3 columns]

# %%
film
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
film[film.genre=="Crime"]
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
film[film.genre=="Crime", 'star_rating']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978     True
# Name: genre, Length: 979, dtype: bool, 'star_rating')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# ...

# %%
film.loc[film.genre=="Crime"]
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
film.loc[film.genre=="Crime", 'star_rating']
# Out:
# 0      9.3
# 1      9.2
# 2      9.1
# 4      8.9
# 21     8.7
#       ...
# 927    7.5
# 931    7.4
# 950    7.4
# 969    7.4
# 978    7.4
# Name: star_rating, Length: 124, dtype: float64

# %%
film.loc[film.genre=="Crime", ['star_rating']]
# Out:
#      star_rating
# 0            9.3
# 1            9.2
# 2            9.1
# 4            8.9
# 21           8.7
# ..           ...
# 927          7.5
# 931          7.4
# 950          7.4
# 969          7.4
# 978          7.4
#
# [124 rows x 1 columns]

# %%
film.loc[film.genre=="Crime", ['star_rating', 'title', 'duration']]
# Out:
#      star_rating                     title  duration
# 0            9.3  The Shawshank Redemption       142
# 1            9.2             The Godfather       175
# 2            9.1    The Godfather: Part II       200
# 4            8.9              Pulp Fiction       154
# 21           8.7               City of God       130
# ..           ...                       ...       ...
# 927          7.5                     Brick       110
# 931          7.4              Mean Streets       112
# 950          7.4                     Bound       108
# 969          7.4       Law Abiding Citizen       109
# 978          7.4               Wall Street       126
#
# [124 rows x 3 columns]

# %%
film.loc[film.genre.str.lower()=="crime", ['star_rating', 'title', 'duration', 'genre']]
# Out:
#      star_rating                     title  duration  genre
# 0            9.3  The Shawshank Redemption       142  Crime
# 1            9.2             The Godfather       175  Crime
# 2            9.1    The Godfather: Part II       200  Crime
# 4            8.9              Pulp Fiction       154  Crime
# 21           8.7               City of God       130  Crime
# ..           ...                       ...       ...    ...
# 927          7.5                     Brick       110  Crime
# 931          7.4              Mean Streets       112  Crime
# 950          7.4                     Bound       108  Crime
# 969          7.4       Law Abiding Citizen       109  Crime
# 978          7.4               Wall Street       126  Crime
#
# [124 rows x 4 columns]

# %%
film.loc[film.title=="Pulp Fiction", ['star_rating', 'title', 'duration', 'genre']]
# Out:
#    star_rating         title  duration  genre
# 4          8.9  Pulp Fiction       154  Crime

# %%
film.loc[film.title=="fiction", ['star_rating', 'title', 'duration', 'genre']]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, duration, genre]
# Index: []

# %%
film.loc[film.title.str.contains("fiction", case=False), ['star_rating', 'title', 'duration', 'genre']]
# Out:
#      star_rating                  title  duration   genre
# 4            8.9           Pulp Fiction       154   Crime
# 696          7.7  Stranger Than Fiction       113  Comedy

# %%
film.loc[film['title'].str.lower().str.replace(' ', '') == 'pulpfiction', ['star_rating', 'title', 'duration', 'genre']]
# Out:
#    star_rating         title  duration  genre
# 4          8.9  Pulp Fiction       154  Crime

# %%
film.loc[film.loc[:, 'title'].str.contains('fiction', case=False), ['star_rating', 'title', 'duration', 'genre']]
# Out:
#      star_rating                  title  duration   genre
# 4            8.9           Pulp Fiction       154   Crime
# 696          7.7  Stranger Than Fiction       113  Comedy

# %%
film.title
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
film['title']
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
film.loc[:, 'title']
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: object

# %%
film.loc[film.genre=="Crime", "title":"duration"]
# Out:
#                         title content_rating  genre  duration
# 0    The Shawshank Redemption              R  Crime       142
# 1               The Godfather              R  Crime       175
# 2      The Godfather: Part II              R  Crime       200
# 4                Pulp Fiction              R  Crime       154
# 21                City of God              R  Crime       130
# ..                        ...            ...    ...       ...
# 927                     Brick              R  Crime       110
# 931              Mean Streets              R  Crime       112
# 950                     Bound              R  Crime       108
# 969       Law Abiding Citizen              R  Crime       109
# 978               Wall Street              R  Crime       126
#
# [124 rows x 4 columns]

# %%
film
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
( (film.star_rating >= 6) | (film.star_rating <= 9) ) & (film.genre == 'Action')
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 974    False
# 975    False
# 976     True
# 977    False
# 978    False
# Length: 979, dtype: bool

# %%
film.loc[( (film.star_rating >= 6) | (film.star_rating <= 9) ) & (film.genre == 'Action')]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
film.loc[( (film.star_rating >= 6) | (film.star_rating <= 9) ) & (film.genre == 'Action'), ['star_rating', "genre"]]
# Out:
#      star_rating   genre
# 3            9.0  Action
# 11           8.8  Action
# 12           8.8  Action
# 19           8.7  Action
# 20           8.7  Action
# ..           ...     ...
# 918          7.5  Action
# 954          7.4  Action
# 963          7.4  Action
# 967          7.4  Action
# 976          7.4  Action
#
# [136 rows x 2 columns]

# %%
film.loc[~( ( (film.star_rating >= 6) | (film.star_rating <= 9) ) & (film.genre == 'Action') ), ['star_rating', "genre"]]
# Out:
#      star_rating      genre
# 0            9.3      Crime
# 1            9.2      Crime
# 2            9.1      Crime
# 4            8.9      Crime
# 5            8.9      Drama
# ..           ...        ...
# 973          7.4      Drama
# 974          7.4     Comedy
# 975          7.4  Adventure
# 977          7.4     Horror
# 978          7.4      Crime
#
# [843 rows x 2 columns]

# %%
film.iloc[0]
# Out:
# star_rating                                                     9.3
# title                                      The Shawshank Redemption
# content_rating                                                    R
# genre                                                         Crime
# duration                                                        142
# actors_list       [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# Name: 0, dtype: object

# %%
film.iloc[[0]]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
film.iloc[0:6]
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
# 5          8.9              12 Angry Men      NOT RATED   Drama        96
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...

# %%
film.iloc[0:6, 0]
# Out:
# 0    9.3
# 1    9.2
# 2    9.1
# 3    9.0
# 4    8.9
# 5    8.9
# Name: star_rating, dtype: float64

# %%
film.iloc[:, 0]
# Out:
# 0      9.3
# 1      9.2
# 2      9.1
# 3      9.0
# 4      8.9
#       ...
# 974    7.4
# 975    7.4
# 976    7.4
# 977    7.4
# 978    7.4
# Name: star_rating, Length: 979, dtype: float64

# %%
film.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
film.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
film.iloc[[2, 4], [2, 3]]
# Out:
#   content_rating  genre
# 2              R  Crime
# 4              R  Crime

# %%
film.iloc[:, [2, 3]]
# Out:
#     content_rating      genre
# 0                R      Crime
# 1                R      Crime
# 2                R      Crime
# 3            PG-13     Action
# 4                R      Crime
# ..             ...        ...
# 974             PG     Comedy
# 975             PG  Adventure
# 976          PG-13     Action
# 977             PG     Horror
# 978              R      Crime
#
# [979 rows x 2 columns]

# %%
film
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
film.iloc[:, 0:5]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
film.iloc[0, 0:5]
# Out:
# star_rating                            9.3
# title             The Shawshank Redemption
# content_rating                           R
# genre                                Crime
# duration                               142
# Name: 0, dtype: object

# %%
film.iloc[[0], 0:5]
# Out:
#    star_rating                     title content_rating  genre  duration
# 0          9.3  The Shawshank Redemption              R  Crime       142

# %%
film.iloc[0:3, 0:3]
# Out:
#    star_rating                     title content_rating
# 0          9.3  The Shawshank Redemption              R
# 1          9.2             The Godfather              R
# 2          9.1    The Godfather: Part II              R

# %%
film.iloc[[0, 1, 4]]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 4          8.9              Pulp Fiction              R  Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
film.iloc[[0, 1, 4], :]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 4          8.9              Pulp Fiction              R  Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
film
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
film[(film.duration >= 200) & (film.genre == "Crime")]
# Out:
#     star_rating                        title content_rating  genre  duration  \
# 2           9.1       The Godfather: Part II              R  Crime       200
# 78          8.4  Once Upon a Time in America              R  Crime       229
#
#                                           actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...

# %%
film[(film.duration >= 200) | (film.genre == "Crime")]
# Out:
#      star_rating                                          title  \
# 0            9.3                       The Shawshank Redemption
# 1            9.2                                  The Godfather
# 2            9.1                         The Godfather: Part II
# 4            8.9                                   Pulp Fiction
# 7            8.9  The Lord of the Rings: The Return of the King
# ..           ...                                            ...
# 927          7.5                                          Brick
# 931          7.4                                   Mean Streets
# 950          7.4                                          Bound
# 969          7.4                            Law Abiding Citizen
# 978          7.4                                    Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
film[(film.duration >= 200) | 
     (film.genre == "Crime") |
     (film.genre=="Action")]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 969          7.4                              Law Abiding Citizen
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
film.genre.isin(['Action', "Crime", "Drama"])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 974    False
# 975    False
# 976     True
# 977    False
# 978     True
# Name: genre, Length: 979, dtype: bool

# %%
film[film.genre.isin(['Action', "Crime", "Drama"])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
film.loc[film.genre.isin(['Action', "Crime", "Drama"]), ["title", "duration", 'genre']]
# Out:
#                                                title  duration   genre
# 0                           The Shawshank Redemption       142   Crime
# 1                                      The Godfather       175   Crime
# 2                             The Godfather: Part II       200   Crime
# 3                                    The Dark Knight       152  Action
# 4                                       Pulp Fiction       154   Crime
# ..                                               ...       ...     ...
# 970                                      Wonder Boys       107   Drama
# 972                                   Blue Valentine       112   Drama
# 973                            The Cider House Rules       126   Drama
# 976  Master and Commander: The Far Side of the World       138  Action
# 978                                      Wall Street       126   Crime
#
# [538 rows x 3 columns]

# %%
film.loc[film.loc[:, 'star_rating'].isin([8.9, 9]), ['star_rating', 'title']]
# Out:
#    star_rating                                          title
# 3          9.0                                The Dark Knight
# 4          8.9                                   Pulp Fiction
# 5          8.9                                   12 Angry Men
# 6          8.9                 The Good, the Bad and the Ugly
# 7          8.9  The Lord of the Rings: The Return of the King
# 8          8.9                               Schindler's List
# 9          8.9                                     Fight Club
