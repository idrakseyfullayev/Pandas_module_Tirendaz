# %%
import pandas as pd; import numpy as np

# %%
data=pd.DataFrame(
    np.arange(16).reshape(4,4),
    index=[list("aabb"),[1,2]*2],
    columns=[["num","num",
              "comp","comp"],
             ["math","stat"]*2])
data
# Out:
#      num      comp
#     math stat math stat
# a 1    0    1    2    3
#   2    4    5    6    7
# b 1    8    9   10   11
#   2   12   13   14   15

# %%
long = data.stack()
long
# Out:
#           comp  num
# a 1 math     2    0
#     stat     3    1
#   2 math     6    4
#     stat     7    5
# b 1 math    10    8
#     stat    11    9
#   2 math    14   12
#     stat    15   13

# %%
data.index.names=["class","exam"]
data.columns.names=["field","lesson"]
data
# Out:
# field       num      comp
# lesson     math stat math stat
# class exam
# a     1       0    1    2    3
#       2       4    5    6    7
# b     1       8    9   10   11
#       2      12   13   14   15

# %%
long = data.stack()
long
# Out:
# field              comp  num
# class exam lesson
# a     1    math       2    0
#            stat       3    1
#       2    math       6    4
#            stat       7    5
# b     1    math      10    8
#            stat      11    9
#       2    math      14   12
#            stat      15   13

# %%
long.unstack()
# Out:
# field      comp       num
# lesson     math stat math stat
# class exam
# a     1       2    3    0    1
#       2       6    7    4    5
# b     1      10   11    8    9
#       2      14   15   12   13

# %%
data
# Out:
# field       num      comp
# lesson     math stat math stat
# class exam
# a     1       0    1    2    3
#       2       4    5    6    7
# b     1       8    9   10   11
#       2      12   13   14   15

# %%
data.stack()
# Out:
# field              comp  num
# class exam lesson
# a     1    math       2    0
#            stat       3    1
#       2    math       6    4
#            stat       7    5
# b     1    math      10    8
#            stat      11    9
#       2    math      14   12
#            stat      15   13

# %%
data.stack(level=0)
# Out:
# lesson            math  stat
# class exam field
# a     1    comp      2     3
#            num       0     1
#       2    comp      6     7
#            num       4     5
# b     1    comp     10    11
#            num       8     9
#       2    comp     14    15
#            num      12    13

# %%
data.stack(level='field')
# Out:
# lesson            math  stat
# class exam field
# a     1    comp      2     3
#            num       0     1
#       2    comp      6     7
#            num       4     5
# b     1    comp     10    11
#            num       8     9
#       2    comp     14    15
#            num      12    13

# %%
data.stack(level='field').unstack(level='field')
# Out:
# lesson     math     stat
# field      comp num comp num
# class exam
# a     1       2   0    3   1
#       2       6   4    7   5
# b     1      10   8   11   9
#       2      14  12   15  13

# %%
data.stack(level='field').unstack(level='exam')
# Out:
# lesson      math     stat
# exam           1   2    1   2
# class field
# a     comp     2   6    3   7
#       num      0   4    1   5
# b     comp    10  14   11  15
#       num      8  12    9  13

# %%
data.stack(level='field').unstack(level=['exam', 'field'])
# Out:
# lesson math              stat
# exam      1        2        1        2
# field  comp num comp num comp num comp num
# class
# a         2   0    6   4    3   1    7   5
# b        10   8   14  12   11   9   15  13

# %%
data.stack(level='field').unstack(level=['exam', 'class', 'field'])
# Out:
# lesson  exam  class  field
# math    1     a      comp      2
#                      num       0
#         2     a      comp      6
#                      num       4
#         1     b      comp     10
#                      num       8
#         2     b      comp     14
#                      num      12
# stat    1     a      comp      3
#                      num       1
#         2     a      comp      7
#                      num       5
#         1     b      comp     11
#                      num       9
#         2     b      comp     15
#                      num      13
# dtype: int32

# %%
ser1=pd.Series(
    np.arange(4),index=list("abcd"))
ser2=pd.Series(
    np.arange(6,9),index=list("cde"))

# %%
ser1
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int32

# %%
ser2
# Out:
# c    6
# d    7
# e    8
# dtype: int32

# %%
data = pd.concat([ser1, ser2], keys=['one', 'two', 'three'])
data
# Out:
# one  a    0
#      b    1
#      c    2
#      d    3
# two  c    6
#      d    7
#      e    8
# dtype: int32

# %%
data.unstack(level=0)
# Out:
#    one  two
# a  0.0  NaN
# b  1.0  NaN
# c  2.0  6.0
# d  3.0  7.0
# e  NaN  8.0

# %%
data.unstack()
# Out:
#        a    b    c    d    e
# one  0.0  1.0  2.0  3.0  NaN
# two  NaN  NaN  6.0  7.0  8.0

# %%
data.unstack(level=1)
# Out:
#        a    b    c    d    e
# one  0.0  1.0  2.0  3.0  NaN
# two  NaN  NaN  6.0  7.0  8.0

# %%
data.unstack().stack()
# Out:
# one  a    0.0
#      b    1.0
#      c    2.0
#      d    3.0
# two  c    6.0
#      d    7.0
#      e    8.0
# dtype: float64

# %%
data.unstack().stack(dropna=False)
# Out:
# one  a    0.0
#      b    1.0
#      c    2.0
#      d    3.0
#      e    NaN
# two  a    NaN
#      b    NaN
#      c    6.0
#      d    7.0
#      e    8.0
# dtype: float64

# %%
stock=pd.DataFrame(
    {"fruit": ["apple", "plum","grape"]*2,
     "color": ["purple","yellow"]*3,
     "piece":[3,4,5,6,1,2]})

stock
# Out:
#    fruit   color  piece
# 0  apple  purple      3
# 1   plum  yellow      4
# 2  grape  purple      5
# 3  apple  yellow      6
# 4   plum  purple      1
# 5  grape  yellow      2

# %%
stock.pivot(index='fruit', columns='color', values='piece')
# Out:
# color  purple  yellow
# fruit
# apple       3       6
# grape       5       2
# plum        1       4

# %%
np.random.seed(100)
stock['value'] = np.random.rand(len(stock))
stock
# Out:
#    fruit   color  piece     value
# 0  apple  purple      3  0.543405
# 1   plum  yellow      4  0.278369
# 2  grape  purple      5  0.424518
# 3  apple  yellow      6  0.844776
# 4   plum  purple      1  0.004719
# 5  grape  yellow      2  0.121569

# %%
p = stock.pivot(index="fruit", columns='color')
p
# Out:
#        piece            value
# color purple yellow    purple    yellow
# fruit
# apple      3      6  0.543405  0.844776
# grape      5      2  0.424518  0.121569
# plum       1      4  0.004719  0.278369

# %%
p = stock.pivot(index="fruit", columns='color', values=['piece', 'value'])
p
# Out:
#        piece            value
# color purple yellow    purple    yellow
# fruit
# apple    3.0    6.0  0.543405  0.844776
# grape    5.0    2.0  0.424518  0.121569
# plum     1.0    4.0  0.004719  0.278369

# %%
p = stock.pivot(index="fruit", columns='color', values='piece')
p
# Out:
# color  purple  yellow
# fruit
# apple       3       6
# grape       5       2
# plum        1       4

# %%
p = stock.pivot(index="fruit", columns='color', values=['piece', 'value'])
p
# Out:
#        piece            value
# color purple yellow    purple    yellow
# fruit
# apple    3.0    6.0  0.543405  0.844776
# grape    5.0    2.0  0.424518  0.121569
# plum     1.0    4.0  0.004719  0.278369

# %%
p["value"]
# Out:
# color    purple    yellow
# fruit
# apple  0.543405  0.844776
# grape  0.424518  0.121569
# plum   0.004719  0.278369

# %%
stock
# Out:
#    fruit   color  piece     value
# 0  apple  purple      3  0.543405
# 1   plum  yellow      4  0.278369
# 2  grape  purple      5  0.424518
# 3  apple  yellow      6  0.844776
# 4   plum  purple      1  0.004719
# 5  grape  yellow      2  0.121569

# %%
t = stock.pivot(index='fruit', columns='color')
t
# Out:
#        piece            value
# color purple yellow    purple    yellow
# fruit
# apple      3      6  0.543405  0.844776
# grape      5      2  0.424518  0.121569
# plum       1      4  0.004719  0.278369

# %%
t.stack()
# Out:
#               piece     value
# fruit color
# apple purple      3  0.543405
#       yellow      6  0.844776
# grape purple      5  0.424518
#       yellow      2  0.121569
# plum  purple      1  0.004719
#       yellow      4  0.278369

# %%
t.stack().reset_index()
# Out:
#    fruit   color  piece     value
# 0  apple  purple      3  0.543405
# 1  apple  yellow      6  0.844776
# 2  grape  purple      5  0.424518
# 3  grape  yellow      2  0.121569
# 4   plum  purple      1  0.004719
# 5   plum  yellow      4  0.278369

# %%
stock
# Out:
#    fruit   color  piece     value
# 0  apple  purple      3  0.543405
# 1   plum  yellow      4  0.278369
# 2  grape  purple      5  0.424518
# 3  apple  yellow      6  0.844776
# 4   plum  purple      1  0.004719
# 5  grape  yellow      2  0.121569

# %%
stock.set_index(['fruit', 'color'])
# Out:
#               piece     value
# fruit color
# apple purple      3  0.543405
# plum  yellow      4  0.278369
# grape purple      5  0.424518
# apple yellow      6  0.844776
# plum  purple      1  0.004719
# grape yellow      2  0.121569

# %%
stock.set_index(['fruit', 'color']).unstack()
# Out:
#        piece            value
# color purple yellow    purple    yellow
# fruit
# apple      3      6  0.543405  0.844776
# grape      5      2  0.424518  0.121569
# plum       1      4  0.004719  0.278369

# %%
stock.pivot(index="fruit", columns='color', values=['piece', 'value'])
# Out:
#        piece            value
# color purple yellow    purple    yellow
# fruit
# apple    3.0    6.0  0.543405  0.844776
# grape    5.0    2.0  0.424518  0.121569
# plum     1.0    4.0  0.004719  0.278369

# %%
stock.pivot(columns='color', values=['piece', 'value'])
# Out:
#        piece            value
# color purple yellow    purple    yellow
# 0        3.0    NaN  0.543405       NaN
# 1        NaN    4.0       NaN  0.278369
# 2        5.0    NaN  0.424518       NaN
# 3        NaN    6.0       NaN  0.844776
# 4        1.0    NaN  0.004719       NaN
# 5        NaN    2.0       NaN  0.121569

# %%
data=pd.DataFrame(
    {"lesson":["math","stat","bio"],
     "Sam":[50,60,70],
     "Kim":[80,70,90],
     "Tom":[60,70,85]})
data
# Out:
#   lesson  Sam  Kim  Tom
# 0   math   50   80   60
# 1   stat   60   70   70
# 2    bio   70   90   85

# %%
group = pd.melt(frame=data, id_vars=['lesson'])
group
# Out:
#   lesson variable  value
# 0   math      Sam     50
# 1   stat      Sam     60
# 2    bio      Sam     70
# 3   math      Kim     80
# 4   stat      Kim     70
# 5    bio      Kim     90
# 6   math      Tom     60
# 7   stat      Tom     70
# 8    bio      Tom     85

# %%
group = data.melt(id_vars=['lesson'])
group
# Out:
#   lesson variable  value
# 0   math      Sam     50
# 1   stat      Sam     60
# 2    bio      Sam     70
# 3   math      Kim     80
# 4   stat      Kim     70
# 5    bio      Kim     90
# 6   math      Tom     60
# 7   stat      Tom     70
# 8    bio      Tom     85

# %%
data
# Out:
#   lesson  Sam  Kim  Tom
# 0   math   50   80   60
# 1   stat   60   70   70
# 2    bio   70   90   85

# %%
group = data.melt(id_vars=['lesson'], value_vars='Sam')
group
# Out:
#   lesson variable  value
# 0   math      Sam     50
# 1   stat      Sam     60
# 2    bio      Sam     70

# %%
group = data.melt(id_vars=['lesson'], value_vars=['Sam', 'Kim'])
group
# Out:
#   lesson variable  value
# 0   math      Sam     50
# 1   stat      Sam     60
# 2    bio      Sam     70
# 3   math      Kim     80
# 4   stat      Kim     70
# 5    bio      Kim     90

# %%
data.melt(id_vars='lesson', var_name='Names', value_name='score')
# Out:
#   lesson Names  score
# 0   math   Sam     50
# 1   stat   Sam     60
# 2    bio   Sam     70
# 3   math   Kim     80
# 4   stat   Kim     70
# 5    bio   Kim     90
# 6   math   Tom     60
# 7   stat   Tom     70
# 8    bio   Tom     85

# %%
group = pd.melt(frame=data, id_vars='lesson')
group
# Out:
#   lesson variable  value
# 0   math      Sam     50
# 1   stat      Sam     60
# 2    bio      Sam     70
# 3   math      Kim     80
# 4   stat      Kim     70
# 5    bio      Kim     90
# 6   math      Tom     60
# 7   stat      Tom     70
# 8    bio      Tom     85

# %%
data = group.pivot(index='lesson', columns=['variable'], values='value')
data
# Out:
# variable  Kim  Sam  Tom
# lesson
# bio        90   70   85
# math       80   50   60
# stat       70   60   70

# %%
data = data.reset_index()
data
# Out:
# variable lesson  Kim  Sam  Tom
# 0           bio   90   70   85
# 1          math   80   50   60
# 2          stat   70   60   70

# %%
data.columns.name= None
data
# Out:
#   lesson  Kim  Sam  Tom
# 0    bio   90   70   85
# 1   math   80   50   60
# 2   stat   70   60   70

# %%
import pandas as pd

games = pd.read_csv(r'C:\Users\dell\Desktop\img\vgsalesGlobale.csv')
games
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games.pivot(index='Year', columns='Genre', values='NA_Sales')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[392], line 1
# ----> 1 games.pivot(index='Year', columns='Genre', values='NA_Sales')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8414, in DataFrame.pivot(self, columns, index, values)
#    8409 @Substitution("")
#    8410 @Appender(_shared_docs["pivot"])
#    8411 def pivot(self, *, columns, index=lib.NoDefault, values=lib.NoDefault) -> DataFrame:
#    8412     from pandas.core.reshape.pivot import pivot
# -> 8414     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:557, in pivot(data, columns, index, values)
#     553         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     554 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
# ...

# %%
games.pivot_table(index='Year', columns='Genre', values='NA_Sales')
# Out:
# Genre     Action    Shooter     Sports
# Year
# 1980   49.501429  34.604000  59.533333
# 1981   45.405000  25.163333  44.900000
# 1982   41.778571  46.091000  44.570000
# 1983   59.761818  71.978571  62.350000
# 1984   46.666250  37.182222  38.480000
# 1985   39.993750  45.530000  40.755000
# 1986   41.017143  47.661429  42.705000
# 1987   30.355556  52.734000  49.272857
# 1988   38.921667  29.870000  55.161250
# 1989   49.481538  44.175000  28.432500
# 1990   34.934444  37.071250  48.944286
# 1991   34.682222  63.016667  46.347143
# 1992   34.197778  39.481429  38.633750
# 1993   43.930000  46.898750  44.734286
# 1994   61.882500  41.404545  35.167500
# 1995   39.521250  39.432000  33.928333
# 1996   43.965714  43.548571  68.966000
# 1997   43.007143  44.432000  49.357778
# 1998   35.800000  41.190000  49.336000
# 1999   38.945000  34.348750  53.210000
# 2000   42.019167  51.660000  66.342500
# 2001   29.215556  52.149167  48.115000
# 2002   20.753333  28.292500  35.922857
# ...

# %%
games.pivot_table(index='Year', columns='Genre', values=['NA_Sales', "EU_Sales"])
# Out:
#         EU_Sales                         NA_Sales
# Genre     Action    Shooter     Sports     Action    Shooter     Sports
# Year
# 1980   15.968571  15.568000  16.730000  49.501429  34.604000  59.533333
# 1981   20.075000  14.785000  16.031818  45.405000  25.163333  44.900000
# 1982   12.051429  17.097000  19.116250  41.778571  46.091000  44.570000
# 1983   13.222727  14.652857  14.308000  59.761818  71.978571  62.350000
# 1984   13.032500  12.380000  17.277500  46.666250  37.182222  38.480000
# 1985   14.650000   9.032000  15.313571  39.993750  45.530000  40.755000
# 1986   14.018571  20.027143  14.868000  41.017143  47.661429  42.705000
# 1987   19.151111  11.922000  11.290000  30.355556  52.734000  49.272857
# 1988   16.326667  18.834444   8.503750  38.921667  29.870000  55.161250
# 1989   16.064615  12.536250  14.465000  49.481538  44.175000  28.432500
# 1990   13.164444  13.973750  12.495714  34.934444  37.071250  48.944286
# ...

# %%
games.pivot_table(index='Year', columns='Genre', values=['NA_Sales', "EU_Sales"]).stack('Genre')
# Out:
#                EU_Sales   NA_Sales
# Year Genre
# 1980 Action   15.968571  49.501429
#      Shooter  15.568000  34.604000
#      Sports   16.730000  59.533333
# 1981 Action   20.075000  45.405000
#      Shooter  14.785000  25.163333
# ...                 ...        ...
# 2021 Shooter  10.806667  39.365556
#      Sports   16.406667  43.931667
# 2022 Action    9.905000  39.056000
#      Shooter  11.160000  30.208000
#      Sports   16.090000  46.644000
#
# [129 rows x 2 columns]

# %%
games.pivot_table(index='Year', columns='Genre', values=['NA_Sales', "EU_Sales"]).stack('Genre').reset_index()
# Out:
#      Year    Genre   EU_Sales   NA_Sales
# 0    1980   Action  15.968571  49.501429
# 1    1980  Shooter  15.568000  34.604000
# 2    1980   Sports  16.730000  59.533333
# 3    1981   Action  20.075000  45.405000
# 4    1981  Shooter  14.785000  25.163333
# ..    ...      ...        ...        ...
# 124  2021  Shooter  10.806667  39.365556
# 125  2021   Sports  16.406667  43.931667
# 126  2022   Action   9.905000  39.056000
# 127  2022  Shooter  11.160000  30.208000
# 128  2022   Sports  16.090000  46.644000
#
# [129 rows x 4 columns]
