# %%
import pandas as pd; import numpy as np
df=pd.DataFrame(
    {"class":list("ABC")*4,
     "lesson":["math","stat"]*6,
     "sex":list("MFMM")*3,
     "sibling":[1,2,3]*4,
     "score":np.arange(40,100,5)})
df
# Out:
#    class lesson sex  sibling  score
# 0      A   math   M        1     40
# 1      B   stat   F        2     45
# 2      C   math   M        3     50
# 3      A   stat   M        1     55
# 4      B   math   M        2     60
# 5      C   stat   F        3     65
# 6      A   math   M        1     70
# 7      B   stat   M        2     75
# 8      C   math   M        3     80
# 9      A   stat   F        1     85
# 10     B   math   M        2     90
# 11     C   stat   M        3     95

# %%
df_ = df.pivot_table(values=['sibling', 'score'], index=['class'], columns=['sex', 'lesson'], fill_value=0)
df_
# Out:
#        score           sibling
# sex        F    M            F    M
# lesson  stat math stat    stat math stat
# class
# A         85   55   55       1    1    1
# B         45   75   75       2    2    2
# C         65   65   95       3    3    3

# %%
df_.columns
# Out:
# MultiIndex([(  'score', 'F', 'stat'),
#             (  'score', 'M', 'math'),
#             (  'score', 'M', 'stat'),
#             ('sibling', 'F', 'stat'),
#             ('sibling', 'M', 'math'),
#             ('sibling', 'M', 'stat')],
#            names=[None, 'sex', 'lesson'])

# %%
df_.index
# Out:
# Index(['A', 'B', 'C'], dtype='object', name='class')

# %%
df_
# Out:
#        score           sibling
# sex        F    M            F    M
# lesson  stat math stat    stat math stat
# class
# A         85   55   55       1    1    1
# B         45   75   75       2    2    2
# C         65   65   95       3    3    3

# %%
df_.groupby(level=0, axis=0).sum()
# Out:
#        score           sibling
# sex        F    M            F    M
# lesson  stat math stat    stat math stat
# class
# A         85   55   55       1    1    1
# B         45   75   75       2    2    2
# C         65   65   95       3    3    3

# %%
df_
# Out:
#        score           sibling
# sex        F    M            F    M
# lesson  stat math stat    stat math stat
# class
# A         85   55   55       1    1    1
# B         45   75   75       2    2    2
# C         65   65   95       3    3    3

# %%
df_.groupby(level=0, axis=1).sum()
# Out:
#        score  sibling
# class
# A        195        3
# B        195        6
# C        225        9

# %%
df_
# Out:
#        score           sibling
# sex        F    M            F    M
# lesson  stat math stat    stat math stat
# class
# A         85   55   55       1    1    1
# B         45   75   75       2    2    2
# C         65   65   95       3    3    3

# %%
df_.groupby(level=1, axis=1).sum()
# Out:
# sex     F    M
# class
# A      86  112
# B      47  154
# C      68  166

# %%
df_
# Out:
#        score           sibling
# sex        F    M            F    M
# lesson  stat math stat    stat math stat
# class
# A         85   55   55       1    1    1
# B         45   75   75       2    2    2
# C         65   65   95       3    3    3

# %%
df_.groupby(level=2, axis=1).sum()
# Out:
# lesson  math  stat
# class
# A         56   142
# B         77   124
# C         68   166

# %%
df_1 = df.pivot_table(values=['sibling', 'score'], index=['class', 'sex'], columns=['lesson'], fill_value=0)
df_1
# Out:
#           score      sibling
# lesson     math stat    math stat
# class sex
# A     F       0   85       0    1
#       M      55   55       1    1
# B     F       0   45       0    2
#       M      75   75       2    2
# C     F       0   65       0    3
#       M      65   95       3    3

# %%
df_1.groupby(level=0, axis=0).sum()
# Out:
#        score      sibling
# lesson  math stat    math stat
# class
# A         55  140       1    2
# B         75  120       2    4
# C         65  160       3    6

# %%
df_1
# Out:
#           score      sibling
# lesson     math stat    math stat
# class sex
# A     F       0   85       0    1
#       M      55   55       1    1
# B     F       0   45       0    2
#       M      75   75       2    2
# C     F       0   65       0    3
#       M      65   95       3    3

# %%
df_1.groupby(level=1, axis=0).sum()
# Out:
#        score      sibling
# lesson  math stat    math stat
# sex
# F          0  195       0    6
# M        195  225       6    6

# %%
df_1.groupby(level=-1, axis=0).sum()
# Out:
#        score      sibling
# lesson  math stat    math stat
# sex
# F          0  195       0    6
# M        195  225       6    6

# %%
df_1
# Out:
#           score      sibling
# lesson     math stat    math stat
# class sex
# A     F       0   85       0    1
#       M      55   55       1    1
# B     F       0   45       0    2
#       M      75   75       2    2
# C     F       0   65       0    3
#       M      65   95       3    3

# %%
df_1.groupby(level='sex', axis=0).sum()
# Out:
#        score      sibling
# lesson  math stat    math stat
# sex
# F          0  195       0    6
# M        195  225       6    6

# %%
df_1
# Out:
#           score      sibling
# lesson     math stat    math stat
# class sex
# A     F       0   85       0    1
#       M      55   55       1    1
# B     F       0   45       0    2
#       M      75   75       2    2
# C     F       0   65       0    3
#       M      65   95       3    3

# %%
df_1.groupby(level='lesson', axis=1).sum()
# Out:
# lesson     math  stat
# class sex
# A     F       0    86
#       M      56    56
# B     F       0    47
#       M      77    77
# C     F       0    68
#       M      68    98

# %%
df_1
# Out:
#           score      sibling
# lesson     math stat    math stat
# class sex
# A     F       0   85       0    1
#       M      55   55       1    1
# B     F       0   45       0    2
#       M      75   75       2    2
# C     F       0   65       0    3
#       M      65   95       3    3

# %%
df_1.groupby(level=0, axis=1).sum()
# Out:
#            score  sibling
# class sex
# A     F       85        1
#       M      110        2
# B     F       45        2
#       M      150        4
# C     F       65        3
#       M      160        6

# %%
df_1
# Out:
#           score      sibling
# lesson     math stat    math stat
# class sex
# A     F       0   85       0    1
#       M      55   55       1    1
# B     F       0   45       0    2
#       M      75   75       2    2
# C     F       0   65       0    3
#       M      65   95       3    3

# %%
df_1.groupby(level=0).sum()
# Out:
#        score      sibling
# lesson  math stat    math stat
# class
# A         55  140       1    2
# B         75  120       2    4
# C         65  160       3    6

# %%
df_1.groupby(level='sex').sum()
# Out:
#        score      sibling
# lesson  math stat    math stat
# sex
# F          0  195       0    6
# M        195  225       6    6
