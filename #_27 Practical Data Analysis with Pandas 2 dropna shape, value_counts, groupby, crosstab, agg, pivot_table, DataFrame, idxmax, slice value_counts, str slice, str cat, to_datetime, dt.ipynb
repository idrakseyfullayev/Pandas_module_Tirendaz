# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\dell\Desktop\img\ca_san_diego_2019_02_25.csv')
df
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 0                    1  2014-01-01  01:25:00          110         24.0
# 1                    2  2014-01-01  05:47:00          320         42.0
# 2                    3  2014-01-01  07:46:00          320         29.0
# 3                    4  2014-01-01  08:10:00          610         23.0
# 4                    5  2014-01-01  08:35:00          930         35.0
# ...                ...         ...       ...          ...          ...
# 390994          390995  2017-03-31  23:45:00          830         20.0
# 390995          390996  2017-03-31  23:45:00          710         65.0
# 390996          390997  2017-03-31  23:49:00          620         23.0
# 390997          390998  2017-03-31  23:55:00          710          NaN
# 390998          390999  2017-03-31  23:58:00          310         26.0
#
#                   subject_race subject_sex       type arrest_made  \
# ...

# %%
df.shape
# Out:
# (390999, 19)

# %%
df.dropna(how='all', axis='columns')
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 0                    1  2014-01-01  01:25:00          110         24.0
# 1                    2  2014-01-01  05:47:00          320         42.0
# 2                    3  2014-01-01  07:46:00          320         29.0
# 3                    4  2014-01-01  08:10:00          610         23.0
# 4                    5  2014-01-01  08:35:00          930         35.0
# ...                ...         ...       ...          ...          ...
# 390994          390995  2017-03-31  23:45:00          830         20.0
# 390995          390996  2017-03-31  23:45:00          710         65.0
# 390996          390997  2017-03-31  23:49:00          620         23.0
# 390997          390998  2017-03-31  23:55:00          710          NaN
# 390998          390999  2017-03-31  23:58:00          310         26.0
#
#                   subject_race subject_sex       type arrest_made  \
# ...

# %%
df.dropna(how='all', axis='columns').shape
# Out:
# (390999, 19)

# %%
df.dropna(how='any', axis='columns').shape
# Out:
# (390999, 3)

# %%
df.dropna(how='all', axis='index').shape
# Out:
# (390999, 19)

# %%
df.dropna(how='any', axis='index').shape
# Out:
# (8886, 19)

# %%
df.dropna().shape
# Out:
# (8886, 19)

# %%
df.dropna(axis=1).shape
# Out:
# (390999, 3)

# %%
df
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 0                    1  2014-01-01  01:25:00          110         24.0
# 1                    2  2014-01-01  05:47:00          320         42.0
# 2                    3  2014-01-01  07:46:00          320         29.0
# 3                    4  2014-01-01  08:10:00          610         23.0
# 4                    5  2014-01-01  08:35:00          930         35.0
# ...                ...         ...       ...          ...          ...
# 390994          390995  2017-03-31  23:45:00          830         20.0
# 390995          390996  2017-03-31  23:45:00          710         65.0
# 390996          390997  2017-03-31  23:49:00          620         23.0
# 390997          390998  2017-03-31  23:55:00          710          NaN
# 390998          390999  2017-03-31  23:58:00          310         26.0
#
#                   subject_race subject_sex       type arrest_made  \
# ...

# %%
df[['reason_for_stop']].agg(['value_counts'])
# Out:
#                                    reason_for_stop
#                                       value_counts
# reason_for_stop
# Moving Violation                            285562
# Equipment Violation                          99577
# Radio Call/Citizen Contact                    1941
# Muni, County, H&S Code                        1349
# Personal Knowledge/Informant                   884
# Suspect Info (I.S., Bulletin, Log)             539
# No Cause Specified on a Card                   430
# Personal Observ/Knowledge                      104
# Muni                                            85
# UNI, &County, H&&S Code                         73
# Other                                           39
# Suspect Info (I.S.                              39
# MUNI, County, H&S Code                          29
# &Moving Violation                               21
# Suspect Info                                    17
# MUNI                                             8
# ...

# %%
df['subject_sex'].agg(['value_counts'])
# Out:
#              value_counts
# subject_sex
# male               253397
# female             136796

# %%
df[['subject_sex']].agg(['count'])
# Out:
#        subject_sex
# count       390193

# %%
df[['date', 'subject_sex']].groupby(['date']).agg('value_counts').unstack()
# Out:
# subject_sex  female  male
# date
# 2014-01-01       18    33
# 2014-01-02       19    49
# 2014-01-03       35    62
# 2014-01-04       23    53
# 2014-01-05       33    71
# ...             ...   ...
# 2017-03-27       88   193
# 2017-03-28      143   245
# 2017-03-29       73   158
# 2017-03-30      150   243
# 2017-03-31      145   299
#
# [1186 rows x 2 columns]

# %%
df.pivot_table(index=['date'], values=['subject_sex'], aggfunc='value_counts').unstack()
# Out:
# subject_sex  female  male
# date
# 2014-01-01       18    33
# 2014-01-02       19    49
# 2014-01-03       35    62
# 2014-01-04       23    53
# 2014-01-05       33    71
# ...             ...   ...
# 2017-03-27       88   193
# 2017-03-28      143   245
# 2017-03-29       73   158
# 2017-03-30      150   243
# 2017-03-31      145   299
#
# [1186 rows x 2 columns]

# %%
pd.crosstab(index=df.date, columns=df.subject_sex)
# Out:
# subject_sex  female  male
# date
# 2014-01-01       18    33
# 2014-01-02       19    49
# 2014-01-03       35    62
# 2014-01-04       23    53
# 2014-01-05       33    71
# ...             ...   ...
# 2017-03-27       88   193
# 2017-03-28      143   245
# 2017-03-29       73   158
# 2017-03-30      150   243
# 2017-03-31      145   299
#
# [1186 rows x 2 columns]

# %%
pd.crosstab(index=df.date, columns=df.subject_sex).loc[['2014-01-03']]
# Out:
# subject_sex  female  male
# date
# 2014-01-03       35    62

# %%
df[df.date == '2014-01-03'].subject_sex.value_counts()
# Out:
# subject_sex
# male      62
# female    35
# Name: count, dtype: int64

# %%
df[['reason_for_stop']].agg(['value_counts']).head()
# Out:
#                              reason_for_stop
#                                 value_counts
# reason_for_stop
# Moving Violation                      285562
# Equipment Violation                    99577
# Radio Call/Citizen Contact              1941
# Muni, County, H&S Code                  1349
# Personal Knowledge/Informant             884

# %%
df[df.reason_for_stop=='Moving Violation'].agg({'subject_sex': 'value_counts'})
# Out:
#              subject_sex
# subject_sex
# male              179242
# female            105765

# %%
df[df.reason_for_stop=='Moving Violation'].subject_sex.agg(['value_counts'])
# Out:
#              value_counts
# subject_sex
# male               179242
# female             105765

# %%
df[df.reason_for_stop=='Moving Violation'].subject_sex.value_counts(normalize=True)
# Out:
# subject_sex
# male      0.628904
# female    0.371096
# Name: proportion, dtype: float64

# %%
pd.DataFrame(data=df[df.reason_for_stop=='Moving Violation'].subject_sex.value_counts(normalize=True))
# Out:
#              proportion
# subject_sex
# male           0.628904
# female         0.371096

# %%
df[df.subject_sex=="female"].reason_for_stop.value_counts(normalize=True)
# Out:
# reason_for_stop
# Moving Violation                      0.773651
# Equipment Violation                   0.215736
# Radio Call/Citizen Contact            0.003606
# Muni, County, H&S Code                0.002516
# Personal Knowledge/Informant          0.001609
# No Cause Specified on a Card          0.001287
# Suspect Info (I.S., Bulletin, Log)    0.000929
# Personal Observ/Knowledge             0.000234
# Other                                 0.000110
# UNI, &County, H&&S Code               0.000110
# &Moving Violation                     0.000044
# Suspect Info                          0.000044
# MUNI, County, H&S Code                0.000029
# NOTHING MARKED                        0.000015
# not marked                            0.000015
# NOT MARKED                            0.000015
# &Equipment Violation                  0.000015
# not marked  not marked                0.000007
# NOT CHECKED                           0.000007
# not secified                          0.000007
# ...

# %%
df.groupby('subject_sex').reason_for_stop.value_counts()
# Out:
# subject_sex  reason_for_stop
# female       Moving Violation                      105765
#              Equipment Violation                    29493
#              Radio Call/Citizen Contact               493
#              Muni, County, H&S Code                   344
#              Personal Knowledge/Informant             220
#              No Cause Specified on a Card             176
#              Suspect Info (I.S., Bulletin, Log)       127
#              Personal Observ/Knowledge                 32
#              Other                                     15
#              UNI, &County, H&&S Code                   15
#              &Moving Violation                          6
#              Suspect Info                               6
#              MUNI, County, H&S Code                     4
#              &Equipment Violation                       2
#              not marked                                 2
#              NOTHING MARKED                             2
# ...

# %%
pd.DataFrame(data=df.groupby('subject_sex').reason_for_stop.value_counts(normalize=True))
# Out:
#                                                 proportion
# subject_sex reason_for_stop
# female      Moving Violation                      0.773651
#             Equipment Violation                   0.215736
#             Radio Call/Citizen Contact            0.003606
#             Muni, County, H&S Code                0.002516
#             Personal Knowledge/Informant          0.001609
#             No Cause Specified on a Card          0.001287
#             Suspect Info (I.S., Bulletin, Log)    0.000929
#             Personal Observ/Knowledge             0.000234
#             Other                                 0.000110
#             UNI, &County, H&&S Code               0.000110
#             &Moving Violation                     0.000044
#             Suspect Info                          0.000044
#             MUNI, County, H&S Code                0.000029
#             not marked                            0.000015
# ...

# %%
pd.DataFrame(data=df.groupby('subject_sex').reason_for_stop.value_counts(normalize=True).unstack())
# Out:
# reason_for_stop  Moving Violation  Equipment Violation  \
# subject_sex
# female                   0.773651             0.215736
# male                     0.707770             0.276510
#
# reason_for_stop  Radio Call/Citizen Contact  Muni, County, H&S Code  \
# subject_sex
# female                             0.003606                0.002516
# male                               0.005690                0.003961
#
# reason_for_stop  Personal Knowledge/Informant  No Cause Specified on a Card  \
# subject_sex
# female                               0.001609                      0.001287
# male                                 0.002614                      0.000991
#
# reason_for_stop  Suspect Info (I.S., Bulletin, Log)  \
# subject_sex
# female                                     0.000929
# male                                       0.001619
#
# reason_for_stop  Personal Observ/Knowledge     Other  UNI, &County, H&&S Code  \
# subject_sex
# ...

# %%
df
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 0                    1  2014-01-01  01:25:00          110         24.0
# 1                    2  2014-01-01  05:47:00          320         42.0
# 2                    3  2014-01-01  07:46:00          320         29.0
# 3                    4  2014-01-01  08:10:00          610         23.0
# 4                    5  2014-01-01  08:35:00          930         35.0
# ...                ...         ...       ...          ...          ...
# 390994          390995  2017-03-31  23:45:00          830         20.0
# 390995          390996  2017-03-31  23:45:00          710         65.0
# 390996          390997  2017-03-31  23:49:00          620         23.0
# 390997          390998  2017-03-31  23:55:00          710          NaN
# 390998          390999  2017-03-31  23:58:00          310         26.0
#
#                   subject_race subject_sex       type arrest_made  \
# ...

# %%
df.groupby('date').agg({'reason_for_stop': 'value_counts'})
# Out:
#                                          reason_for_stop
# date       reason_for_stop
# 2014-01-01 Moving Violation                           31
#            Equipment Violation                        19
#            Muni, County, H&S Code                      1
# 2014-01-02 Moving Violation                           45
#            Equipment Violation                        22
# ...                                                  ...
# 2017-03-31 Moving Violation                          359
#            Equipment Violation                        79
#            Radio Call/Citizen Contact                  3
#            Personal Knowledge/Informant                2
#            Personal Observ/Knowledge                   1
#
# [5269 rows x 1 columns]

# %%
df.groupby('date').agg({'reason_for_stop': 'value_counts'}).agg({'reason_for_stop': ['idxmax']})
# Out:
#                        reason_for_stop
# idxmax  (2014-02-05, Moving Violation)

# %%
max_=df.groupby('date').agg({'reason_for_stop': 'value_counts'})['reason_for_stop'].max()
max_
# Out:
# 695

# %%
df.groupby('date').agg({'reason_for_stop': 'value_counts'
                       })[df.groupby('date').agg({'reason_for_stop': 'value_counts'
                                                 })['reason_for_stop']==max_]
# Out:
#                              reason_for_stop
# date       reason_for_stop
# 2014-02-05 Moving Violation              695

# %%
max_1 = df.groupby('date').agg({'reason_for_stop': 'value_counts'}).max()
max_1
# Out:
# reason_for_stop    695
# dtype: int64

# %%
df.groupby('date').agg({'reason_for_stop': 'value_counts'
                       })[df.groupby('date').agg({'reason_for_stop': 'value_counts'
                                                 })==max_1].dropna()
# Out:
#                              reason_for_stop
# date       reason_for_stop
# 2014-02-05 Moving Violation            695.0

# %%
df
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 0                    1  2014-01-01  01:25:00          110         24.0
# 1                    2  2014-01-01  05:47:00          320         42.0
# 2                    3  2014-01-01  07:46:00          320         29.0
# 3                    4  2014-01-01  08:10:00          610         23.0
# 4                    5  2014-01-01  08:35:00          930         35.0
# ...                ...         ...       ...          ...          ...
# 390994          390995  2017-03-31  23:45:00          830         20.0
# 390995          390996  2017-03-31  23:45:00          710         65.0
# 390996          390997  2017-03-31  23:49:00          620         23.0
# 390997          390998  2017-03-31  23:55:00          710          NaN
# 390998          390999  2017-03-31  23:58:00          310         26.0
#
#                   subject_race subject_sex       type arrest_made  \
# ...

# %%
df.date.str.slice(0,4)
# Out:
# 0         2014
# 1         2014
# 2         2014
# 3         2014
# 4         2014
#           ...
# 390994    2017
# 390995    2017
# 390996    2017
# 390997    2017
# 390998    2017
# Name: date, Length: 390999, dtype: object

# %%
df.date.str.slice(0,4).agg(['value_counts'])
# Out:
#       value_counts
# date
# 2014        144164
# 2015        115422
# 2016        103051
# 2017         28230

# %%
df['date'].str[0:4].agg(['value_counts'])
# Out:
#       value_counts
# date
# 2014        144164
# 2015        115422
# 2016        103051
# 2017         28230

# %%
df
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 0                    1  2014-01-01  01:25:00          110         24.0
# 1                    2  2014-01-01  05:47:00          320         42.0
# 2                    3  2014-01-01  07:46:00          320         29.0
# 3                    4  2014-01-01  08:10:00          610         23.0
# 4                    5  2014-01-01  08:35:00          930         35.0
# ...                ...         ...       ...          ...          ...
# 390994          390995  2017-03-31  23:45:00          830         20.0
# 390995          390996  2017-03-31  23:45:00          710         65.0
# 390996          390997  2017-03-31  23:49:00          620         23.0
# 390997          390998  2017-03-31  23:55:00          710          NaN
# 390998          390999  2017-03-31  23:58:00          310         26.0
#
#                   subject_race subject_sex       type arrest_made  \
# ...

# %%
df.arrest_made.value_counts()
# Out:
# arrest_made
# False    351060
# True       4917
# Name: count, dtype: int64

# %%
df.arrest_made.value_counts(normalize=True)
# Out:
# arrest_made
# False    0.986187
# True     0.013813
# Name: proportion, dtype: float64

# %%
df.groupby('subject_sex').agg({'arrest_made': 'value_counts'})
# Out:
#                          arrest_made
# subject_sex arrest_made
# female      False             123901
#             True                1119
# male        False             226778
#             True                3793

# %%
df.groupby('subject_sex').arrest_made.value_counts(normalize=True)
# Out:
# subject_sex  arrest_made
# female       False          0.991049
#              True           0.008951
# male         False          0.983550
#              True           0.016450
# Name: proportion, dtype: float64

# %%
df.groupby(["subject_race","subject_sex"]).arrest_made.value_counts(normalize=True)
# Out:
# subject_race            subject_sex  arrest_made
# asian/pacific islander  female       False          0.993134
#                                      True           0.006866
#                         male         False          0.987704
#                                      True           0.012296
# black                   female       False          0.985657
#                                      True           0.014343
#                         male         False          0.975443
#                                      True           0.024557
# hispanic                female       False          0.990328
#                                      True           0.009672
#                         male         False          0.980173
#                                      True           0.019827
# other/unknown           female       False          0.996578
#                                      True           0.003422
#                         male         False          0.992050
# ...

# %%
df
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 0                    1  2014-01-01  01:25:00          110         24.0
# 1                    2  2014-01-01  05:47:00          320         42.0
# 2                    3  2014-01-01  07:46:00          320         29.0
# 3                    4  2014-01-01  08:10:00          610         23.0
# 4                    5  2014-01-01  08:35:00          930         35.0
# ...                ...         ...       ...          ...          ...
# 390994          390995  2017-03-31  23:45:00          830         20.0
# 390995          390996  2017-03-31  23:45:00          710         65.0
# 390996          390997  2017-03-31  23:49:00          620         23.0
# 390997          390998  2017-03-31  23:55:00          710          NaN
# 390998          390999  2017-03-31  23:58:00          310         26.0
#
#                   subject_race subject_sex       type arrest_made  \
# ...

# %%
combined = df.date.str.cat(df.time, sep=' ')
combined
# Out:
# 0         2014-01-01 01:25:00
# 1         2014-01-01 05:47:00
# 2         2014-01-01 07:46:00
# 3         2014-01-01 08:10:00
# 4         2014-01-01 08:35:00
#                  ...
# 390994    2017-03-31 23:45:00
# 390995    2017-03-31 23:45:00
# 390996    2017-03-31 23:49:00
# 390997    2017-03-31 23:55:00
# 390998    2017-03-31 23:58:00
# Name: date, Length: 390999, dtype: object

# %%
df["stop_datetime"] = pd.to_datetime(combined)
df.stop_datetime
# Out:
# 0        2014-01-01 01:25:00
# 1        2014-01-01 05:47:00
# 2        2014-01-01 07:46:00
# 3        2014-01-01 08:10:00
# 4        2014-01-01 08:35:00
#                  ...
# 390994   2017-03-31 23:45:00
# 390995   2017-03-31 23:45:00
# 390996   2017-03-31 23:49:00
# 390997   2017-03-31 23:55:00
# 390998   2017-03-31 23:58:00
# Name: stop_datetime, Length: 390999, dtype: datetime64[ns]

# %%
df
# Out:
#         raw_row_number        date      time service_area  subject_age  \
# 0                    1  2014-01-01  01:25:00          110         24.0
# 1                    2  2014-01-01  05:47:00          320         42.0
# 2                    3  2014-01-01  07:46:00          320         29.0
# 3                    4  2014-01-01  08:10:00          610         23.0
# 4                    5  2014-01-01  08:35:00          930         35.0
# ...                ...         ...       ...          ...          ...
# 390994          390995  2017-03-31  23:45:00          830         20.0
# 390995          390996  2017-03-31  23:45:00          710         65.0
# 390996          390997  2017-03-31  23:49:00          620         23.0
# 390997          390998  2017-03-31  23:55:00          710          NaN
# 390998          390999  2017-03-31  23:58:00          310         26.0
#
#                   subject_race subject_sex       type arrest_made  \
# ...

# %%
df.dtypes
# Out:
# raw_row_number                int64
# date                         object
# time                         object
# service_area                 object
# subject_age                 float64
# subject_race                 object
# subject_sex                  object
# type                         object
# arrest_made                  object
# citation_issued              object
# warning_issued               object
# outcome                      object
# contraband_found             object
# search_conducted             object
# search_person                object
# search_vehicle               object
# search_basis                 object
# reason_for_search            object
# reason_for_stop              object
# stop_datetime        datetime64[ns]
# dtype: object

# %%
df.stop_datetime.dt.year
# Out:
# 0         2014.0
# 1         2014.0
# 2         2014.0
# 3         2014.0
# 4         2014.0
#            ...
# 390994    2017.0
# 390995    2017.0
# 390996    2017.0
# 390997    2017.0
# 390998    2017.0
# Name: stop_datetime, Length: 390999, dtype: float64

# %%
df.stop_datetime.dt.month
# Out:
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 390994    3.0
# 390995    3.0
# 390996    3.0
# 390997    3.0
# 390998    3.0
# Name: stop_datetime, Length: 390999, dtype: float64

# %%
df.stop_datetime.dt.day
# Out:
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
#           ...
# 390994    31.0
# 390995    31.0
# 390996    31.0
# 390997    31.0
# 390998    31.0
# Name: stop_datetime, Length: 390999, dtype: float64

# %%
df.arrest_made
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 390994    False
# 390995      NaN
# 390996    False
# 390997      NaN
# 390998      NaN
# Name: arrest_made, Length: 390999, dtype: object

# %%
df.arrest_made = df.arrest_made.astype(bool)
df.arrest_made
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 390994    False
# 390995     True
# 390996    False
# 390997     True
# 390998     True
# Name: arrest_made, Length: 390999, dtype: bool

# %%
df.dtypes
# Out:
# raw_row_number                int64
# date                         object
# time                         object
# service_area                 object
# subject_age                 float64
# subject_race                 object
# subject_sex                  object
# type                         object
# arrest_made                    bool
# citation_issued              object
# warning_issued               object
# outcome                      object
# contraband_found             object
# search_conducted             object
# search_person                object
# search_vehicle               object
# search_basis                 object
# reason_for_search            object
# reason_for_stop              object
# stop_datetime        datetime64[ns]
# dtype: object

# %%
df.arrest_made.value_counts()
# Out:
# arrest_made
# False    351060
# True      39939
# Name: count, dtype: int64

# %%
df.arrest_made.mean()
# Out:
# 0.10214604129422326

# %%
df.groupby(df.stop_datetime.dt.hour).arrest_made.mean()
# Out:
# stop_datetime
# 0.0     0.113073
# 1.0     0.140684
# 2.0     0.141698
# 3.0     0.127541
# 4.0     0.105165
# 5.0     0.063767
# 6.0     0.114924
# 7.0     0.075330
# 8.0     0.064346
# 9.0     0.061174
# 10.0    0.058614
# 11.0    0.078432
# 12.0    0.015655
# 13.0    0.053309
# 14.0    0.075281
# 15.0    0.132653
# 16.0    0.163263
# 17.0    0.171670
# 18.0    0.169753
# 19.0    0.139718
# 20.0    0.152607
# 21.0    0.125060
# 22.0    0.102684
# 23.0    0.105551
# Name: arrest_made, dtype: float64

# %%
df.groupby(df.stop_datetime.dt.hour).arrest_made.mean().plot()
# Out:
# <Axes: xlabel='stop_datetime'>

# %%
df.groupby(df.stop_datetime.dt.hour).arrest_made.sum()
# Out:
# stop_datetime
# 0.0     2542
# 1.0     1202
# 2.0      838
# 3.0      458
# 4.0      338
# 5.0      261
# 6.0      432
# 7.0     1357
# 8.0     1793
# 9.0     1820
# 10.0    1793
# 11.0    1539
# 12.0     149
# 13.0    1160
# 14.0    1499
# 15.0    3263
# 16.0    3550
# 17.0    3357
# 18.0    2695
# 19.0    1831
# 20.0    2028
# 21.0    2077
# 22.0    2211
# 23.0    1563
# Name: arrest_made, dtype: int64
