# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
iris = pd.read_csv(r'C:\Users\dell\Desktop\img\iris.data', header=None, names=["sepal_length","sepal_width", "petal_length", 
              "petal_width", "species"])
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
plt.plot(iris.sepal_length)

# %%
iris.sepal_length.plot()
# Out:
# <Axes: >

# %%
plt.plot(iris.iloc[:, 0:4])
plt.legend(iris.columns)
plt.show()

# %%
iris.plot()
# Out:
# <Axes: >

# %%
np.random.seed(11)
data = pd.Series(np.random.randn(10), index=list('abcdefghij'))
data
# Out:
# a    1.749455
# b   -0.286073
# c   -0.484565
# d   -2.653319
# e   -0.008285
# f   -0.319631
# g   -0.536629
# h    0.315403
# i    0.421051
# j   -1.065603
# dtype: float64

# %%
fig = plt.figure()
ax = fig.subplots(1,2)
ax[0].bar(x=data.index, height=data)
ax[1].barh(y=data.index, width=data)

plt.show()

# %%
np.random.seed(11)
data = pd.Series(np.random.randn(10), index=list('abcdefghij'))
data
# Out:
# a    1.749455
# b   -0.286073
# c   -0.484565
# d   -2.653319
# e   -0.008285
# f   -0.319631
# g   -0.536629
# h    0.315403
# i    0.421051
# j   -1.065603
# dtype: float64

# %%
fig, axes = plt.subplots(1, 2)
data.plot.bar(ax=axes[0], color='r', alpha=1)
data.plot(kind='barh', ax=axes[1], color='b', alpha=1)
# Out:
# <Axes: >

# %%
np.random.seed(23)
df = pd.DataFrame(data=np.random.rand(5, 3),
                 columns=pd.Index(list("ABC")),
                 index=['one', 'two', 'three', 'four', 'five'])
df
# Out:
#               A         B         C
# one    0.517298  0.946963  0.765460
# two    0.282396  0.221045  0.686222
# three  0.167139  0.392442  0.618052
# four   0.411930  0.002465  0.884032
# five   0.884948  0.300410  0.589582

# %%
df.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five'], dtype='object')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.plot(kind='bar');

# %%
df.plot.bar();

# %%
df.plot.bar(stacked=True, alpha=1);

# %%
df.plot.barh(stacked=True, alpha=1);

# %%
tips = pd.read_csv(r'C:\Users\dell\Desktop\img\tips.csv')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
count_party = pd.crosstab(index=tips['day'], columns=tips['size'])
count_party
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
tips.groupby('day').agg({'size': 'value_counts'}).unstack().fillna(0)
# Out:
#      size
# size    1     2     3     4    5    6
# day
# Fri   1.0  16.0   1.0   1.0  0.0  0.0
# Sat   2.0  53.0  18.0  13.0  1.0  0.0
# Sun   0.0  39.0  15.0  18.0  3.0  1.0
# Thur  1.0  48.0   4.0   5.0  1.0  3.0

# %%
tips.pivot_table(index='day', values=['size'], aggfunc='value_counts').unstack().fillna(value=0)
# Out:
# size    1     2     3     4    5    6
# day
# Fri   1.0  16.0   1.0   1.0  0.0  0.0
# Sat   2.0  53.0  18.0  13.0  1.0  0.0
# Sun   0.0  39.0  15.0  18.0  3.0  1.0
# Thur  1.0  48.0   4.0   5.0  1.0  3.0

# %%
count_party.plot.bar();

# %%
import seaborn as sns

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['tip_per'] = tips.tip / (tips.total_bill - tips.tip)
tips.tip_per
# Out:
# 0      0.063204
# 1      0.191244
# 2      0.199886
# 3      0.162494
# 4      0.172069
#          ...
# 239    0.256166
# 240    0.079428
# 241    0.096759
# 242    0.108899
# 243    0.190114
# Name: tip_per, Length: 244, dtype: float64

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_per
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.063204
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.191244
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.199886
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.162494
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.172069
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.256166
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.079428
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.096759
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.108899
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.190114
#
# [244 rows x 8 columns]

# %%
sns.barplot(data=tips, x='day', y='tip_per', orient='v', estimator='mean');

# %%
sns.barplot(data=tips, x='day', y='tip_per', orient='v', hue='time', estimator='mean');

# %%
tips.time.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
from matplotlib.ticker import MultipleLocator
ax = sns.barplot(data=tips, x='day', y='tip_per', orient='v', estimator='mean');
ax.yaxis.set_major_locator(MultipleLocator(base=0.01))
ax.grid()

# %%
tips.groupby('day').tip_per.mean()
# Out:
# day
# Fri     0.208598
# Sat     0.185305
# Sun     0.225718
# Thur    0.194818
# Name: tip_per, dtype: float64

# %%
tips.groupby('day').tip_per.mean().plot.bar();

# %%
from matplotlib.ticker import MultipleLocator
ax = tips.groupby('day').tip_per.mean().plot.bar();
ax.yaxis.set_major_locator(MultipleLocator(0.01))
ax.grid()

# %%
plt.bar(x=tips.groupby('day').tip_per.mean().index, height=tips.groupby('day').tip_per.mean().values);

# %%
tips.groupby('day').tip_per.mean()
# Out:
# day
# Fri     0.208598
# Sat     0.185305
# Sun     0.225718
# Thur    0.194818
# Name: tip_per, dtype: float64

# %%
tips.groupby('day').tip_per.mean().values
# Out:
# array([0.20859767, 0.1853048 , 0.22571784, 0.19481779])

# %%
tips.groupby('day').tip_per.mean().index
# Out:
# Index(['Fri', 'Sat', 'Sun', 'Thur'], dtype='object', name='day')

# %%
tips['tip_per']
# Out:
# 0      0.063204
# 1      0.191244
# 2      0.199886
# 3      0.162494
# 4      0.172069
#          ...
# 239    0.256166
# 240    0.079428
# 241    0.096759
# 242    0.108899
# 243    0.190114
# Name: tip_per, Length: 244, dtype: float64

# %%
tips['tip_per'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
tips['tip_per'].plot.hist(bins=70)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(tips['tip_per'], bins=50, color='r');

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.regplot(data=iris, x='sepal_length', y='petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(x='sepal_length', y='petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot(kind = 'scatter', x='sepal_length', y='petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
plt.scatter(data=iris, x='sepal_length', y='petal_length')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data=iris)
# Out:
# C:\Users\dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(data=iris, hue="species")
# Out:
# C:\Users\dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
pd.plotting.scatter_matrix(iris, figsize=(10, 10));

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_per
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.063204
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.191244
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.199886
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.162494
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.172069
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.256166
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.079428
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.096759
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.108899
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.190114
#
# [244 rows x 8 columns]

# %%
sns.catplot(data=tips, x='day', y='tip_per', hue='time', col='smoker', kind='bar')
# Out:
# C:\Users\dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=tips, x='day', y='tip_per', row='time', col='smoker', kind='bar')
# Out:
# C:\Users\dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
