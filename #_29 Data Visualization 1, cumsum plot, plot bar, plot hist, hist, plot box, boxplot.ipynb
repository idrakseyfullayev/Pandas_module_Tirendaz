# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
np.random.seed(11)
data = pd.Series(np.random.randn(1000).cumsum())
data.plot()
# Out:
# <Axes: >

# %%
np.random.seed(111)
df1 = pd.DataFrame(np.random.randn(100, 4),columns=list('ABCD'))
df1
# Out:
#            A         B         C         D
# 0  -1.133838  0.384319  1.496554 -0.355382
# 1  -0.787534 -0.459439 -0.059169 -0.354174
# 2  -0.735523 -1.183940  0.238894 -0.589920
# 3  -1.440585  0.773703 -1.027967 -0.090986
# 4   0.492003  0.424672  1.283049  0.315986
# ..       ...       ...       ...       ...
# 95 -0.493703  0.715037  2.866247 -0.937749
# 96  0.989114 -1.787336 -1.986321  0.997874
# 97  1.027321  0.405988 -0.947181  1.945032
# 98 -0.287698  0.215549  0.345918 -1.817811
# 99 -0.817430 -0.091703  1.589308  0.288788
#
# [100 rows x 4 columns]

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1.cumsum()
# Out:
#            A         B          C         D
# 0  -1.133838  0.384319   1.496554 -0.355382
# 1  -1.921372 -0.075120   1.437385 -0.709556
# 2  -2.656895 -1.259060   1.676279 -1.299476
# 3  -4.097480 -0.485356   0.648312 -1.390462
# 4  -3.605477 -0.060684   1.931361 -1.074476
# ..       ...       ...        ...       ...
# 95 -9.397473 -4.448742 -12.343975 -4.109807
# 96 -8.408359 -6.236077 -14.330296 -3.111933
# 97 -7.381038 -5.830089 -15.277476 -1.166901
# 98 -7.668736 -5.614540 -14.931558 -2.984712
# 99 -8.486166 -5.706243 -13.342250 -2.695924
#
# [100 rows x 4 columns]

# %%
df1.cumsum().plot()
# Out:
# <Axes: >

# %%
df1
# Out:
#            A         B         C         D
# 0  -1.133838  0.384319  1.496554 -0.355382
# 1  -0.787534 -0.459439 -0.059169 -0.354174
# 2  -0.735523 -1.183940  0.238894 -0.589920
# 3  -1.440585  0.773703 -1.027967 -0.090986
# 4   0.492003  0.424672  1.283049  0.315986
# ..       ...       ...       ...       ...
# 95 -0.493703  0.715037  2.866247 -0.937749
# 96  0.989114 -1.787336 -1.986321  0.997874
# 97  1.027321  0.405988 -0.947181  1.945032
# 98 -0.287698  0.215549  0.345918 -1.817811
# 99 -0.817430 -0.091703  1.589308  0.288788
#
# [100 rows x 4 columns]

# %%
df1.iloc[10]
# Out:
# A   -1.303570
# B    0.178105
# C   -0.334402
# D   -0.306027
# Name: 10, dtype: float64

# %%
df1.iloc[10].plot(kind='bar')
# Out:
# <Axes: >

# %%
df1.iloc[10].plot.bar()
# Out:
# <Axes: >

# %%
df1.iloc[:7].plot.bar()
# Out:
# <Axes: >

# %%
np.random.seed(234)
df2=pd.DataFrame(np.random.rand(7,3), columns=list("ABC"))
df2
# Out:
#           A         B         C
# 0  0.030967  0.254282  0.912400
# 1  0.970174  0.246620  0.698807
# 2  0.866429  0.639522  0.456844
# 3  0.498795  0.720475  0.271253
# 4  0.800619  0.509253  0.819921
# 5  0.307713  0.659278  0.313509
# 6  0.544652  0.319841  0.459153

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2
# Out:
#           A         B         C
# 0  0.030967  0.254282  0.912400
# 1  0.970174  0.246620  0.698807
# 2  0.866429  0.639522  0.456844
# 3  0.498795  0.720475  0.271253
# 4  0.800619  0.509253  0.819921
# 5  0.307713  0.659278  0.313509
# 6  0.544652  0.319841  0.459153

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df2.cumsum(axis=1)
# Out:
#           A         B         C
# 0  0.030967  0.285249  1.197650
# 1  0.970174  1.216794  1.915601
# 2  0.866429  1.505951  1.962795
# 3  0.498795  1.219270  1.490523
# 4  0.800619  1.309872  2.129793
# 5  0.307713  0.966991  1.280500
# 6  0.544652  0.864493  1.323646

# %%
df2.cumsum(axis=1).plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True).set_xlim([1,3])
# Out:
# (1.0, 3.0)

# %%
df2.plot.bar(stacked=True).set(xlim=(1,3), ylim=(0.5, 1.75))
# Out:
# [(1.0, 3.0), (0.5, 1.75)]

# %%
df2.plot.barh(stacked=True)
# Out:
# <Axes: >

# %%
iris = pd.read_csv(r'C:\Users\dell\Desktop\img\iris.data', header=None, names=["sepal_length","sepal_width", "petal_length", 
              "petal_width", "species"])
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.plot.hist(alpha=0.7)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.hist(alpha=0.7, stacked=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.hist(alpha=1, stacked=True, bins=25)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.sepal_width.plot.hist(orientation="horizontal")
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris.sepal_width.hist(orientation="horizontal")
# Out:
# <Axes: >

# %%
iris.sepal_length.hist()
# Out:
# <Axes: >

# %%
iris.sepal_length.diff().hist()
# Out:
# <Axes: >

# %%
iris.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
plt.style.use('seaborn-whitegrid')
iris.hist(color='r', alpha=0.7, bins=25)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3984\3326605462.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
iris.hist(column='petal_length', by='species')
# Out:
# array([[<Axes: title={'center': 'Iris-setosa'}>,
#         <Axes: title={'center': 'Iris-versicolor'}>],
#        [<Axes: title={'center': 'Iris-virginica'}>, <Axes: >]],
#       dtype=object)

# %%
iris.plot.hist(column='petal_length', by='species')
# Out:
# array([<Axes: title={'center': 'Iris-setosa'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'Iris-versicolor'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'Iris-virginica'}, ylabel='Frequency'>],
#       dtype=object)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.hist(by='species')
# Out:
# array([[<Axes: title={'center': 'Iris-setosa'}>,
#         <Axes: title={'center': 'Iris-versicolor'}>],
#        [<Axes: title={'center': 'Iris-virginica'}>, <Axes: >]],
#       dtype=object)

# %%
iris.hist(by='species', legend=['1', '2', '3', '4'], figsize=(11,11), bins=25)
# Out:
# array([[<Axes: title={'center': 'Iris-setosa'}>,
#         <Axes: title={'center': 'Iris-versicolor'}>],
#        [<Axes: title={'center': 'Iris-virginica'}>, <Axes: >]],
#       dtype=object)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.plot.box()
# Out:
# <Axes: >

# %%
colors={'boxes': 'Red', 'whiskers': 'blue','medians': 'Black', 'caps': 'Green'}

# %%
iris.plot.box(color=colors)
# Out:
# <Axes: >

# %%
iris.plot.box(color=colors, vert=False)
# Out:
# <Axes: >

# %%
iris.boxplot()
# Out:
# <Axes: >

# %%
iris.boxplot(vert=False)
# Out:
# <Axes: >

# %%
iris.boxplot(by='species')
# Out:
# array([[<Axes: title={'center': 'petal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='[species]'>],
#        [<Axes: title={'center': 'sepal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)

# %%
iris.boxplot(by='species', figsize=(8,8))
# Out:
# array([[<Axes: title={'center': 'petal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='[species]'>],
#        [<Axes: title={'center': 'sepal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)

# %%
plt.rcParams["figure.figsize"]=(8,8)
plt.style.use('ggplot')
iris.boxplot(by='species')
# Out:
# array([[<Axes: title={'center': 'petal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='[species]'>],
#        [<Axes: title={'center': 'sepal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)
