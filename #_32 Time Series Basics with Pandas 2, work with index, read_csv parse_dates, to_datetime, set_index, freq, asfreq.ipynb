# %%
import pandas as pd; import numpy as np

# %%
date = pd.date_range(start='2018', end='2019', freq="BM")
date
# Out:
# DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-30', '2018-04-30',
#                '2018-05-31', '2018-06-29', '2018-07-31', '2018-08-31',
#                '2018-09-28', '2018-10-31', '2018-11-30', '2018-12-31'],
#               dtype='datetime64[ns]', freq='BM')

# %%
np.random.seed(90)
tser = pd.Series(np.random.randn(len(date)), index=date)
tser
# Out:
# 2018-01-31   -0.224487
# 2018-02-28   -0.227524
# 2018-03-30   -0.591399
# 2018-04-30   -0.799228
# 2018-05-31    1.190110
# 2018-06-29   -1.365895
# 2018-07-31    0.720956
# 2018-08-31   -1.325562
# 2018-09-28    1.856932
# 2018-10-31    1.247180
# 2018-11-30   -1.354258
# 2018-12-31   -0.740473
# Freq: BM, dtype: float64

# %%
tser.index
# Out:
# DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-30', '2018-04-30',
#                '2018-05-31', '2018-06-29', '2018-07-31', '2018-08-31',
#                '2018-09-28', '2018-10-31', '2018-11-30', '2018-12-31'],
#               dtype='datetime64[ns]', freq='BM')

# %%
tser.index[:5]
# Out:
# DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-30', '2018-04-30',
#                '2018-05-31'],
#               dtype='datetime64[ns]', freq='BM')

# %%
fb = pd.read_csv(r'C:\Users\dell\Desktop\img\FB.csv')
fb
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 1    2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2    2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 3    2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 4    2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
# ..          ...         ...         ...         ...         ...         ...
# 246  2019-07-23  202.839996  204.240005  200.960007  202.360001  202.360001
# 247  2019-07-24  197.630005  204.809998  197.220001  204.660004  204.660004
# 248  2019-07-25  206.699997  208.660004  198.259995  200.710007  200.710007
# 249  2019-07-26  200.190002  202.880005  196.250000  199.750000  199.750000
# 250  2019-07-29  199.000000  199.590302  197.880005  198.059998  198.059998
#
#        Volume
# 0    65280800
# 1    40356500
# ...

# %%
fb.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
fb = pd.read_csv(r'C:\Users\dell\Desktop\img\FB.csv', parse_dates=['Date'])
fb
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 1   2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2   2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 3   2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 4   2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
# ..         ...         ...         ...         ...         ...         ...
# 246 2019-07-23  202.839996  204.240005  200.960007  202.360001  202.360001
# 247 2019-07-24  197.630005  204.809998  197.220001  204.660004  204.660004
# 248 2019-07-25  206.699997  208.660004  198.259995  200.710007  200.710007
# 249 2019-07-26  200.190002  202.880005  196.250000  199.750000  199.750000
# 250 2019-07-29  199.000000  199.590302  197.880005  198.059998  198.059998
#
#        Volume
# 0    65280800
# 1    40356500
# 2    34042100
# ...

# %%
fb.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
fb = pd.read_csv(r'C:\Users\dell\Desktop\img\FB.csv', parse_dates=['Date'], index_col='Date')
fb
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
# ...                ...         ...         ...         ...         ...
# 2019-07-23  202.839996  204.240005  200.960007  202.360001  202.360001
# 2019-07-24  197.630005  204.809998  197.220001  204.660004  204.660004
# 2019-07-25  206.699997  208.660004  198.259995  200.710007  200.710007
# 2019-07-26  200.190002  202.880005  196.250000  199.750000  199.750000
# 2019-07-29  199.000000  199.590302  197.880005  198.059998  198.059998
#
#               Volume
# Date
# 2018-07-30  65280800
# 2018-07-31  40356500
# 2018-08-01  34042100
# ...

# %%
fb.index
# Out:
# DatetimeIndex(['2018-07-30', '2018-07-31', '2018-08-01', '2018-08-02',
#                '2018-08-03', '2018-08-06', '2018-08-07', '2018-08-08',
#                '2018-08-09', '2018-08-10',
#                ...
#                '2019-07-16', '2019-07-17', '2019-07-18', '2019-07-19',
#                '2019-07-22', '2019-07-23', '2019-07-24', '2019-07-25',
#                '2019-07-26', '2019-07-29'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
fb.loc['2019-06']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-06-03  175.000000  175.050003  161.009995  164.149994  164.149994
# 2019-06-04  163.710007  168.279999  160.839996  167.500000  167.500000
# 2019-06-05  167.479996  168.720001  164.630005  168.169998  168.169998
# 2019-06-06  168.300003  169.699997  167.229996  168.330002  168.330002
# 2019-06-07  170.169998  173.869995  168.839996  173.350006  173.350006
# 2019-06-10  174.750000  177.860001  173.800003  174.820007  174.820007
# 2019-06-11  178.479996  179.979996  176.789993  178.100006  178.100006
# 2019-06-12  178.380005  179.270004  172.880005  175.039993  175.039993
# 2019-06-13  175.529999  178.029999  174.610001  177.470001  177.470001
# 2019-06-14  180.509995  181.839996  180.000000  181.330002  181.330002
# 2019-06-17  185.009995  189.500000  184.410004  189.009995  189.009995
# 2019-06-18  194.000000  194.529999  187.279999  188.470001  188.470001
# ...

# %%
fb.loc['2019-06'].agg(['mean']).iloc[:, 0:4]
# Out:
#           Open      High         Low     Close
# mean  181.6645  183.8925  178.924001  181.2745

# %%
fb.loc['2019-06'].agg(['mean']).iloc[:, 0:4].plot.bar()
# Out:
# <Axes: >

# %%
fb.loc['2019-06']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-06-03  175.000000  175.050003  161.009995  164.149994  164.149994
# 2019-06-04  163.710007  168.279999  160.839996  167.500000  167.500000
# 2019-06-05  167.479996  168.720001  164.630005  168.169998  168.169998
# 2019-06-06  168.300003  169.699997  167.229996  168.330002  168.330002
# 2019-06-07  170.169998  173.869995  168.839996  173.350006  173.350006
# 2019-06-10  174.750000  177.860001  173.800003  174.820007  174.820007
# 2019-06-11  178.479996  179.979996  176.789993  178.100006  178.100006
# 2019-06-12  178.380005  179.270004  172.880005  175.039993  175.039993
# 2019-06-13  175.529999  178.029999  174.610001  177.470001  177.470001
# 2019-06-14  180.509995  181.839996  180.000000  181.330002  181.330002
# 2019-06-17  185.009995  189.500000  184.410004  189.009995  189.009995
# 2019-06-18  194.000000  194.529999  187.279999  188.470001  188.470001
# ...

# %%
fb.loc['2019-06'].Close.mean()
# Out:
# 181.27450025000002

# %%
fb.loc['2019-06-05':'2019-06-10']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-06-05  167.479996  168.720001  164.630005  168.169998  168.169998
# 2019-06-06  168.300003  169.699997  167.229996  168.330002  168.330002
# 2019-06-07  170.169998  173.869995  168.839996  173.350006  173.350006
# 2019-06-10  174.750000  177.860001  173.800003  174.820007  174.820007
#
#               Volume
# Date
# 2019-06-05  19758300
# 2019-06-06  12446400
# 2019-06-07  16917300
# 2019-06-10  14767900

# %%
fb["2019-02":"2019-03"]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-02-01  165.839996  169.100006  165.660004  165.710007  165.710007
# 2019-02-04  165.699997  169.300003  163.619995  169.250000  169.250000
# 2019-02-05  169.149994  171.979996  168.690002  171.160004  171.160004
# 2019-02-06  171.199997  172.470001  169.270004  170.490005  170.490005
# 2019-02-07  168.199997  169.240005  165.250000  166.380005  166.380005
# 2019-02-08  164.470001  167.369995  164.210007  167.330002  167.330002
# 2019-02-11  167.899994  168.300003  165.080002  165.789993  165.789993
# 2019-02-12  166.860001  168.339996  164.500000  165.039993  165.039993
# 2019-02-13  165.380005  166.220001  163.729996  164.070007  164.070007
# 2019-02-14  163.190002  164.869995  162.250000  163.949997  163.949997
# 2019-02-15  164.509995  164.699997  160.860001  162.500000  162.500000
# 2019-02-19  160.500000  164.149994  160.330002  162.289993  162.289993
# ...

# %%
t = pd.to_datetime('7/22/2019')
t
# Out:
# Timestamp('2019-07-22 00:00:00')

# %%
fb.loc[fb.index>t, :]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-07-23  202.839996  204.240005  200.960007  202.360001  202.360001
# 2019-07-24  197.630005  204.809998  197.220001  204.660004  204.660004
# 2019-07-25  206.699997  208.660004  198.259995  200.710007  200.710007
# 2019-07-26  200.190002  202.880005  196.250000  199.750000  199.750000
# 2019-07-29  199.000000  199.590302  197.880005  198.059998  198.059998
#
#               Volume
# Date
# 2019-07-23  14583700
# 2019-07-24  32532500
# 2019-07-25  39889900
# 2019-07-26  24426700
# 2019-07-29    754198

# %%
fb.loc[fb.index>t, ['Open', 'Close']]
# Out:
#                   Open       Close
# Date
# 2019-07-23  202.839996  202.360001
# 2019-07-24  197.630005  204.660004
# 2019-07-25  206.699997  200.710007
# 2019-07-26  200.190002  199.750000
# 2019-07-29  199.000000  198.059998

# %%
fb1 = pd.read_csv(r'C:\Users\dell\Desktop\img\FB-no-date.csv', sep=';')
fb1
# Out:
#          Open       High        Low      Close  Adj Close    Volume
# 0   162600006  163130005  161690002  162279999  162279999  11097800
# 1   163899994  167500000  163830002  167369995  167369995  18894700
# 2   167369995  171880005  166550003  171259995  171259995  28187900
# 3   172899994  173570007  171270004  172509995  172509995  21531700
# 4   171500000  171740005  167610001  169130005  169130005  18306500
# 5   166199997  169619995  165970001  169600006  169600006  13184800
# 6   171600006  174300003  171580002  172070007  172070007  18884000
# 7   172089996  173800003  171220001  171919998  171919998  12155300
# 8   172320007  174029999  172119995  173369995  173369995  11973300
# 9   169759995  171149994  168160004  170169998  170169998  18037400
# 10  167160004  167580002  162509995  165979996  165979996  37135400
# 11  163570007  163899994  159279999  160470001  160470001  37524200
# 12  161479996  163820007  160820007  161570007  161570007  25611500
# ...

# %%
date = pd.date_range(start='2019/03/01', end='2019/03/29', freq='B')
date
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-04', '2019-03-05', '2019-03-06',
#                '2019-03-07', '2019-03-08', '2019-03-11', '2019-03-12',
#                '2019-03-13', '2019-03-14', '2019-03-15', '2019-03-18',
#                '2019-03-19', '2019-03-20', '2019-03-21', '2019-03-22',
#                '2019-03-25', '2019-03-26', '2019-03-27', '2019-03-28',
#                '2019-03-29'],
#               dtype='datetime64[ns]', freq='B')

# %%
fb1.index=date
fb1
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# 2019-03-01  162600006  163130005  161690002  162279999  162279999  11097800
# 2019-03-04  163899994  167500000  163830002  167369995  167369995  18894700
# 2019-03-05  167369995  171880005  166550003  171259995  171259995  28187900
# 2019-03-06  172899994  173570007  171270004  172509995  172509995  21531700
# 2019-03-07  171500000  171740005  167610001  169130005  169130005  18306500
# 2019-03-08  166199997  169619995  165970001  169600006  169600006  13184800
# 2019-03-11  171600006  174300003  171580002  172070007  172070007  18884000
# 2019-03-12  172089996  173800003  171220001  171919998  171919998  12155300
# 2019-03-13  172320007  174029999  172119995  173369995  173369995  11973300
# 2019-03-14  169759995  171149994  168160004  170169998  170169998  18037400
# 2019-03-15  167160004  167580002  162509995  165979996  165979996  37135400
# ...

# %%
fb1.index
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-04', '2019-03-05', '2019-03-06',
#                '2019-03-07', '2019-03-08', '2019-03-11', '2019-03-12',
#                '2019-03-13', '2019-03-14', '2019-03-15', '2019-03-18',
#                '2019-03-19', '2019-03-20', '2019-03-21', '2019-03-22',
#                '2019-03-25', '2019-03-26', '2019-03-27', '2019-03-28',
#                '2019-03-29'],
#               dtype='datetime64[ns]', freq='B')

# %%
fb1 = pd.read_csv(r'C:\Users\dell\Desktop\img\FB-no-date.csv', sep=';')
fb1
# Out:
#          Open       High        Low      Close  Adj Close    Volume
# 0   162600006  163130005  161690002  162279999  162279999  11097800
# 1   163899994  167500000  163830002  167369995  167369995  18894700
# 2   167369995  171880005  166550003  171259995  171259995  28187900
# 3   172899994  173570007  171270004  172509995  172509995  21531700
# 4   171500000  171740005  167610001  169130005  169130005  18306500
# 5   166199997  169619995  165970001  169600006  169600006  13184800
# 6   171600006  174300003  171580002  172070007  172070007  18884000
# 7   172089996  173800003  171220001  171919998  171919998  12155300
# 8   172320007  174029999  172119995  173369995  173369995  11973300
# 9   169759995  171149994  168160004  170169998  170169998  18037400
# 10  167160004  167580002  162509995  165979996  165979996  37135400
# 11  163570007  163899994  159279999  160470001  160470001  37524200
# 12  161479996  163820007  160820007  161570007  161570007  25611500
# ...

# %%
fb1.set_index(date, inplace=True)
fb1
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# 2019-03-01  162600006  163130005  161690002  162279999  162279999  11097800
# 2019-03-04  163899994  167500000  163830002  167369995  167369995  18894700
# 2019-03-05  167369995  171880005  166550003  171259995  171259995  28187900
# 2019-03-06  172899994  173570007  171270004  172509995  172509995  21531700
# 2019-03-07  171500000  171740005  167610001  169130005  169130005  18306500
# 2019-03-08  166199997  169619995  165970001  169600006  169600006  13184800
# 2019-03-11  171600006  174300003  171580002  172070007  172070007  18884000
# 2019-03-12  172089996  173800003  171220001  171919998  171919998  12155300
# 2019-03-13  172320007  174029999  172119995  173369995  173369995  11973300
# 2019-03-14  169759995  171149994  168160004  170169998  170169998  18037400
# 2019-03-15  167160004  167580002  162509995  165979996  165979996  37135400
# ...

# %%
fb1.index
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-04', '2019-03-05', '2019-03-06',
#                '2019-03-07', '2019-03-08', '2019-03-11', '2019-03-12',
#                '2019-03-13', '2019-03-14', '2019-03-15', '2019-03-18',
#                '2019-03-19', '2019-03-20', '2019-03-21', '2019-03-22',
#                '2019-03-25', '2019-03-26', '2019-03-27', '2019-03-28',
#                '2019-03-29'],
#               dtype='datetime64[ns]', freq='B')

# %%
# %matplotlib inline

# %%
fb1.Close
# Out:
# 2019-03-01    162279999
# 2019-03-04    167369995
# 2019-03-05    171259995
# 2019-03-06    172509995
# 2019-03-07    169130005
# 2019-03-08    169600006
# 2019-03-11    172070007
# 2019-03-12    171919998
# 2019-03-13    173369995
# 2019-03-14    170169998
# 2019-03-15    165979996
# 2019-03-18    160470001
# 2019-03-19    161570007
# 2019-03-20    165440002
# 2019-03-21    166080002
# 2019-03-22    164339996
# 2019-03-25    166289993
# 2019-03-26    167679993
# 2019-03-27    165869995
# 2019-03-28    165550003
# 2019-03-29    166690002
# Freq: B, Name: Close, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateLocator, DateFormatter, DayLocator
ax = fb1.Close.plot(xlim=[fb1.index[0], fb1.index[-1]])
ax.xaxis.set_major_locator(DayLocator(interval=1))
# set formatter
ax.xaxis.set_major_formatter(DateFormatter('%d-%m-%Y'))
# set font and rotation for date tick labels
plt.gcf().autofmt_xdate()

# %%
date
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-04', '2019-03-05', '2019-03-06',
#                '2019-03-07', '2019-03-08', '2019-03-11', '2019-03-12',
#                '2019-03-13', '2019-03-14', '2019-03-15', '2019-03-18',
#                '2019-03-19', '2019-03-20', '2019-03-21', '2019-03-22',
#                '2019-03-25', '2019-03-26', '2019-03-27', '2019-03-28',
#                '2019-03-29'],
#               dtype='datetime64[ns]', freq='B')

# %%
fb1
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# 2019-03-01  162600006  163130005  161690002  162279999  162279999  11097800
# 2019-03-04  163899994  167500000  163830002  167369995  167369995  18894700
# 2019-03-05  167369995  171880005  166550003  171259995  171259995  28187900
# 2019-03-06  172899994  173570007  171270004  172509995  172509995  21531700
# 2019-03-07  171500000  171740005  167610001  169130005  169130005  18306500
# 2019-03-08  166199997  169619995  165970001  169600006  169600006  13184800
# 2019-03-11  171600006  174300003  171580002  172070007  172070007  18884000
# 2019-03-12  172089996  173800003  171220001  171919998  171919998  12155300
# 2019-03-13  172320007  174029999  172119995  173369995  173369995  11973300
# 2019-03-14  169759995  171149994  168160004  170169998  170169998  18037400
# 2019-03-15  167160004  167580002  162509995  165979996  165979996  37135400
# ...

# %%
fb1.asfreq('D', method='pad')
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# 2019-03-01  162600006  163130005  161690002  162279999  162279999  11097800
# 2019-03-02  162600006  163130005  161690002  162279999  162279999  11097800
# 2019-03-03  162600006  163130005  161690002  162279999  162279999  11097800
# 2019-03-04  163899994  167500000  163830002  167369995  167369995  18894700
# 2019-03-05  167369995  171880005  166550003  171259995  171259995  28187900
# 2019-03-06  172899994  173570007  171270004  172509995  172509995  21531700
# 2019-03-07  171500000  171740005  167610001  169130005  169130005  18306500
# 2019-03-08  166199997  169619995  165970001  169600006  169600006  13184800
# 2019-03-09  166199997  169619995  165970001  169600006  169600006  13184800
# 2019-03-10  166199997  169619995  165970001  169600006  169600006  13184800
# 2019-03-11  171600006  174300003  171580002  172070007  172070007  18884000
# ...

# %%
fb1.asfreq('W', method='pad')
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# 2019-03-03  162600006  163130005  161690002  162279999  162279999  11097800
# 2019-03-10  166199997  169619995  165970001  169600006  169600006  13184800
# 2019-03-17  167160004  167580002  162509995  165979996  165979996  37135400
# 2019-03-24  165649994  167419998  164089996  164339996  164339996  16389200

# %%
fb1.asfreq('H', method='pad')
# Out:
#                           Open       High        Low      Close  Adj Close  \
# 2019-03-01 00:00:00  162600006  163130005  161690002  162279999  162279999
# 2019-03-01 01:00:00  162600006  163130005  161690002  162279999  162279999
# 2019-03-01 02:00:00  162600006  163130005  161690002  162279999  162279999
# 2019-03-01 03:00:00  162600006  163130005  161690002  162279999  162279999
# 2019-03-01 04:00:00  162600006  163130005  161690002  162279999  162279999
# ...                        ...        ...        ...        ...        ...
# 2019-03-28 20:00:00  164570007  166720001  163330002  165550003  165550003
# 2019-03-28 21:00:00  164570007  166720001  163330002  165550003  165550003
# 2019-03-28 22:00:00  164570007  166720001  163330002  165550003  165550003
# 2019-03-28 23:00:00  164570007  166720001  163330002  165550003  165550003
# 2019-03-29 00:00:00  166389999  167190002  164809998  166690002  166690002
#
#                        Volume
# 2019-03-01 00:00:00  11097800
# ...

# %%
z=pd.date_range(start="3/1/2019", 
                periods=60 , freq="B")
z
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-04', '2019-03-05', '2019-03-06',
#                '2019-03-07', '2019-03-08', '2019-03-11', '2019-03-12',
#                '2019-03-13', '2019-03-14', '2019-03-15', '2019-03-18',
#                '2019-03-19', '2019-03-20', '2019-03-21', '2019-03-22',
#                '2019-03-25', '2019-03-26', '2019-03-27', '2019-03-28',
#                '2019-03-29', '2019-04-01', '2019-04-02', '2019-04-03',
#                '2019-04-04', '2019-04-05', '2019-04-08', '2019-04-09',
#                '2019-04-10', '2019-04-11', '2019-04-12', '2019-04-15',
#                '2019-04-16', '2019-04-17', '2019-04-18', '2019-04-19',
#                '2019-04-22', '2019-04-23', '2019-04-24', '2019-04-25',
#                '2019-04-26', '2019-04-29', '2019-04-30', '2019-05-01',
#                '2019-05-02', '2019-05-03', '2019-05-06', '2019-05-07',
#                '2019-05-08', '2019-05-09', '2019-05-10', '2019-05-13',
# ...

# %%
z=pd.date_range(
    start="3/1/2019", periods=30, freq="H")
z
# Out:
# DatetimeIndex(['2019-03-01 00:00:00', '2019-03-01 01:00:00',
#                '2019-03-01 02:00:00', '2019-03-01 03:00:00',
#                '2019-03-01 04:00:00', '2019-03-01 05:00:00',
#                '2019-03-01 06:00:00', '2019-03-01 07:00:00',
#                '2019-03-01 08:00:00', '2019-03-01 09:00:00',
#                '2019-03-01 10:00:00', '2019-03-01 11:00:00',
#                '2019-03-01 12:00:00', '2019-03-01 13:00:00',
#                '2019-03-01 14:00:00', '2019-03-01 15:00:00',
#                '2019-03-01 16:00:00', '2019-03-01 17:00:00',
#                '2019-03-01 18:00:00', '2019-03-01 19:00:00',
#                '2019-03-01 20:00:00', '2019-03-01 21:00:00',
#                '2019-03-01 22:00:00', '2019-03-01 23:00:00',
#                '2019-03-02 00:00:00', '2019-03-02 01:00:00',
#                '2019-03-02 02:00:00', '2019-03-02 03:00:00',
#                '2019-03-02 04:00:00', '2019-03-02 05:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
np.random.seed(92929)
ts = pd.Series(np.random.randint(1, 10, len(z)), index=z)
ts
# Out:
# 2019-03-01 00:00:00    9
# 2019-03-01 01:00:00    2
# 2019-03-01 02:00:00    8
# 2019-03-01 03:00:00    2
# 2019-03-01 04:00:00    3
# 2019-03-01 05:00:00    8
# 2019-03-01 06:00:00    4
# 2019-03-01 07:00:00    2
# 2019-03-01 08:00:00    3
# 2019-03-01 09:00:00    4
# 2019-03-01 10:00:00    6
# 2019-03-01 11:00:00    4
# 2019-03-01 12:00:00    6
# 2019-03-01 13:00:00    5
# 2019-03-01 14:00:00    3
# 2019-03-01 15:00:00    8
# 2019-03-01 16:00:00    3
# 2019-03-01 17:00:00    7
# 2019-03-01 18:00:00    7
# 2019-03-01 19:00:00    8
# 2019-03-01 20:00:00    2
# 2019-03-01 21:00:00    4
# 2019-03-01 22:00:00    3
# 2019-03-01 23:00:00    8
# 2019-03-02 00:00:00    4
# 2019-03-02 01:00:00    8
# 2019-03-02 02:00:00    8
# 2019-03-02 03:00:00    7
# 2019-03-02 04:00:00    5
# 2019-03-02 05:00:00    3
# Freq: H, dtype: int32
