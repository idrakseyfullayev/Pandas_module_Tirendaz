# %%
import pandas as pd; import numpy as np

# %%
fb = pd.read_csv(r'C:\Users\dell\Desktop\img\FB.csv', parse_dates=['Date'], index_col='Date')
fb
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
# ...                ...         ...         ...         ...         ...
# 2019-07-23  202.839996  204.240005  200.960007  202.360001  202.360001
# 2019-07-24  197.630005  204.809998  197.220001  204.660004  204.660004
# 2019-07-25  206.699997  208.660004  198.259995  200.710007  200.710007
# 2019-07-26  200.190002  202.880005  196.250000  199.750000  199.750000
# 2019-07-29  199.000000  199.590302  197.880005  198.059998  198.059998
#
#               Volume
# Date
# 2018-07-30  65280800
# 2018-07-31  40356500
# 2018-08-01  34042100
# ...

# %%
fb.index
# Out:
# DatetimeIndex(['2018-07-30', '2018-07-31', '2018-08-01', '2018-08-02',
#                '2018-08-03', '2018-08-06', '2018-08-07', '2018-08-08',
#                '2018-08-09', '2018-08-10',
#                ...
#                '2019-07-16', '2019-07-17', '2019-07-18', '2019-07-19',
#                '2019-07-22', '2019-07-23', '2019-07-24', '2019-07-25',
#                '2019-07-26', '2019-07-29'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
fb.resample('M').mean()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-07-31  172.985001  174.770004  168.279999  171.820000  171.820000
# 2018-08-31  177.598695  179.433914  175.680868  177.492172  177.492172
# 2018-09-30  164.233158  166.399473  162.416843  164.377368  164.377368
# 2018-10-31  154.873479  157.124784  152.103045  154.187826  154.187826
# 2018-11-30  141.762857  143.658096  139.593336  141.635715  141.635715
# 2018-12-31  137.529475  140.493684  134.814209  137.161052  137.161052
# 2019-01-31  144.551904  147.329999  142.938095  145.422857  145.422857
# 2019-02-28  164.754735  166.534211  163.293158  164.813684  164.813684
# 2019-03-31  166.840477  168.799524  165.379525  167.411428  167.411428
# 2019-04-30  180.315239  182.084285  178.955712  180.544285  180.544285
# 2019-05-31  185.974546  187.902727  184.217273  186.082273  186.082273
# 2019-06-30  181.664500  183.892500  178.924001  181.274500  181.274500
# ...

# %%
fb.groupby(fb.index.strftime('%Y-%m')).mean()
# Out:
#                Open        High         Low       Close   Adj Close  \
# Date
# 2018-07  172.985001  174.770004  168.279999  171.820000  171.820000
# 2018-08  177.598695  179.433914  175.680868  177.492172  177.492172
# 2018-09  164.233158  166.399473  162.416843  164.377368  164.377368
# 2018-10  154.873479  157.124784  152.103045  154.187826  154.187826
# 2018-11  141.762857  143.658096  139.593336  141.635715  141.635715
# 2018-12  137.529475  140.493684  134.814209  137.161052  137.161052
# 2019-01  144.551904  147.329999  142.938095  145.422857  145.422857
# 2019-02  164.754735  166.534211  163.293158  164.813684  164.813684
# 2019-03  166.840477  168.799524  165.379525  167.411428  167.411428
# 2019-04  180.315239  182.084285  178.955712  180.544285  180.544285
# 2019-05  185.974546  187.902727  184.217273  186.082273  186.082273
# 2019-06  181.664500  183.892500  178.924001  181.274500  181.274500
# 2019-07  199.628499  201.783017  197.694002  200.097500  200.097500
#
# ...

# %%
fb.resample('M').mean()['Close']
# Out:
# Date
# 2018-07-31    171.820000
# 2018-08-31    177.492172
# 2018-09-30    164.377368
# 2018-10-31    154.187826
# 2018-11-30    141.635715
# 2018-12-31    137.161052
# 2019-01-31    145.422857
# 2019-02-28    164.813684
# 2019-03-31    167.411428
# 2019-04-30    180.544285
# 2019-05-31    186.082273
# 2019-06-30    181.274500
# 2019-07-31    200.097500
# Freq: M, Name: Close, dtype: float64

# %%
fb.resample('M')[['Close']].mean()
# Out:
#                  Close
# Date
# 2018-07-31  171.820000
# 2018-08-31  177.492172
# 2018-09-30  164.377368
# 2018-10-31  154.187826
# 2018-11-30  141.635715
# 2018-12-31  137.161052
# 2019-01-31  145.422857
# 2019-02-28  164.813684
# 2019-03-31  167.411428
# 2019-04-30  180.544285
# 2019-05-31  186.082273
# 2019-06-30  181.274500
# 2019-07-31  200.097500

# %%
fb.Close.resample('M').mean()
# Out:
# Date
# 2018-07-31    171.820000
# 2018-08-31    177.492172
# 2018-09-30    164.377368
# 2018-10-31    154.187826
# 2018-11-30    141.635715
# 2018-12-31    137.161052
# 2019-01-31    145.422857
# 2019-02-28    164.813684
# 2019-03-31    167.411428
# 2019-04-30    180.544285
# 2019-05-31    186.082273
# 2019-06-30    181.274500
# 2019-07-31    200.097500
# Freq: M, Name: Close, dtype: float64

# %%
fb.Close.resample('M').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
fb.Close.resample('Q').mean()
# Out:
# Date
# 2018-09-30    171.571135
# 2018-12-31    144.868730
# 2019-03-31    159.032458
# 2019-06-30    182.710000
# 2019-09-30    200.097500
# Freq: Q-DEC, Name: Close, dtype: float64

# %%
fb.Close.resample('Q').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
fb.Close.resample('Q').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
fb
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
# ...                ...         ...         ...         ...         ...
# 2019-07-23  202.839996  204.240005  200.960007  202.360001  202.360001
# 2019-07-24  197.630005  204.809998  197.220001  204.660004  204.660004
# 2019-07-25  206.699997  208.660004  198.259995  200.710007  200.710007
# 2019-07-26  200.190002  202.880005  196.250000  199.750000  199.750000
# 2019-07-29  199.000000  199.590302  197.880005  198.059998  198.059998
#
#               Volume
# Date
# 2018-07-30  65280800
# 2018-07-31  40356500
# 2018-08-01  34042100
# ...

# %%
fb1 = pd.DataFrame(fb.Close['2019-03'])
fb1
# Out:
#                  Close
# Date
# 2019-03-01  162.279999
# 2019-03-04  167.369995
# 2019-03-05  171.259995
# 2019-03-06  172.509995
# 2019-03-07  169.130005
# 2019-03-08  169.600006
# 2019-03-11  172.070007
# 2019-03-12  171.919998
# 2019-03-13  173.369995
# 2019-03-14  170.169998
# 2019-03-15  165.979996
# 2019-03-18  160.470001
# 2019-03-19  161.570007
# 2019-03-20  165.440002
# 2019-03-21  166.080002
# 2019-03-22  164.339996
# 2019-03-25  166.289993
# 2019-03-26  167.679993
# 2019-03-27  165.869995
# 2019-03-28  165.550003
# 2019-03-29  166.690002

# %%
fb1.shift(2)
# Out:
#                  Close
# Date
# 2019-03-01         NaN
# 2019-03-04         NaN
# 2019-03-05  162.279999
# 2019-03-06  167.369995
# 2019-03-07  171.259995
# 2019-03-08  172.509995
# 2019-03-11  169.130005
# 2019-03-12  169.600006
# 2019-03-13  172.070007
# 2019-03-14  171.919998
# 2019-03-15  173.369995
# 2019-03-18  170.169998
# 2019-03-19  165.979996
# 2019-03-20  160.470001
# 2019-03-21  161.570007
# 2019-03-22  165.440002
# 2019-03-25  166.080002
# 2019-03-26  164.339996
# 2019-03-27  166.289993
# 2019-03-28  167.679993
# 2019-03-29  165.869995

# %%
fb1.shift(-2)
# Out:
#                  Close
# Date
# 2019-03-01  171.259995
# 2019-03-04  172.509995
# 2019-03-05  169.130005
# 2019-03-06  169.600006
# 2019-03-07  172.070007
# 2019-03-08  171.919998
# 2019-03-11  173.369995
# 2019-03-12  170.169998
# 2019-03-13  165.979996
# 2019-03-14  160.470001
# 2019-03-15  161.570007
# 2019-03-18  165.440002
# 2019-03-19  166.080002
# 2019-03-20  164.339996
# 2019-03-21  166.289993
# 2019-03-22  167.679993
# 2019-03-25  165.869995
# 2019-03-26  165.550003
# 2019-03-27  166.690002
# 2019-03-28         NaN
# 2019-03-29         NaN

# %%
fb1["Previous Price"]=fb1.shift(1)
fb1
# Out:
#                  Close  Previous Price
# Date
# 2019-03-01  162.279999             NaN
# 2019-03-04  167.369995      162.279999
# 2019-03-05  171.259995      167.369995
# 2019-03-06  172.509995      171.259995
# 2019-03-07  169.130005      172.509995
# 2019-03-08  169.600006      169.130005
# 2019-03-11  172.070007      169.600006
# 2019-03-12  171.919998      172.070007
# 2019-03-13  173.369995      171.919998
# 2019-03-14  170.169998      173.369995
# 2019-03-15  165.979996      170.169998
# 2019-03-18  160.470001      165.979996
# 2019-03-19  161.570007      160.470001
# 2019-03-20  165.440002      161.570007
# 2019-03-21  166.080002      165.440002
# 2019-03-22  164.339996      166.080002
# 2019-03-25  166.289993      164.339996
# 2019-03-26  167.679993      166.289993
# 2019-03-27  165.869995      167.679993
# 2019-03-28  165.550003      165.869995
# 2019-03-29  166.690002      165.550003

# %%
fb1['one day difference'] = fb1['Close'] - fb1['Previous Price']
fb1
# Out:
#                  Close  Previous Price  one day difference
# Date
# 2019-03-01  162.279999             NaN                 NaN
# 2019-03-04  167.369995      162.279999            5.089996
# 2019-03-05  171.259995      167.369995            3.890000
# 2019-03-06  172.509995      171.259995            1.250000
# 2019-03-07  169.130005      172.509995           -3.379990
# 2019-03-08  169.600006      169.130005            0.470001
# 2019-03-11  172.070007      169.600006            2.470001
# 2019-03-12  171.919998      172.070007           -0.150009
# 2019-03-13  173.369995      171.919998            1.449997
# 2019-03-14  170.169998      173.369995           -3.199997
# 2019-03-15  165.979996      170.169998           -4.190002
# 2019-03-18  160.470001      165.979996           -5.509995
# 2019-03-19  161.570007      160.470001            1.100006
# 2019-03-20  165.440002      161.570007            3.869995
# 2019-03-21  166.080002      165.440002            0.640000
# ...

# %%
fb1["Percentage Change"]=(
    fb1["Close"]-fb1[
        "Previous Price"])*100/fb1[
    "Previous Price"]

fb1
# Out:
#                  Close  Previous Price  one day difference  Percentage Change
# Date
# 2019-03-01  162.279999             NaN                 NaN                NaN
# 2019-03-04  167.369995      162.279999            5.089996           3.136552
# 2019-03-05  171.259995      167.369995            3.890000           2.324192
# 2019-03-06  172.509995      171.259995            1.250000           0.729884
# 2019-03-07  169.130005      172.509995           -3.379990          -1.959301
# 2019-03-08  169.600006      169.130005            0.470001           0.277893
# 2019-03-11  172.070007      169.600006            2.470001           1.456368
# 2019-03-12  171.919998      172.070007           -0.150009          -0.087179
# 2019-03-13  173.369995      171.919998            1.449997           0.843414
# 2019-03-14  170.169998      173.369995           -3.199997          -1.845762
# 2019-03-15  165.979996      170.169998           -4.190002          -2.462245
# ...

# %%
fb2 = fb1[["Close"]]
fb2
# Out:
#                  Close
# Date
# 2019-03-01  162.279999
# 2019-03-04  167.369995
# 2019-03-05  171.259995
# 2019-03-06  172.509995
# 2019-03-07  169.130005
# 2019-03-08  169.600006
# 2019-03-11  172.070007
# 2019-03-12  171.919998
# 2019-03-13  173.369995
# 2019-03-14  170.169998
# 2019-03-15  165.979996
# 2019-03-18  160.470001
# 2019-03-19  161.570007
# 2019-03-20  165.440002
# 2019-03-21  166.080002
# 2019-03-22  164.339996
# 2019-03-25  166.289993
# 2019-03-26  167.679993
# 2019-03-27  165.869995
# 2019-03-28  165.550003
# 2019-03-29  166.690002

# %%
fb2.index
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-04', '2019-03-05', '2019-03-06',
#                '2019-03-07', '2019-03-08', '2019-03-11', '2019-03-12',
#                '2019-03-13', '2019-03-14', '2019-03-15', '2019-03-18',
#                '2019-03-19', '2019-03-20', '2019-03-21', '2019-03-22',
#                '2019-03-25', '2019-03-26', '2019-03-27', '2019-03-28',
#                '2019-03-29'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
fb2.asfreq('B').index
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-04', '2019-03-05', '2019-03-06',
#                '2019-03-07', '2019-03-08', '2019-03-11', '2019-03-12',
#                '2019-03-13', '2019-03-14', '2019-03-15', '2019-03-18',
#                '2019-03-19', '2019-03-20', '2019-03-21', '2019-03-22',
#                '2019-03-25', '2019-03-26', '2019-03-27', '2019-03-28',
#                '2019-03-29'],
#               dtype='datetime64[ns]', name='Date', freq='B')

# %%
fb2.index = pd.date_range(start='2019-03-01', periods=21, freq='B')
fb2.index
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-04', '2019-03-05', '2019-03-06',
#                '2019-03-07', '2019-03-08', '2019-03-11', '2019-03-12',
#                '2019-03-13', '2019-03-14', '2019-03-15', '2019-03-18',
#                '2019-03-19', '2019-03-20', '2019-03-21', '2019-03-22',
#                '2019-03-25', '2019-03-26', '2019-03-27', '2019-03-28',
#                '2019-03-29'],
#               dtype='datetime64[ns]', freq='B')

# %%
fb2
# Out:
#                  Close
# 2019-03-01  162.279999
# 2019-03-04  167.369995
# 2019-03-05  171.259995
# 2019-03-06  172.509995
# 2019-03-07  169.130005
# 2019-03-08  169.600006
# 2019-03-11  172.070007
# 2019-03-12  171.919998
# 2019-03-13  173.369995
# 2019-03-14  170.169998
# 2019-03-15  165.979996
# 2019-03-18  160.470001
# 2019-03-19  161.570007
# 2019-03-20  165.440002
# 2019-03-21  166.080002
# 2019-03-22  164.339996
# 2019-03-25  166.289993
# 2019-03-26  167.679993
# 2019-03-27  165.869995
# 2019-03-28  165.550003
# 2019-03-29  166.690002

# %%
fb2[['Close']].shift(1)
# Out:
#                  Close
# 2019-03-01         NaN
# 2019-03-04  162.279999
# 2019-03-05  167.369995
# 2019-03-06  171.259995
# 2019-03-07  172.509995
# 2019-03-08  169.130005
# 2019-03-11  169.600006
# 2019-03-12  172.070007
# 2019-03-13  171.919998
# 2019-03-14  173.369995
# 2019-03-15  170.169998
# 2019-03-18  165.979996
# 2019-03-19  160.470001
# 2019-03-20  161.570007
# 2019-03-21  165.440002
# 2019-03-22  166.080002
# 2019-03-25  164.339996
# 2019-03-26  166.289993
# 2019-03-27  167.679993
# 2019-03-28  165.869995
# 2019-03-29  165.550003

# %%
fb2.shift(1)
# Out:
#                  Close
# 2019-03-01         NaN
# 2019-03-04  162.279999
# 2019-03-05  167.369995
# 2019-03-06  171.259995
# 2019-03-07  172.509995
# 2019-03-08  169.130005
# 2019-03-11  169.600006
# 2019-03-12  172.070007
# 2019-03-13  171.919998
# 2019-03-14  173.369995
# 2019-03-15  170.169998
# 2019-03-18  165.979996
# 2019-03-19  160.470001
# 2019-03-20  161.570007
# 2019-03-21  165.440002
# 2019-03-22  166.080002
# 2019-03-25  164.339996
# 2019-03-26  166.289993
# 2019-03-27  167.679993
# 2019-03-28  165.869995
# 2019-03-29  165.550003

# %%
fb2
# Out:
#                  Close
# 2019-03-01  162.279999
# 2019-03-04  167.369995
# 2019-03-05  171.259995
# 2019-03-06  172.509995
# 2019-03-07  169.130005
# 2019-03-08  169.600006
# 2019-03-11  172.070007
# 2019-03-12  171.919998
# 2019-03-13  173.369995
# 2019-03-14  170.169998
# 2019-03-15  165.979996
# 2019-03-18  160.470001
# 2019-03-19  161.570007
# 2019-03-20  165.440002
# 2019-03-21  166.080002
# 2019-03-22  164.339996
# 2019-03-25  166.289993
# 2019-03-26  167.679993
# 2019-03-27  165.869995
# 2019-03-28  165.550003
# 2019-03-29  166.690002

# %%
fb2.index=fb2.index.shift(1)

# %%
fb2
# Out:
#                  Close
# 2019-03-04  162.279999
# 2019-03-05  167.369995
# 2019-03-06  171.259995
# 2019-03-07  172.509995
# 2019-03-08  169.130005
# 2019-03-11  169.600006
# 2019-03-12  172.070007
# 2019-03-13  171.919998
# 2019-03-14  173.369995
# 2019-03-15  170.169998
# 2019-03-18  165.979996
# 2019-03-19  160.470001
# 2019-03-20  161.570007
# 2019-03-21  165.440002
# 2019-03-22  166.080002
# 2019-03-25  164.339996
# 2019-03-26  166.289993
# 2019-03-27  167.679993
# 2019-03-28  165.869995
# 2019-03-29  165.550003
# 2019-04-01  166.690002

# %%
fb2.index=fb2.index.shift(-2)

# %%
fb2
# Out:
#                  Close
# 2019-02-28  162.279999
# 2019-03-01  167.369995
# 2019-03-04  171.259995
# 2019-03-05  172.509995
# 2019-03-06  169.130005
# 2019-03-07  169.600006
# 2019-03-08  172.070007
# 2019-03-11  171.919998
# 2019-03-12  173.369995
# 2019-03-13  170.169998
# 2019-03-14  165.979996
# 2019-03-15  160.470001
# 2019-03-18  161.570007
# 2019-03-19  165.440002
# 2019-03-20  166.080002
# 2019-03-21  164.339996
# 2019-03-22  166.289993
# 2019-03-25  167.679993
# 2019-03-26  165.869995
# 2019-03-27  165.550003
# 2019-03-28  166.690002

# %%
fb
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
# ...                ...         ...         ...         ...         ...
# 2019-07-23  202.839996  204.240005  200.960007  202.360001  202.360001
# 2019-07-24  197.630005  204.809998  197.220001  204.660004  204.660004
# 2019-07-25  206.699997  208.660004  198.259995  200.710007  200.710007
# 2019-07-26  200.190002  202.880005  196.250000  199.750000  199.750000
# 2019-07-29  199.000000  199.590302  197.880005  198.059998  198.059998
#
#               Volume
# Date
# 2018-07-30  65280800
# 2018-07-31  40356500
# 2018-08-01  34042100
# ...

# %%
fb.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
fb.Close.rolling(30).mean()
# Out:
# Date
# 2018-07-30           NaN
# 2018-07-31           NaN
# 2018-08-01           NaN
# 2018-08-02           NaN
# 2018-08-03           NaN
#                  ...
# 2019-07-23    193.598000
# 2019-07-24    194.483333
# 2019-07-25    195.339000
# 2019-07-26    196.081667
# 2019-07-29    196.639333
# Name: Close, Length: 251, dtype: float64

# %%
# %matplotlib inline
fb.Close.rolling(30).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
import pytz

# %%
pytz.timezone("Asia/Baku")
# Out:
# <DstTzInfo 'Asia/Baku' LMT+3:19:00 STD>

# %%
pytz.timezone("Turkey")
# Out:
# <DstTzInfo 'Turkey' LMT+1:56:00 STD>

# %%
pytz.timezone("America/New_York")
# Out:
# <DstTzInfo 'America/New_York' LMT-1 day, 19:04:00 STD>

# %%
pytz.common_timezones[-7:]
# Out:
# ['US/Arizona',
#  'US/Central',
#  'US/Eastern',
#  'US/Hawaii',
#  'US/Mountain',
#  'US/Pacific',
#  'UTC']

# %%
x=pd.date_range("12/9/2009 9:30", 
                periods=6, freq="D")
x
# Out:
# DatetimeIndex(['2009-12-09 09:30:00', '2009-12-10 09:30:00',
#                '2009-12-11 09:30:00', '2009-12-12 09:30:00',
#                '2009-12-13 09:30:00', '2009-12-14 09:30:00'],
#               dtype='datetime64[ns]', freq='D')

# %%
np.random.seed(23)
ts = pd.Series(np.random.randn(len(x)), index=x)
ts
# Out:
# 2009-12-09 09:30:00    0.666988
# 2009-12-10 09:30:00    0.025813
# 2009-12-11 09:30:00   -0.777619
# 2009-12-12 09:30:00    0.948634
# 2009-12-13 09:30:00    0.701672
# 2009-12-14 09:30:00   -1.051082
# Freq: D, dtype: float64

# %%
print(ts.index.tz)
# Out:
# None

# %%
ts_utc=ts.tz_localize("UTC")
ts_utc
# Out:
# 2009-12-09 09:30:00+00:00    0.666988
# 2009-12-10 09:30:00+00:00    0.025813
# 2009-12-11 09:30:00+00:00   -0.777619
# 2009-12-12 09:30:00+00:00    0.948634
# 2009-12-13 09:30:00+00:00    0.701672
# 2009-12-14 09:30:00+00:00   -1.051082
# Freq: D, dtype: float64

# %%
ts
# Out:
# 2009-12-09 09:30:00    0.666988
# 2009-12-10 09:30:00    0.025813
# 2009-12-11 09:30:00   -0.777619
# 2009-12-12 09:30:00    0.948634
# 2009-12-13 09:30:00    0.701672
# 2009-12-14 09:30:00   -1.051082
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("Asia/Baku")
# Out:
# 2009-12-09 13:30:00+04:00    0.666988
# 2009-12-10 13:30:00+04:00    0.025813
# 2009-12-11 13:30:00+04:00   -0.777619
# 2009-12-12 13:30:00+04:00    0.948634
# 2009-12-13 13:30:00+04:00    0.701672
# 2009-12-14 13:30:00+04:00   -1.051082
# Freq: D, dtype: float64

# %%
zstamp=pd.Timestamp("2019-06-26 05:00")
zstamp
# Out:
# Timestamp('2019-06-26 05:00:00')

# %%
zstamp_utc = zstamp.tz_localize('UTC')
zstamp_utc
# Out:
# Timestamp('2019-06-26 05:00:00+0000', tz='UTC')

# %%
zstamp_utc.tz_convert('Asia/Baku')
# Out:
# Timestamp('2019-06-26 09:00:00+0400', tz='Asia/Baku')

# %%
ts
# Out:
# 2009-12-09 09:30:00    0.666988
# 2009-12-10 09:30:00    0.025813
# 2009-12-11 09:30:00   -0.777619
# 2009-12-12 09:30:00    0.948634
# 2009-12-13 09:30:00    0.701672
# 2009-12-14 09:30:00   -1.051082
# Freq: D, dtype: float64

# %%
ts1 = ts[:5].tz_localize("Europe/Berlin")
ts1
# Out:
# 2009-12-09 09:30:00+01:00    0.666988
# 2009-12-10 09:30:00+01:00    0.025813
# 2009-12-11 09:30:00+01:00   -0.777619
# 2009-12-12 09:30:00+01:00    0.948634
# 2009-12-13 09:30:00+01:00    0.701672
# dtype: float64

# %%
ts2 = ts[2:].tz_localize("Europe/Istanbul")
ts2
# Out:
# 2009-12-11 09:30:00+02:00   -0.777619
# 2009-12-12 09:30:00+02:00    0.948634
# 2009-12-13 09:30:00+02:00    0.701672
# 2009-12-14 09:30:00+02:00   -1.051082
# dtype: float64

# %%
result = ts1+ts2
result
# Out:
# 2009-12-09 08:30:00+00:00   NaN
# 2009-12-10 08:30:00+00:00   NaN
# 2009-12-11 07:30:00+00:00   NaN
# 2009-12-11 08:30:00+00:00   NaN
# 2009-12-12 07:30:00+00:00   NaN
# 2009-12-12 08:30:00+00:00   NaN
# 2009-12-13 07:30:00+00:00   NaN
# 2009-12-13 08:30:00+00:00   NaN
# 2009-12-14 07:30:00+00:00   NaN
# dtype: float64

# %%
result.index
# Out:
# DatetimeIndex(['2009-12-09 08:30:00+00:00', '2009-12-10 08:30:00+00:00',
#                '2009-12-11 07:30:00+00:00', '2009-12-11 08:30:00+00:00',
#                '2009-12-12 07:30:00+00:00', '2009-12-12 08:30:00+00:00',
#                '2009-12-13 07:30:00+00:00', '2009-12-13 08:30:00+00:00',
#                '2009-12-14 07:30:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq=None)
