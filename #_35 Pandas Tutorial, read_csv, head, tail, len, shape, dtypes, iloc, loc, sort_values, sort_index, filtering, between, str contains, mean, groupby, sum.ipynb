# %%
import pandas as pd

# %%
pd.read_csv(r'vgsalesGlobale.csv')
# Out:
#      Rank                           Name         Platform  Year    Genre  \
# 0       1  Syrup - Monin - Passion Fruit  Nintendo Switch  2008   Action
# 1       2                           Yams  Nintendo Switch  2010   Sports
# 2       3                  Pepsi, 355 Ml              PS4  1985   Sports
# 3       4                        Gherkin         Xbox One  2016   Action
# 4       5  Pastry - French Mini Assorted  Nintendo Switch  2020  Shooter
# ..    ...                            ...              ...   ...      ...
# 995   996     Shrimp - Black Tiger 16/20         Xbox One  1985   Sports
# 996   997     Muffin Mix - Morning Glory         Xbox One  2011  Shooter
# 997   998       Muffin Orange Individual              PS4  1996   Action
# 998   999                  Sage - Ground              PS4  1997   Sports
# 999  1000          Cheese - Swiss Sliced         Xbox One  1996   Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
games = pd.read_csv(r'vgsalesGlobale.csv', index_col='Name')
games
# Out:
#                                Rank         Platform  Year    Genre  \
# Name
# Syrup - Monin - Passion Fruit     1  Nintendo Switch  2008   Action
# Yams                              2  Nintendo Switch  2010   Sports
# Pepsi, 355 Ml                     3              PS4  1985   Sports
# Gherkin                           4         Xbox One  2016   Action
# Pastry - French Mini Assorted     5  Nintendo Switch  2020  Shooter
# ...                             ...              ...   ...      ...
# Shrimp - Black Tiger 16/20      996         Xbox One  1985   Sports
# Muffin Mix - Morning Glory      997         Xbox One  2011  Shooter
# Muffin Orange Individual        998              PS4  1996   Action
# Sage - Ground                   999              PS4  1997   Sports
# Cheese - Swiss Sliced          1000         Xbox One  1996   Action
#
#                                 Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games.tail(5)
# Out:
#                             Rank  Platform  Year    Genre   Publisher  \
# Name
# Shrimp - Black Tiger 16/20   996  Xbox One  1985   Sports    Edgewire
# Muffin Mix - Morning Glory   997  Xbox One  2011  Shooter       Skyba
# Muffin Orange Individual     998       PS4  1996   Action  Topicstorm
# Sage - Ground                999       PS4  1997   Sports  Jabbertype
# Cheese - Swiss Sliced       1000  Xbox One  1996   Action      Voonyx
#
#                             NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Shrimp - Black Tiger 16/20     77.09      3.36      0.69        10.33
# Muffin Mix - Morning Glory      5.14      8.72      4.02         7.42
# Muffin Orange Individual       19.89     27.42      4.02         4.12
# Sage - Ground                  38.59      7.22      6.20         3.71
# Cheese - Swiss Sliced          58.61     21.83      5.89         2.65
#
#                             Global_Sales
# Name
# Shrimp - Black Tiger 16/20          0.34
# ...

# %%
games.tail(10)
# Out:
#                               Rank         Platform  Year    Genre  \
# Name
# Cabbage - Green                991         Xbox One  1989   Sports
# Lettuce - Mini Greens, Whole   992  Nintendo Switch  1985   Sports
# Wine - Barbera Alba Doc 2001   993              PS4  2001   Sports
# Apple - Granny Smith           994  Nintendo Switch  2019   Sports
# Sausage - Chorizo              995         Xbox One  1990   Action
# Shrimp - Black Tiger 16/20     996         Xbox One  1985   Sports
# Muffin Mix - Morning Glory     997         Xbox One  2011  Shooter
# Muffin Orange Individual       998              PS4  1996   Action
# Sage - Ground                  999              PS4  1997   Sports
# Cheese - Swiss Sliced         1000         Xbox One  1996   Action
#
#                                 Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# Cabbage - Green               Twitterlist     22.59     22.05      8.40
# ...

# %%
len(games)
# Out:
# 1000

# %%
games.shape
# Out:
# (1000, 10)

# %%
games.dtypes
# Out:
# Rank              int64
# Platform         object
# Year              int64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
games.iloc[[299]]
# Out:
#                 Rank  Platform  Year   Genre Publisher  NA_Sales  EU_Sales  \
# Name
# English Muffin   300  Xbox One  1981  Sports      Viva     39.68     10.04
#
#                 JP_Sales  Other_Sales  Global_Sales
# Name
# English Muffin      0.23         4.64          9.64

# %%
games.loc[games.index.str.contains('super', case=False), :]
# Out:
#                             Rank         Platform  Year    Genre    Publisher  \
# Name
# Ice Cream - Super Sandwich    72              PS4  2018   Sports       Skaboo
# Ice Cream - Super Sandwich   303              PS4  2012   Action       Wikizz
# Flour Pastry Super Fine      377  Nintendo Switch  1991   Action         Zava
# Ice Cream - Super Sandwich   470  Nintendo Switch  2018  Shooter  Thoughtbeat
#
#                             NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Ice Cream - Super Sandwich     18.18     21.35      8.41         8.52
# Ice Cream - Super Sandwich     78.54     22.62      5.04         6.65
# Flour Pastry Super Fine         2.52      0.90      4.28         5.60
# Ice Cream - Super Sandwich     53.78     17.61      0.16         9.85
#
#                             Global_Sales
# Name
# Ice Cream - Super Sandwich          2.73
# Ice Cream - Super Sandwich          7.36
# Flour Pastry Super Fine             5.00
# ...

# %%
games
# Out:
#                                Rank         Platform  Year    Genre  \
# Name
# Syrup - Monin - Passion Fruit     1  Nintendo Switch  2008   Action
# Yams                              2  Nintendo Switch  2010   Sports
# Pepsi, 355 Ml                     3              PS4  1985   Sports
# Gherkin                           4         Xbox One  2016   Action
# Pastry - French Mini Assorted     5  Nintendo Switch  2020  Shooter
# ...                             ...              ...   ...      ...
# Shrimp - Black Tiger 16/20      996         Xbox One  1985   Sports
# Muffin Mix - Morning Glory      997         Xbox One  2011  Shooter
# Muffin Orange Individual        998              PS4  1996   Action
# Sage - Ground                   999              PS4  1997   Sports
# Cheese - Swiss Sliced          1000         Xbox One  1996   Action
#
#                                 Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games.sort_values(by='Year')
# Out:
#                              Rank         Platform  Year    Genre  Publisher  \
# Name
# Wine - Sogrape Mateus Rose    953         Xbox One  1980   Action     Wikizz
# Chicken - Livers              785              PS4  1980   Action   Cogilith
# Steampan - Foil               744              PS4  1980  Shooter       Kare
# V8 - Vegetable Cocktail       245         Xbox One  1980   Sports  Bubblebox
# Pasta - Rotini, Colour, Dry   586              PS4  1980   Action  Photobean
# ...                           ...              ...   ...      ...        ...
# Bread Base - Toscano          870         Xbox One  2022   Action       Jayo
# Curry Paste - Green Masala    372              PS4  2022   Sports  Buzzshare
# Tumeric                       818         Xbox One  2022  Shooter    Dabtype
# Wine - Gato Negro Cabernet    191         Xbox One  2022  Shooter       Yodo
# Pears - Bartlett              446  Nintendo Switch  2022   Action  Reallinks
#
# ...

# %%
games.sort_values(by='Year', ascending=False)
# Out:
#                                 Rank         Platform  Year    Genre  \
# Name
# Bread Base - Toscano             870         Xbox One  2022   Action
# Cheese - Woolwich Goat, Log      264         Xbox One  2022   Action
# Wine - Harrow Estates, Vidal     251              PS4  2022   Action
# Tumeric                          818         Xbox One  2022  Shooter
# Beer - Original Organic Lager    225              PS4  2022   Action
# ...                              ...              ...   ...      ...
# Steampan - Foil                  744              PS4  1980  Shooter
# Wine - Puligny Montrachet A.     280  Nintendo Switch  1980   Action
# Pasta - Lasagna Noodle, Frozen    91         Xbox One  1980  Shooter
# Chicken - Livers                 785              PS4  1980   Action
# V8 Pet                           762         Xbox One  1980   Sports
#
#                                Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games.sort_values(by=['Year', "Genre"], ascending=False)
# Out:
#                                  Rank         Platform  Year   Genre  \
# Name
# Stock - Beef, Brown                13         Xbox One  2022  Sports
# Pie Box - Cello Window 2.5         86              PS4  2022  Sports
# Curry Paste - Green Masala        372              PS4  2022  Sports
# Horseradish - Prepared            672  Nintendo Switch  2022  Sports
# Pineapple - Canned, Rings         713         Xbox One  2022  Sports
# ...                               ...              ...   ...     ...
# Pasta - Rotini, Colour, Dry       586              PS4  1980  Action
# Beans - Navy, Dry                 620  Nintendo Switch  1980  Action
# Chicken - Livers                  785              PS4  1980  Action
# Ice - Clear, 300 Lb For Carving   796              PS4  1980  Action
# Wine - Sogrape Mateus Rose        953         Xbox One  1980  Action
#
#                                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games.sort_values(by=['Year', "Genre"], ascending=[False, True])
# Out:
#                                Rank         Platform  Year    Genre  \
# Name
# Noodles - Cellophane, Thin       33         Xbox One  2022   Action
# Trout - Hot Smkd, Dbl Fillet     38              PS4  2022   Action
# Beer - Original Organic Lager   225              PS4  2022   Action
# Wine - Harrow Estates, Vidal    251              PS4  2022   Action
# Cheese - Woolwich Goat, Log     264         Xbox One  2022   Action
# ...                             ...              ...   ...      ...
# Rabbit - Saddles                434         Xbox One  1980  Shooter
# Steampan - Foil                 744              PS4  1980  Shooter
# V8 - Vegetable Cocktail         245         Xbox One  1980   Sports
# Nori Sea Weed - Gold Label      554  Nintendo Switch  1980   Sports
# V8 Pet                          762         Xbox One  1980   Sports
#
#                                 Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games.sort_index()
# Out:
#                                Rank         Platform  Year    Genre  \
# Name
# Alize Sunset                    908         Xbox One  1992  Shooter
# Anchovy Fillets                 591              PS4  1995   Action
# Anchovy Fillets                 517  Nintendo Switch  1992   Action
# Appetizer - Asian Shrimp Roll    56  Nintendo Switch  1994  Shooter
# Appetizer - Asian Shrimp Roll   783  Nintendo Switch  2014  Shooter
# ...                             ...              ...   ...      ...
# Yogurt - French Vanilla         442         Xbox One  2019  Shooter
# Yogurt - Plain                  907  Nintendo Switch  1987   Sports
# Yucca                           513              PS4  2014   Sports
# Yukon Jack                      237  Nintendo Switch  1990   Action
# Zucchini - Mini, Green          275         Xbox One  1988   Action
#
#                                   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games
# Out:
#                                Rank         Platform  Year    Genre  \
# Name
# Syrup - Monin - Passion Fruit     1  Nintendo Switch  2008   Action
# Yams                              2  Nintendo Switch  2010   Sports
# Pepsi, 355 Ml                     3              PS4  1985   Sports
# Gherkin                           4         Xbox One  2016   Action
# Pastry - French Mini Assorted     5  Nintendo Switch  2020  Shooter
# ...                             ...              ...   ...      ...
# Shrimp - Black Tiger 16/20      996         Xbox One  1985   Sports
# Muffin Mix - Morning Glory      997         Xbox One  2011  Shooter
# Muffin Orange Individual        998              PS4  1996   Action
# Sage - Ground                   999              PS4  1997   Sports
# Cheese - Swiss Sliced          1000         Xbox One  1996   Action
#
#                                 Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games.sort_index(axis=1)
# Out:
#                                EU_Sales    Genre  Global_Sales  JP_Sales  \
# Name
# Syrup - Monin - Passion Fruit     20.44   Action          7.01      8.39
# Yams                               8.40   Sports          6.33      9.66
# Pepsi, 355 Ml                     17.96   Sports          5.63      7.15
# Gherkin                            5.60   Action          1.23      5.64
# Pastry - French Mini Assorted     24.00  Shooter          3.66      5.59
# ...                                 ...      ...           ...       ...
# Shrimp - Black Tiger 16/20         3.36   Sports          0.34      0.69
# Muffin Mix - Morning Glory         8.72  Shooter          8.20      4.02
# Muffin Orange Individual          27.42   Action          0.65      4.02
# Sage - Ground                      7.22   Sports          0.09      6.20
# Cheese - Swiss Sliced             21.83   Action          0.50      5.89
#
#                                NA_Sales  Other_Sales         Platform  \
# Name
# ...

# %%
games['Publisher']
# Out:
# Name
# Syrup - Monin - Passion Fruit      Devshare
# Yams                                   Muxo
# Pepsi, 355 Ml                         Eidel
# Gherkin                               Mynte
# Pastry - French Mini Assorted         Quinu
#                                     ...
# Shrimp - Black Tiger 16/20         Edgewire
# Muffin Mix - Morning Glory            Skyba
# Muffin Orange Individual         Topicstorm
# Sage - Ground                    Jabbertype
# Cheese - Swiss Sliced                Voonyx
# Name: Publisher, Length: 1000, dtype: object

# %%
games[['Publisher']]
# Out:
#                                 Publisher
# Name
# Syrup - Monin - Passion Fruit    Devshare
# Yams                                 Muxo
# Pepsi, 355 Ml                       Eidel
# Gherkin                             Mynte
# Pastry - French Mini Assorted       Quinu
# ...                                   ...
# Shrimp - Black Tiger 16/20       Edgewire
# Muffin Mix - Morning Glory          Skyba
# Muffin Orange Individual       Topicstorm
# Sage - Ground                  Jabbertype
# Cheese - Swiss Sliced              Voonyx
#
# [1000 rows x 1 columns]

# %%
games.loc[:, ['Publisher']]
# Out:
#                                 Publisher
# Name
# Syrup - Monin - Passion Fruit    Devshare
# Yams                                 Muxo
# Pepsi, 355 Ml                       Eidel
# Gherkin                             Mynte
# Pastry - French Mini Assorted       Quinu
# ...                                   ...
# Shrimp - Black Tiger 16/20       Edgewire
# Muffin Mix - Morning Glory          Skyba
# Muffin Orange Individual       Topicstorm
# Sage - Ground                  Jabbertype
# Cheese - Swiss Sliced              Voonyx
#
# [1000 rows x 1 columns]

# %%
games.iloc[:, [4]].head(10)
# Out:
#                                    Publisher
# Name
# Syrup - Monin - Passion Fruit       Devshare
# Yams                                    Muxo
# Pepsi, 355 Ml                          Eidel
# Gherkin                                Mynte
# Pastry - French Mini Assorted          Quinu
# Pastry - Banana Muffin - Mini        Myworks
# Nantucket Pine Orangebanana          Gabcube
# Island Oasis - Raspberry           Gigashots
# Nori Sea Weed                        Myworks
# Cheese - Taleggio D.o.p.       Chatterbridge

# %%
games
# Out:
#                                Rank         Platform  Year    Genre  \
# Name
# Syrup - Monin - Passion Fruit     1  Nintendo Switch  2008   Action
# Yams                              2  Nintendo Switch  2010   Sports
# Pepsi, 355 Ml                     3              PS4  1985   Sports
# Gherkin                           4         Xbox One  2016   Action
# Pastry - French Mini Assorted     5  Nintendo Switch  2020  Shooter
# ...                             ...              ...   ...      ...
# Shrimp - Black Tiger 16/20      996         Xbox One  1985   Sports
# Muffin Mix - Morning Glory      997         Xbox One  2011  Shooter
# Muffin Orange Individual        998              PS4  1996   Action
# Sage - Ground                   999              PS4  1997   Sports
# Cheese - Swiss Sliced          1000         Xbox One  1996   Action
#
#                                 Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games[games['Genre']=='Action']
# Out:
#                                Rank         Platform  Year   Genre  \
# Name
# Syrup - Monin - Passion Fruit     1  Nintendo Switch  2008  Action
# Gherkin                           4         Xbox One  2016  Action
# Nantucket Pine Orangebanana       7         Xbox One  2017  Action
# Island Oasis - Raspberry          8              PS4  1999  Action
# Cheese - Taleggio D.o.p.         10  Nintendo Switch  2005  Action
# ...                             ...              ...   ...     ...
# Danishes - Mini Raspberry       985              PS4  2000  Action
# Fireball Whisky                 990              PS4  2008  Action
# Sausage - Chorizo               995         Xbox One  1990  Action
# Muffin Orange Individual        998              PS4  1996  Action
# Cheese - Swiss Sliced          1000         Xbox One  1996  Action
#
#                                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games.loc[games['Genre']=='Action', :]
# Out:
#                                Rank         Platform  Year   Genre  \
# Name
# Syrup - Monin - Passion Fruit     1  Nintendo Switch  2008  Action
# Gherkin                           4         Xbox One  2016  Action
# Nantucket Pine Orangebanana       7         Xbox One  2017  Action
# Island Oasis - Raspberry          8              PS4  1999  Action
# Cheese - Taleggio D.o.p.         10  Nintendo Switch  2005  Action
# ...                             ...              ...   ...     ...
# Danishes - Mini Raspberry       985              PS4  2000  Action
# Fireball Whisky                 990              PS4  2008  Action
# Sausage - Chorizo               995         Xbox One  1990  Action
# Muffin Orange Individual        998              PS4  1996  Action
# Cheese - Swiss Sliced          1000         Xbox One  1996  Action
#
#                                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games.loc[games.loc[:, 'Genre']=='Action', :]
# Out:
#                                Rank         Platform  Year   Genre  \
# Name
# Syrup - Monin - Passion Fruit     1  Nintendo Switch  2008  Action
# Gherkin                           4         Xbox One  2016  Action
# Nantucket Pine Orangebanana       7         Xbox One  2017  Action
# Island Oasis - Raspberry          8              PS4  1999  Action
# Cheese - Taleggio D.o.p.         10  Nintendo Switch  2005  Action
# ...                             ...              ...   ...     ...
# Danishes - Mini Raspberry       985              PS4  2000  Action
# Fireball Whisky                 990              PS4  2008  Action
# Sausage - Chorizo               995         Xbox One  1990  Action
# Muffin Orange Individual        998              PS4  1996  Action
# Cheese - Swiss Sliced          1000         Xbox One  1996  Action
#
#                                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games_by_genre = games.Genre=='Action'
games[games_by_genre]
# Out:
#                                Rank         Platform  Year   Genre  \
# Name
# Syrup - Monin - Passion Fruit     1  Nintendo Switch  2008  Action
# Gherkin                           4         Xbox One  2016  Action
# Nantucket Pine Orangebanana       7         Xbox One  2017  Action
# Island Oasis - Raspberry          8              PS4  1999  Action
# Cheese - Taleggio D.o.p.         10  Nintendo Switch  2005  Action
# ...                             ...              ...   ...     ...
# Danishes - Mini Raspberry       985              PS4  2000  Action
# Fireball Whisky                 990              PS4  2008  Action
# Sausage - Chorizo               995         Xbox One  1990  Action
# Muffin Orange Individual        998              PS4  1996  Action
# Cheese - Swiss Sliced          1000         Xbox One  1996  Action
#
#                                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games_in_2010 = games.Year==2010
games[games_in_2010]
# Out:
#                               Rank         Platform  Year    Genre  \
# Name
# Yams                             2  Nintendo Switch  2010   Sports
# Soup - Campbells                12              PS4  2010  Shooter
# Shrimp - 31/40                  43         Xbox One  2010   Action
# Rabbit - Whole                 151              PS4  2010  Shooter
# Breadfruit                     189         Xbox One  2010  Shooter
# Cookies Almond Hazelnut        201              PS4  2010   Action
# Asparagus - White, Fresh       208         Xbox One  2010   Action
# Crab - Imitation Flakes        310              PS4  2010  Shooter
# Appetizer - Mushroom Tart      325              PS4  2010  Shooter
# Soup - Campbells Chili         392         Xbox One  2010   Sports
# Lamb - Whole Head Off          402  Nintendo Switch  2010   Action
# Vanilla Beans                  437         Xbox One  2010   Sports
# Halibut - Steaks               476  Nintendo Switch  2010   Sports
# ...

# %%
games[games_by_genre & games_in_2010]
# Out:
#                               Rank         Platform  Year   Genre Publisher  \
# Name
# Shrimp - 31/40                  43         Xbox One  2010  Action     Meemm
# Cookies Almond Hazelnut        201              PS4  2010  Action   Jaxspan
# Asparagus - White, Fresh       208         Xbox One  2010  Action  Gigazoom
# Lamb - Whole Head Off          402  Nintendo Switch  2010  Action      Lajo
# Ginsing - Fresh                553              PS4  2010  Action    Podcat
# Bread - Corn Muffaleta Onion   622              PS4  2010  Action  Brainbox
#
#                               NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Shrimp - 31/40                   62.27     10.05      8.27         5.03
# Cookies Almond Hazelnut          73.91      7.98      5.92         0.46
# Asparagus - White, Fresh          5.07      5.67      0.61         3.65
# Lamb - Whole Head Off            75.22      1.09      7.25         8.57
# ...

# %%
games[games_by_genre | games_in_2010]
# Out:
#                                Rank         Platform  Year   Genre  \
# Name
# Syrup - Monin - Passion Fruit     1  Nintendo Switch  2008  Action
# Yams                              2  Nintendo Switch  2010  Sports
# Gherkin                           4         Xbox One  2016  Action
# Nantucket Pine Orangebanana       7         Xbox One  2017  Action
# Island Oasis - Raspberry          8              PS4  1999  Action
# ...                             ...              ...   ...     ...
# Danishes - Mini Raspberry       985              PS4  2000  Action
# Fireball Whisky                 990              PS4  2008  Action
# Sausage - Chorizo               995         Xbox One  1990  Action
# Muffin Orange Individual        998              PS4  1996  Action
# Cheese - Swiss Sliced          1000         Xbox One  1996  Action
#
#                                 Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# Syrup - Monin - Passion Fruit    Devshare     82.51     20.44      8.39
# ...

# %%
after_2015 = games.Year>2015
after_2015
# Out:
# Name
# Syrup - Monin - Passion Fruit    False
# Yams                             False
# Pepsi, 355 Ml                    False
# Gherkin                           True
# Pastry - French Mini Assorted     True
#                                  ...
# Shrimp - Black Tiger 16/20       False
# Muffin Mix - Morning Glory       False
# Muffin Orange Individual         False
# Sage - Ground                    False
# Cheese - Swiss Sliced            False
# Name: Year, Length: 1000, dtype: bool

# %%
games.loc[after_2015]
# Out:
#                                Rank         Platform  Year    Genre  \
# Name
# Gherkin                           4         Xbox One  2016   Action
# Pastry - French Mini Assorted     5  Nintendo Switch  2020  Shooter
# Nantucket Pine Orangebanana       7         Xbox One  2017   Action
# Stock - Beef, Brown              13         Xbox One  2022   Sports
# Ice Cream - Chocolate            14  Nintendo Switch  2018  Shooter
# ...                             ...              ...   ...      ...
# Lychee                          958         Xbox One  2018   Action
# Southern Comfort                969              PS4  2018  Shooter
# Tray - 12in Rnd Blk             976         Xbox One  2016   Sports
# Appetizer - Asian Shrimp Roll   989         Xbox One  2019   Sports
# Apple - Granny Smith            994  Nintendo Switch  2019   Sports
#
#                                   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
mid_2000s = games.loc[:, 'Year'].between(2000, 2010)
mid_2000s
# Out:
# Name
# Syrup - Monin - Passion Fruit     True
# Yams                              True
# Pepsi, 355 Ml                    False
# Gherkin                          False
# Pastry - French Mini Assorted    False
#                                  ...
# Shrimp - Black Tiger 16/20       False
# Muffin Mix - Morning Glory       False
# Muffin Orange Individual         False
# Sage - Ground                    False
# Cheese - Swiss Sliced            False
# Name: Year, Length: 1000, dtype: bool

# %%
games[mid_2000s]
# Out:
#                                  Rank         Platform  Year    Genre  \
# Name
# Syrup - Monin - Passion Fruit       1  Nintendo Switch  2008   Action
# Yams                                2  Nintendo Switch  2010   Sports
# Cheese - Taleggio D.o.p.           10  Nintendo Switch  2005   Action
# Soup - Clam Chowder, Dry Mix       11  Nintendo Switch  2005   Action
# Soup - Campbells                   12              PS4  2010  Shooter
# ...                               ...              ...   ...      ...
# Radish - Black, Winter, Organic   984              PS4  2005   Action
# Danishes - Mini Raspberry         985              PS4  2000   Action
# Beer - Rickards Red               987         Xbox One  2001   Sports
# Fireball Whisky                   990              PS4  2008   Action
# Wine - Barbera Alba Doc 2001      993              PS4  2001   Sports
#
#                                      Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games.loc[mid_2000s, :]
# Out:
#                                  Rank         Platform  Year    Genre  \
# Name
# Syrup - Monin - Passion Fruit       1  Nintendo Switch  2008   Action
# Yams                                2  Nintendo Switch  2010   Sports
# Cheese - Taleggio D.o.p.           10  Nintendo Switch  2005   Action
# Soup - Clam Chowder, Dry Mix       11  Nintendo Switch  2005   Action
# Soup - Campbells                   12              PS4  2010  Shooter
# ...                               ...              ...   ...      ...
# Radish - Black, Winter, Organic   984              PS4  2005   Action
# Danishes - Mini Raspberry         985              PS4  2000   Action
# Beer - Rickards Red               987         Xbox One  2001   Sports
# Fireball Whisky                   990              PS4  2008   Action
# Wine - Barbera Alba Doc 2001      993              PS4  2001   Sports
#
#                                      Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
games
# Out:
#                                Rank         Platform  Year    Genre  \
# Name
# Syrup - Monin - Passion Fruit     1  Nintendo Switch  2008   Action
# Yams                              2  Nintendo Switch  2010   Sports
# Pepsi, 355 Ml                     3              PS4  1985   Sports
# Gherkin                           4         Xbox One  2016   Action
# Pastry - French Mini Assorted     5  Nintendo Switch  2020  Shooter
# ...                             ...              ...   ...      ...
# Shrimp - Black Tiger 16/20      996         Xbox One  1985   Sports
# Muffin Mix - Morning Glory      997         Xbox One  2011  Shooter
# Muffin Orange Individual        998              PS4  1996   Action
# Sage - Ground                   999              PS4  1997   Sports
# Cheese - Swiss Sliced          1000         Xbox One  1996   Action
#
#                                 Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# ...

# %%
sport_in_title = games.index.str.lower().str.contains('sport')
sport_in_title
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
games[sport_in_title]
# Out:
#                     Rank         Platform  Year    Genre   Publisher  \
# Name
# Propel Sport Drink   238  Nintendo Switch  1995  Shooter  Topicstorm
#
#                     NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Name
# Propel Sport Drink     81.88     12.66      3.38         4.79          10.1

# %%
sport_in_title = games.index.str.contains('sport', case=False)
sport_in_title
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
games[sport_in_title]
# Out:
#                     Rank         Platform  Year    Genre   Publisher  \
# Name
# Propel Sport Drink   238  Nintendo Switch  1995  Shooter  Topicstorm
#
#                     NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Name
# Propel Sport Drink     81.88     12.66      3.38         4.79          10.1

# %%
games[['Global_Sales']].mean()
# Out:
# Global_Sales    5.34844
# dtype: float64

# %%
genres = games.groupby("Genre")
genres[['Global_Sales']].sum()
# Out:
#          Global_Sales
# Genre
# Action        1778.42
# Shooter       1838.15
# Sports        1731.87

# %%
genres.agg({'Global_Sales': 'sum'})
# Out:
#          Global_Sales
# Genre
# Action        1778.42
# Shooter       1838.15
# Sports        1731.87

# %%
genres[['Global_Sales']].sum().sort_values(by = 'Global_Sales', ascending=False)
# Out:
#          Global_Sales
# Genre
# Shooter       1838.15
# Action        1778.42
# Sports        1731.87

# %%
genres['Global_Sales'].sum().sort_values(ascending=False)
# Out:
# Genre
# Shooter    1838.15
# Action     1778.42
# Sports     1731.87
# Name: Global_Sales, dtype: float64
